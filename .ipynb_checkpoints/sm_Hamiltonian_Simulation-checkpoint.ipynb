# %%
from qiskit_aer import AerSimulator
from qiskit import *
import supermarq
from qiskit.providers.fake_provider import *
import numpy as np 
import os

########## INPUT ############
f=5 # number of fake_backend want to choose
lower_limit= 3 # the lower limit of qubits for the circuit
upper_limit= 17 # the lower limit of qubits for the circuit
steps= 3 #jump in qubit numbers
name_of_algo='hamiltonian'

# %%
all_fakes=[FakeAlmadenV2,FakeArmonkV2,FakeAthensV2,FakeAuckland,FakeBelemV2,FakeBoeblingenV2,FakeBogotaV2,FakeBrooklynV2,FakeBurlingtonV2,FakeCairoV2,FakeCambridgeV2,FakeCasablancaV2,FakeEssexV2,FakeGeneva,FakeGuadalupeV2,FakeHanoiV2,FakeJakartaV2,FakeJohannesburgV2,FakeKolkataV2,FakeLagosV2,FakeLimaV2,FakeLondonV2,FakeManhattanV2,FakeManilaV2,FakeMelbourneV2,FakeMontrealV2,FakeMumbaiV2,FakeNairobiV2,FakeOslo,FakeOurenseV2,FakeParisV2,FakePerth,FakePrague,FakePoughkeepsieV2,FakeQuitoV2,FakeRochesterV2,FakeRomeV2,FakeSantiagoV2,FakeSherbrooke,FakeSingaporeV2,FakeSydneyV2,FakeTorontoV2,FakeValenciaV2,FakeVigoV2,FakeWashingtonV2,FakeYorktownV2]
import random; selected_fakes = random.sample(all_fakes, f)
selected_fakes  # having any randomly selected 5 fake backends out of 46 mentioned in the inital list
# Out:
# [qiskit.providers.fake_provider.backends.cambridge.fake_cambridge.FakeCambridgeV2,
#  qiskit.providers.fake_provider.backends.singapore.fake_singapore.FakeSingaporeV2,
#  qiskit.providers.fake_provider.backends.rome.fake_rome.FakeRomeV2,
#  qiskit.providers.fake_provider.backends.quito.fake_quito.FakeQuitoV2,
#  qiskit.providers.fake_provider.backends.burlington.fake_burlington.FakeBurlingtonV2]

# %%
benchmarks=[]
for i in range(lower_limit,upper_limit,steps):
    label = name_of_algo+str(i)
    benchmarks.append((supermarq.hamiltonian_simulation.HamiltonianSimulation(i),label))
for i in benchmarks:
    circuit=i[0].qiskit_circuit()
    print("--------------------------",i[1],"---------------------------")
    #circuit.draw(output="mpl")
    print(circuit.draw())
# Out:
# -------------------------- hamiltonian3 ---------------------------
#      ┌───┐┌───────────┐┌───┐                           ┌─┐                    »
# q_0: ┤ H ├┤ Rz(-3π/4) ├┤ H ├──■────────────────■───────┤M├────────────────────»
#      ├───┤├───────────┤├───┤┌─┴─┐┌──────────┐┌─┴─┐     └╥┘                 ┌─┐»
# q_1: ┤ H ├┤ Rz(-3π/4) ├┤ H ├┤ X ├┤ Rz(-π/2) ├┤ X ├──■───╫───────────────■──┤M├»
#      ├───┤├───────────┤├───┤└───┘└──────────┘└───┘┌─┴─┐ ║ ┌──────────┐┌─┴─┐└╥┘»
# q_2: ┤ H ├┤ Rz(-3π/4) ├┤ H ├──────────────────────┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├─╫─»
#      └───┘└───────────┘└───┘                      └───┘ ║ └──────────┘└───┘ ║ »
# c: 3/═══════════════════════════════════════════════════╩═══════════════════╩═»
#                                                         0                   1 »
# «
# «q_0: ───
# «
# «q_1: ───
# «     ┌─┐
# «q_2: ┤M├
# «     └╥┘
# «c: 3/═╩═
# «      2
# -------------------------- hamiltonian6 ---------------------------
#      ┌───┐┌───────────┐┌───┐                           ┌─┐                 »
# q_0: ┤ H ├┤ Rz(-3π/4) ├┤ H ├──■────────────────■───────┤M├─────────────────»
#      ├───┤├───────────┤├───┤┌─┴─┐┌──────────┐┌─┴─┐     └╥┘                 »
# q_1: ┤ H ├┤ Rz(-3π/4) ├┤ H ├┤ X ├┤ Rz(-π/2) ├┤ X ├──■───╫───────────────■──»
#      ├───┤├───────────┤├───┤└───┘└──────────┘└───┘┌─┴─┐ ║ ┌──────────┐┌─┴─┐»
# q_2: ┤ H ├┤ Rz(-3π/4) ├┤ H ├──────────────────────┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├»
#      ├───┤├───────────┤├───┤                      └───┘ ║ └──────────┘└───┘»
# q_3: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#      ├───┤├───────────┤├───┤                            ║                  »
# q_4: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#      ├───┤├───────────┤├───┤                            ║                  »
# q_5: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#      └───┘└───────────┘└───┘                            ║                  »
# c: 6/═══════════════════════════════════════════════════╩══════════════════»
#                                                         0                  »
# «                                                                           »
# «q_0: ──────────────────────────────────────────────────────────────────────»
# «          ┌─┐                                                              »
# «q_1: ─────┤M├──────────────────────────────────────────────────────────────»
# «          └╥┘                      ┌─┐                                     »
# «q_2: ──■───╫───────────────■───────┤M├─────────────────────────────────────»
# «     ┌─┴─┐ ║ ┌──────────┐┌─┴─┐     └╥┘                      ┌─┐            »
# «q_3: ┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├──■───╫───────────────■───────┤M├────────────»
# «     └───┘ ║ └──────────┘└───┘┌─┴─┐ ║ ┌──────────┐┌─┴─┐     └╥┘            »
# «q_4: ──────╫──────────────────┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├──■───╫─────────────»
# «           ║                  └───┘ ║ └──────────┘└───┘┌─┴─┐ ║ ┌──────────┐»
# «q_5: ──────╫────────────────────────╫──────────────────┤ X ├─╫─┤ Rz(-π/2) ├»
# «           ║                        ║                  └───┘ ║ └──────────┘»
# «c: 6/══════╩════════════════════════╩════════════════════════╩═════════════»
# «           1                        2                        3             »
# «
# «q_0: ───────────
# «
# «q_1: ───────────
# «
# «q_2: ───────────
# «
# «q_3: ───────────
# «          ┌─┐
# «q_4: ──■──┤M├───
# «     ┌─┴─┐└╥┘┌─┐
# «q_5: ┤ X ├─╫─┤M├
# «     └───┘ ║ └╥┘
# «c: 6/══════╩══╩═
# «           4  5
# -------------------------- hamiltonian9 ---------------------------
#      ┌───┐┌───────────┐┌───┐                           ┌─┐                 »
# q_0: ┤ H ├┤ Rz(-3π/4) ├┤ H ├──■────────────────■───────┤M├─────────────────»
#      ├───┤├───────────┤├───┤┌─┴─┐┌──────────┐┌─┴─┐     └╥┘                 »
# q_1: ┤ H ├┤ Rz(-3π/4) ├┤ H ├┤ X ├┤ Rz(-π/2) ├┤ X ├──■───╫───────────────■──»
#      ├───┤├───────────┤├───┤└───┘└──────────┘└───┘┌─┴─┐ ║ ┌──────────┐┌─┴─┐»
# q_2: ┤ H ├┤ Rz(-3π/4) ├┤ H ├──────────────────────┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├»
#      ├───┤├───────────┤├───┤                      └───┘ ║ └──────────┘└───┘»
# q_3: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#      ├───┤├───────────┤├───┤                            ║                  »
# q_4: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#      ├───┤├───────────┤├───┤                            ║                  »
# q_5: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#      ├───┤├───────────┤├───┤                            ║                  »
# q_6: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#      ├───┤├───────────┤├───┤                            ║                  »
# q_7: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#      ├───┤├───────────┤├───┤                            ║                  »
# q_8: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#      └───┘└───────────┘└───┘                            ║                  »
# c: 9/═══════════════════════════════════════════════════╩══════════════════»
#                                                         0                  »
# «                                                                           »
# «q_0: ──────────────────────────────────────────────────────────────────────»
# «          ┌─┐                                                              »
# «q_1: ─────┤M├──────────────────────────────────────────────────────────────»
# «          └╥┘                      ┌─┐                                     »
# «q_2: ──■───╫───────────────■───────┤M├─────────────────────────────────────»
# «     ┌─┴─┐ ║ ┌──────────┐┌─┴─┐     └╥┘                      ┌─┐            »
# «q_3: ┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├──■───╫───────────────■───────┤M├────────────»
# «     └───┘ ║ └──────────┘└───┘┌─┴─┐ ║ ┌──────────┐┌─┴─┐     └╥┘            »
# «q_4: ──────╫──────────────────┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├──■───╫─────────────»
# «           ║                  └───┘ ║ └──────────┘└───┘┌─┴─┐ ║ ┌──────────┐»
# «q_5: ──────╫────────────────────────╫──────────────────┤ X ├─╫─┤ Rz(-π/2) ├»
# «           ║                        ║                  └───┘ ║ └──────────┘»
# «q_6: ──────╫────────────────────────╫────────────────────────╫─────────────»
# «           ║                        ║                        ║             »
# «q_7: ──────╫────────────────────────╫────────────────────────╫─────────────»
# «           ║                        ║                        ║             »
# «q_8: ──────╫────────────────────────╫────────────────────────╫─────────────»
# «           ║                        ║                        ║             »
# «c: 9/══════╩════════════════════════╩════════════════════════╩═════════════»
# «           1                        2                        3             »
# «                                                                    »
# «q_0: ───────────────────────────────────────────────────────────────»
# «                                                                    »
# «q_1: ───────────────────────────────────────────────────────────────»
# «                                                                    »
# «q_2: ───────────────────────────────────────────────────────────────»
# «                                                                    »
# «q_3: ───────────────────────────────────────────────────────────────»
# «               ┌─┐                                                  »
# «q_4: ──■───────┤M├──────────────────────────────────────────────────»
# «     ┌─┴─┐     └╥┘                      ┌─┐                         »
# «q_5: ┤ X ├──■───╫───────────────■───────┤M├─────────────────────────»
# «     └───┘┌─┴─┐ ║ ┌──────────┐┌─┴─┐     └╥┘                      ┌─┐»
# «q_6: ─────┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├──■───╫───────────────■───────┤M├»
# «          └───┘ ║ └──────────┘└───┘┌─┴─┐ ║ ┌──────────┐┌─┴─┐     └╥┘»
# «q_7: ───────────╫──────────────────┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├──■───╫─»
# «                ║                  └───┘ ║ └──────────┘└───┘┌─┴─┐ ║ »
# «q_8: ───────────╫────────────────────────╫──────────────────┤ X ├─╫─»
# «                ║                        ║                  └───┘ ║ »
# «c: 9/═══════════╩════════════════════════╩════════════════════════╩═»
# «                4                        5                        6 »
# «
# «q_0: ───────────────────────
# «
# «q_1: ───────────────────────
# «
# «q_2: ───────────────────────
# «
# «q_3: ───────────────────────
# «
# «q_4: ───────────────────────
# «
# «q_5: ───────────────────────
# «
# «q_6: ───────────────────────
# «                      ┌─┐
# «q_7: ──────────────■──┤M├───
# «     ┌──────────┐┌─┴─┐└╥┘┌─┐
# «q_8: ┤ Rz(-π/2) ├┤ X ├─╫─┤M├
# «     └──────────┘└───┘ ║ └╥┘
# «c: 9/══════════════════╩══╩═
# «                       7  8
# -------------------------- hamiltonian12 ---------------------------
#       ┌───┐┌───────────┐┌───┐                           ┌─┐                 »
#  q_0: ┤ H ├┤ Rz(-3π/4) ├┤ H ├──■────────────────■───────┤M├─────────────────»
#       ├───┤├───────────┤├───┤┌─┴─┐┌──────────┐┌─┴─┐     └╥┘                 »
#  q_1: ┤ H ├┤ Rz(-3π/4) ├┤ H ├┤ X ├┤ Rz(-π/2) ├┤ X ├──■───╫───────────────■──»
#       ├───┤├───────────┤├───┤└───┘└──────────┘└───┘┌─┴─┐ ║ ┌──────────┐┌─┴─┐»
#  q_2: ┤ H ├┤ Rz(-3π/4) ├┤ H ├──────────────────────┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├»
#       ├───┤├───────────┤├───┤                      └───┘ ║ └──────────┘└───┘»
#  q_3: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#       ├───┤├───────────┤├───┤                            ║                  »
#  q_4: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#       ├───┤├───────────┤├───┤                            ║                  »
#  q_5: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#       ├───┤├───────────┤├───┤                            ║                  »
#  q_6: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#       ├───┤├───────────┤├───┤                            ║                  »
#  q_7: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#       ├───┤├───────────┤├───┤                            ║                  »
#  q_8: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#       ├───┤├───────────┤├───┤                            ║                  »
#  q_9: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#       ├───┤├───────────┤├───┤                            ║                  »
# q_10: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#       ├───┤├───────────┤├───┤                            ║                  »
# q_11: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#       └───┘└───────────┘└───┘                            ║                  »
# c: 12/═══════════════════════════════════════════════════╩══════════════════»
#                                                          0                  »
# «                                                                            »
# « q_0: ──────────────────────────────────────────────────────────────────────»
# «           ┌─┐                                                              »
# « q_1: ─────┤M├──────────────────────────────────────────────────────────────»
# «           └╥┘                      ┌─┐                                     »
# « q_2: ──■───╫───────────────■───────┤M├─────────────────────────────────────»
# «      ┌─┴─┐ ║ ┌──────────┐┌─┴─┐     └╥┘                      ┌─┐            »
# « q_3: ┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├──■───╫───────────────■───────┤M├────────────»
# «      └───┘ ║ └──────────┘└───┘┌─┴─┐ ║ ┌──────────┐┌─┴─┐     └╥┘            »
# « q_4: ──────╫──────────────────┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├──■───╫─────────────»
# «            ║                  └───┘ ║ └──────────┘└───┘┌─┴─┐ ║ ┌──────────┐»
# « q_5: ──────╫────────────────────────╫──────────────────┤ X ├─╫─┤ Rz(-π/2) ├»
# «            ║                        ║                  └───┘ ║ └──────────┘»
# « q_6: ──────╫────────────────────────╫────────────────────────╫─────────────»
# «            ║                        ║                        ║             »
# « q_7: ──────╫────────────────────────╫────────────────────────╫─────────────»
# «            ║                        ║                        ║             »
# « q_8: ──────╫────────────────────────╫────────────────────────╫─────────────»
# «            ║                        ║                        ║             »
# « q_9: ──────╫────────────────────────╫────────────────────────╫─────────────»
# «            ║                        ║                        ║             »
# «q_10: ──────╫────────────────────────╫────────────────────────╫─────────────»
# «            ║                        ║                        ║             »
# «q_11: ──────╫────────────────────────╫────────────────────────╫─────────────»
# «            ║                        ║                        ║             »
# «c: 12/══════╩════════════════════════╩════════════════════════╩═════════════»
# «            1                        2                        3             »
# «                                                                     »
# « q_0: ───────────────────────────────────────────────────────────────»
# «                                                                     »
# « q_1: ───────────────────────────────────────────────────────────────»
# «                                                                     »
# « q_2: ───────────────────────────────────────────────────────────────»
# «                                                                     »
# « q_3: ───────────────────────────────────────────────────────────────»
# «                ┌─┐                                                  »
# « q_4: ──■───────┤M├──────────────────────────────────────────────────»
# «      ┌─┴─┐     └╥┘                      ┌─┐                         »
# « q_5: ┤ X ├──■───╫───────────────■───────┤M├─────────────────────────»
# «      └───┘┌─┴─┐ ║ ┌──────────┐┌─┴─┐     └╥┘                      ┌─┐»
# « q_6: ─────┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├──■───╫───────────────■───────┤M├»
# «           └───┘ ║ └──────────┘└───┘┌─┴─┐ ║ ┌──────────┐┌─┴─┐     └╥┘»
# « q_7: ───────────╫──────────────────┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├──■───╫─»
# «                 ║                  └───┘ ║ └──────────┘└───┘┌─┴─┐ ║ »
# « q_8: ───────────╫────────────────────────╫──────────────────┤ X ├─╫─»
# «                 ║                        ║                  └───┘ ║ »
# « q_9: ───────────╫────────────────────────╫────────────────────────╫─»
# «                 ║                        ║                        ║ »
# «q_10: ───────────╫────────────────────────╫────────────────────────╫─»
# «                 ║                        ║                        ║ »
# «q_11: ───────────╫────────────────────────╫────────────────────────╫─»
# «                 ║                        ║                        ║ »
# «c: 12/═══════════╩════════════════════════╩════════════════════════╩═»
# «                 4                        5                        6 »
# «                                                                              »
# « q_0: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# « q_1: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# « q_2: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# « q_3: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# « q_4: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# « q_5: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# « q_6: ────────────────────────────────────────────────────────────────────────»
# «                            ┌─┐                                               »
# « q_7: ──────────────■───────┤M├───────────────────────────────────────────────»
# «      ┌──────────┐┌─┴─┐     └╥┘                      ┌─┐                      »
# « q_8: ┤ Rz(-π/2) ├┤ X ├──■───╫───────────────■───────┤M├──────────────────────»
# «      └──────────┘└───┘┌─┴─┐ ║ ┌──────────┐┌─┴─┐     └╥┘                      »
# « q_9: ─────────────────┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├──■───╫───────────────■───────»
# «                       └───┘ ║ └──────────┘└───┘┌─┴─┐ ║ ┌──────────┐┌─┴─┐     »
# «q_10: ───────────────────────╫──────────────────┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├──■──»
# «                             ║                  └───┘ ║ └──────────┘└───┘┌─┴─┐»
# «q_11: ───────────────────────╫────────────────────────╫──────────────────┤ X ├»
# «                             ║                        ║                  └───┘»
# «c: 12/═══════════════════════╩════════════════════════╩═══════════════════════»
# «                             7                        8                       »
# «
# « q_0: ──────────────────────────
# «
# « q_1: ──────────────────────────
# «
# « q_2: ──────────────────────────
# «
# « q_3: ──────────────────────────
# «
# « q_4: ──────────────────────────
# «
# « q_5: ──────────────────────────
# «
# « q_6: ──────────────────────────
# «
# « q_7: ──────────────────────────
# «
# « q_8: ──────────────────────────
# «      ┌─┐
# « q_9: ┤M├───────────────────────
# «      └╥┘                 ┌─┐
# «q_10: ─╫───────────────■──┤M├───
# «       ║ ┌──────────┐┌─┴─┐└╥┘┌─┐
# «q_11: ─╫─┤ Rz(-π/2) ├┤ X ├─╫─┤M├
# «       ║ └──────────┘└───┘ ║ └╥┘
# «c: 12/═╩═══════════════════╩══╩═
# «       9                   10 11
# -------------------------- hamiltonian15 ---------------------------
#       ┌───┐┌───────────┐┌───┐                           ┌─┐                 »
#  q_0: ┤ H ├┤ Rz(-3π/4) ├┤ H ├──■────────────────■───────┤M├─────────────────»
#       ├───┤├───────────┤├───┤┌─┴─┐┌──────────┐┌─┴─┐     └╥┘                 »
#  q_1: ┤ H ├┤ Rz(-3π/4) ├┤ H ├┤ X ├┤ Rz(-π/2) ├┤ X ├──■───╫───────────────■──»
#       ├───┤├───────────┤├───┤└───┘└──────────┘└───┘┌─┴─┐ ║ ┌──────────┐┌─┴─┐»
#  q_2: ┤ H ├┤ Rz(-3π/4) ├┤ H ├──────────────────────┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├»
#       ├───┤├───────────┤├───┤                      └───┘ ║ └──────────┘└───┘»
#  q_3: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#       ├───┤├───────────┤├───┤                            ║                  »
#  q_4: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#       ├───┤├───────────┤├───┤                            ║                  »
#  q_5: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#       ├───┤├───────────┤├───┤                            ║                  »
#  q_6: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#       ├───┤├───────────┤├───┤                            ║                  »
#  q_7: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#       ├───┤├───────────┤├───┤                            ║                  »
#  q_8: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#       ├───┤├───────────┤├───┤                            ║                  »
#  q_9: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#       ├───┤├───────────┤├───┤                            ║                  »
# q_10: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#       ├───┤├───────────┤├───┤                            ║                  »
# q_11: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#       ├───┤├───────────┤├───┤                            ║                  »
# q_12: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#       ├───┤├───────────┤├───┤                            ║                  »
# q_13: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#       ├───┤├───────────┤├───┤                            ║                  »
# q_14: ┤ H ├┤ Rz(-3π/4) ├┤ H ├────────────────────────────╫──────────────────»
#       └───┘└───────────┘└───┘                            ║                  »
# c: 15/═══════════════════════════════════════════════════╩══════════════════»
#                                                          0                  »
# «                                                                            »
# « q_0: ──────────────────────────────────────────────────────────────────────»
# «           ┌─┐                                                              »
# « q_1: ─────┤M├──────────────────────────────────────────────────────────────»
# «           └╥┘                      ┌─┐                                     »
# « q_2: ──■───╫───────────────■───────┤M├─────────────────────────────────────»
# «      ┌─┴─┐ ║ ┌──────────┐┌─┴─┐     └╥┘                      ┌─┐            »
# « q_3: ┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├──■───╫───────────────■───────┤M├────────────»
# «      └───┘ ║ └──────────┘└───┘┌─┴─┐ ║ ┌──────────┐┌─┴─┐     └╥┘            »
# « q_4: ──────╫──────────────────┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├──■───╫─────────────»
# «            ║                  └───┘ ║ └──────────┘└───┘┌─┴─┐ ║ ┌──────────┐»
# « q_5: ──────╫────────────────────────╫──────────────────┤ X ├─╫─┤ Rz(-π/2) ├»
# «            ║                        ║                  └───┘ ║ └──────────┘»
# « q_6: ──────╫────────────────────────╫────────────────────────╫─────────────»
# «            ║                        ║                        ║             »
# « q_7: ──────╫────────────────────────╫────────────────────────╫─────────────»
# «            ║                        ║                        ║             »
# « q_8: ──────╫────────────────────────╫────────────────────────╫─────────────»
# «            ║                        ║                        ║             »
# « q_9: ──────╫────────────────────────╫────────────────────────╫─────────────»
# «            ║                        ║                        ║             »
# «q_10: ──────╫────────────────────────╫────────────────────────╫─────────────»
# «            ║                        ║                        ║             »
# «q_11: ──────╫────────────────────────╫────────────────────────╫─────────────»
# «            ║                        ║                        ║             »
# «q_12: ──────╫────────────────────────╫────────────────────────╫─────────────»
# «            ║                        ║                        ║             »
# «q_13: ──────╫────────────────────────╫────────────────────────╫─────────────»
# «            ║                        ║                        ║             »
# «q_14: ──────╫────────────────────────╫────────────────────────╫─────────────»
# «            ║                        ║                        ║             »
# «c: 15/══════╩════════════════════════╩════════════════════════╩═════════════»
# «            1                        2                        3             »
# «                                                                     »
# « q_0: ───────────────────────────────────────────────────────────────»
# «                                                                     »
# « q_1: ───────────────────────────────────────────────────────────────»
# «                                                                     »
# « q_2: ───────────────────────────────────────────────────────────────»
# «                                                                     »
# « q_3: ───────────────────────────────────────────────────────────────»
# «                ┌─┐                                                  »
# « q_4: ──■───────┤M├──────────────────────────────────────────────────»
# «      ┌─┴─┐     └╥┘                      ┌─┐                         »
# « q_5: ┤ X ├──■───╫───────────────■───────┤M├─────────────────────────»
# «      └───┘┌─┴─┐ ║ ┌──────────┐┌─┴─┐     └╥┘                      ┌─┐»
# « q_6: ─────┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├──■───╫───────────────■───────┤M├»
# «           └───┘ ║ └──────────┘└───┘┌─┴─┐ ║ ┌──────────┐┌─┴─┐     └╥┘»
# « q_7: ───────────╫──────────────────┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├──■───╫─»
# «                 ║                  └───┘ ║ └──────────┘└───┘┌─┴─┐ ║ »
# « q_8: ───────────╫────────────────────────╫──────────────────┤ X ├─╫─»
# «                 ║                        ║                  └───┘ ║ »
# « q_9: ───────────╫────────────────────────╫────────────────────────╫─»
# «                 ║                        ║                        ║ »
# «q_10: ───────────╫────────────────────────╫────────────────────────╫─»
# «                 ║                        ║                        ║ »
# «q_11: ───────────╫────────────────────────╫────────────────────────╫─»
# «                 ║                        ║                        ║ »
# «q_12: ───────────╫────────────────────────╫────────────────────────╫─»
# «                 ║                        ║                        ║ »
# «q_13: ───────────╫────────────────────────╫────────────────────────╫─»
# «                 ║                        ║                        ║ »
# «q_14: ───────────╫────────────────────────╫────────────────────────╫─»
# «                 ║                        ║                        ║ »
# «c: 15/═══════════╩════════════════════════╩════════════════════════╩═»
# «                 4                        5                        6 »
# «                                                                              »
# « q_0: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# « q_1: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# « q_2: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# « q_3: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# « q_4: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# « q_5: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# « q_6: ────────────────────────────────────────────────────────────────────────»
# «                            ┌─┐                                               »
# « q_7: ──────────────■───────┤M├───────────────────────────────────────────────»
# «      ┌──────────┐┌─┴─┐     └╥┘                      ┌─┐                      »
# « q_8: ┤ Rz(-π/2) ├┤ X ├──■───╫───────────────■───────┤M├──────────────────────»
# «      └──────────┘└───┘┌─┴─┐ ║ ┌──────────┐┌─┴─┐     └╥┘                      »
# « q_9: ─────────────────┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├──■───╫───────────────■───────»
# «                       └───┘ ║ └──────────┘└───┘┌─┴─┐ ║ ┌──────────┐┌─┴─┐     »
# «q_10: ───────────────────────╫──────────────────┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├──■──»
# «                             ║                  └───┘ ║ └──────────┘└───┘┌─┴─┐»
# «q_11: ───────────────────────╫────────────────────────╫──────────────────┤ X ├»
# «                             ║                        ║                  └───┘»
# «q_12: ───────────────────────╫────────────────────────╫───────────────────────»
# «                             ║                        ║                       »
# «q_13: ───────────────────────╫────────────────────────╫───────────────────────»
# «                             ║                        ║                       »
# «q_14: ───────────────────────╫────────────────────────╫───────────────────────»
# «                             ║                        ║                       »
# «c: 15/═══════════════════════╩════════════════════════╩═══════════════════════»
# «                             7                        8                       »
# «                                                                            »
# « q_0: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# « q_1: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# « q_2: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# « q_3: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# « q_4: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# « q_5: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# « q_6: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# « q_7: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# « q_8: ──────────────────────────────────────────────────────────────────────»
# «      ┌─┐                                                                   »
# « q_9: ┤M├───────────────────────────────────────────────────────────────────»
# «      └╥┘                      ┌─┐                                          »
# «q_10: ─╫───────────────■───────┤M├──────────────────────────────────────────»
# «       ║ ┌──────────┐┌─┴─┐     └╥┘                      ┌─┐                 »
# «q_11: ─╫─┤ Rz(-π/2) ├┤ X ├──■───╫───────────────■───────┤M├─────────────────»
# «       ║ └──────────┘└───┘┌─┴─┐ ║ ┌──────────┐┌─┴─┐     └╥┘                 »
# «q_12: ─╫──────────────────┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├──■───╫───────────────■──»
# «       ║                  └───┘ ║ └──────────┘└───┘┌─┴─┐ ║ ┌──────────┐┌─┴─┐»
# «q_13: ─╫────────────────────────╫──────────────────┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├»
# «       ║                        ║                  └───┘ ║ └──────────┘└───┘»
# «q_14: ─╫────────────────────────╫────────────────────────╫──────────────────»
# «       ║                        ║                        ║                  »
# «c: 15/═╩════════════════════════╩════════════════════════╩══════════════════»
# «       9                        10                       11                 »
# «
# « q_0: ───────────────────────────────
# «
# « q_1: ───────────────────────────────
# «
# « q_2: ───────────────────────────────
# «
# « q_3: ───────────────────────────────
# «
# « q_4: ───────────────────────────────
# «
# « q_5: ───────────────────────────────
# «
# « q_6: ───────────────────────────────
# «
# « q_7: ───────────────────────────────
# «
# « q_8: ───────────────────────────────
# «
# « q_9: ───────────────────────────────
# «
# «q_10: ───────────────────────────────
# «
# «q_11: ───────────────────────────────
# «           ┌─┐
# «q_12: ─────┤M├───────────────────────
# «           └╥┘                 ┌─┐
# «q_13: ──■───╫───────────────■──┤M├───
# «      ┌─┴─┐ ║ ┌──────────┐┌─┴─┐└╥┘┌─┐
# «q_14: ┤ X ├─╫─┤ Rz(-π/2) ├┤ X ├─╫─┤M├
# «      └───┘ ║ └──────────┘└───┘ ║ └╥┘
# «c: 15/══════╩═══════════════════╩══╩═
# «            12                  13 14

# %%
benchmark_features = {}
for benchmark, label in benchmarks:
    benchmark_features[label] = [
        supermarq.converters.compute_communication_with_qiskit(benchmark.qiskit_circuit()),
        supermarq.converters.compute_depth_with_qiskit(benchmark.qiskit_circuit()),
        supermarq.converters.compute_entanglement_with_qiskit(benchmark.qiskit_circuit()),
        supermarq.converters.compute_liveness_with_qiskit(benchmark.qiskit_circuit()),
        supermarq.converters.compute_measurement_with_qiskit(benchmark.qiskit_circuit()),
        supermarq.converters.compute_parallelism_with_qiskit(benchmark.qiskit_circuit()),]
print(benchmark_features)
# Out:
# {'hamiltonian3': [0.6666666666666666, 1.0, 0.26666666666666666, 0.7333333333333333, 0.0, 0.25], 'hamiltonian6': [0.3333333333333333, 1.0, 0.30303030303030304, 0.4298245614035088, 0.0, 0.1473684210526316], 'hamiltonian9': [0.2222222222222222, 1.0, 0.3137254901960784, 0.30158730158730157, 0.0, 0.10267857142857142], 'hamiltonian12': [0.16666666666666666, 1.0, 0.3188405797101449, 0.23198198198198197, 0.0, 0.07862407862407862], 'hamiltonian15': [0.13333333333333333, 1.0, 0.3218390804597701, 0.18840579710144928, 0.0, 0.06366459627329192]}

# %%
# %time
import time
jobs =[]
print("=============SCORES OF ALL THE CIRCUITS=============")    
for backend in selected_fakes:
    print("-----------BACKEND-NAME :: ", backend().name,"----------------")
    for benchmark, label in benchmarks:
        circuit=benchmark.qiskit_circuit()
        score_list=[]
        timetaken=[]
        for i in range(0,5):
            job = backend().run(circuit, shots=1000)
            result = job.result()
            counts = job.result(0).get_counts()
            score = benchmark.score(counts)
            score_list.append(score)
            t=job.result(0).time_taken
            timetaken.append(t)
            print(i+1,"th iteration Execution time::",t)
        score = np.mean(score_list) 
        sd = np.std(score_list)
        execution_time = np.mean(timetaken)
        print("                      Average of Metadata-wise time taken ::",execution_time)
        print("                    ",label, "--> score::",score,"      SD ::",sd)
        jobs.append((label,benchmark,backend,job,score,sd))
#jobs
# Out:
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 8.82 µs
# =============SCORES OF ALL THE CIRCUITS=============
# -----------BACKEND-NAME ::  fake_cambridge ----------------
# 1 th iteration Execution time:: 1.0191755294799805
# 2 th iteration Execution time:: 0.6097533702850342
# 3 th iteration Execution time:: 0.7923848628997803
# 4 th iteration Execution time:: 1.1587536334991455
# 5 th iteration Execution time:: 0.8293354511260986
#                       Average of Metadata-wise time taken :: 0.8818805694580079
#                      hamiltonian3 --> score:: 0.9266466094067258       SD :: 0.0024729649321322076
# 1 th iteration Execution time:: 0.9219710826873779
# 2 th iteration Execution time:: 0.9349789619445801
# 3 th iteration Execution time:: 0.959770679473877
# 4 th iteration Execution time:: 0.6307120323181152
# 5 th iteration Execution time:: 0.9098994731903076
#                       Average of Metadata-wise time taken :: 0.8714664459228516
#                      hamiltonian6 --> score:: 0.9205466094067256       SD :: 0.008065426901975578
# 1 th iteration Execution time:: 1.8547556400299072
# 2 th iteration Execution time:: 1.7075467109680176
# 3 th iteration Execution time:: 1.307941198348999
# 4 th iteration Execution time:: 1.5743200778961182
# 5 th iteration Execution time:: 1.2680318355560303
#                       Average of Metadata-wise time taken :: 1.5425190925598145
#                      hamiltonian9 --> score:: 0.9210910538511703       SD :: 0.00313829394558399
# 1 th iteration Execution time:: 2.0011556148529053
# 2 th iteration Execution time:: 1.5000360012054443
# 3 th iteration Execution time:: 1.5236878395080566
# 4 th iteration Execution time:: 1.5469775199890137
# 5 th iteration Execution time:: 1.5461115837097168
#                       Average of Metadata-wise time taken :: 1.6235937118530273
#                      hamiltonian12 --> score:: 0.8619299427400605       SD :: 0.002454813864860424
# 1 th iteration Execution time:: 5.507583856582642
# 2 th iteration Execution time:: 5.437437295913696
# 3 th iteration Execution time:: 5.680618524551392
# 4 th iteration Execution time:: 5.049031734466553
# 5 th iteration Execution time:: 5.261647701263428
#                       Average of Metadata-wise time taken :: 5.387263822555542
#                      hamiltonian15 --> score:: 0.8707132760733923       SD :: 0.005329832184141521
# -----------BACKEND-NAME ::  fake_singapore ----------------
# 1 th iteration Execution time:: 0.25073885917663574
# 2 th iteration Execution time:: 0.9907050132751465
# 3 th iteration Execution time:: 0.2951631546020508
# 4 th iteration Execution time:: 0.900810956954956
# 5 th iteration Execution time:: 0.25016212463378906
#                       Average of Metadata-wise time taken :: 0.5375160217285156
#                      hamiltonian3 --> score:: 0.9296466094067259       SD :: 0.010372185026416696
# 1 th iteration Execution time:: 0.25557589530944824
# 2 th iteration Execution time:: 0.2621793746948242
# 3 th iteration Execution time:: 0.25086259841918945
# 4 th iteration Execution time:: 0.33646082878112793
# 5 th iteration Execution time:: 0.30901432037353516
#                       Average of Metadata-wise time taken :: 0.282818603515625
#                      hamiltonian6 --> score:: 0.935879942740059       SD :: 0.007532595834106549
# 1 th iteration Execution time:: 1.0741827487945557
# 2 th iteration Execution time:: 0.9518983364105225
# 3 th iteration Execution time:: 0.9342923164367676
# 4 th iteration Execution time:: 0.9010910987854004
# 5 th iteration Execution time:: 0.9970641136169434
#                       Average of Metadata-wise time taken :: 0.9717057228088379
#                      hamiltonian9 --> score:: 0.9323799427400592       SD :: 0.0031666471734292487
# 1 th iteration Execution time:: 1.107743501663208
# 2 th iteration Execution time:: 1.8515863418579102
# 3 th iteration Execution time:: 1.1126224994659424
# 4 th iteration Execution time:: 1.041886329650879
# 5 th iteration Execution time:: 1.8540582656860352
#                       Average of Metadata-wise time taken :: 1.3935793876647948
#                      hamiltonian12 --> score:: 0.926113276073394       SD :: 0.0035935899722823856
# 1 th iteration Execution time:: 3.972926139831543
# 2 th iteration Execution time:: 3.9593451023101807
# 3 th iteration Execution time:: 3.733332872390747
# 4 th iteration Execution time:: 3.4476399421691895
# 5 th iteration Execution time:: 3.8280606269836426
#                       Average of Metadata-wise time taken :: 3.7882609367370605
#                      hamiltonian15 --> score:: 0.9255399427400601       SD :: 0.003193771716603594
# -----------BACKEND-NAME ::  fake_rome ----------------
# 1 th iteration Execution time:: 0.08616089820861816
# 2 th iteration Execution time:: 0.08450102806091309
# 3 th iteration Execution time:: 0.09949898719787598
# 4 th iteration Execution time:: 0.08864402770996094
# 5 th iteration Execution time:: 0.0798788070678711
#                       Average of Metadata-wise time taken :: 0.08773674964904785
#                      hamiltonian3 --> score:: 0.9525132760733926       SD :: 0.008359691647689198
# 1 th iteration Execution time:: 0.10047554969787598
# 2 th iteration Execution time:: 0.10496163368225098
# 3 th iteration Execution time:: 0.10639595985412598
# 4 th iteration Execution time:: 0.11874556541442871
# 5 th iteration Execution time:: 0.105926513671875
#                       Average of Metadata-wise time taken :: 0.10730104446411133
#                      hamiltonian6 --> score:: 0.9596132760733923       SD :: 0.004863697724525629
# 1 th iteration Execution time:: 0.7483601570129395
# 2 th iteration Execution time:: 0.8805022239685059
# 3 th iteration Execution time:: 0.890678882598877
# 4 th iteration Execution time:: 0.8792219161987305
# 5 th iteration Execution time:: 0.9406371116638184
#                       Average of Metadata-wise time taken :: 0.8678800582885742
#                      hamiltonian9 --> score:: 0.9752021649622813       SD :: 0.0021098241691409167
# 1 th iteration Execution time:: 1.7342116832733154
# 2 th iteration Execution time:: 0.7730920314788818
# 3 th iteration Execution time:: 0.8497650623321533
# 4 th iteration Execution time:: 0.8459634780883789
# 5 th iteration Execution time:: 0.8246500492095947
#                       Average of Metadata-wise time taken :: 1.0055364608764648
#                      hamiltonian12 --> score:: 0.9801966094067275       SD :: 0.004205485835324036
# 1 th iteration Execution time:: 3.169900417327881
# 2 th iteration Execution time:: 3.2745168209075928
# 3 th iteration Execution time:: 3.248417377471924
# 4 th iteration Execution time:: 3.41286301612854
# 5 th iteration Execution time:: 3.1902410984039307
#                       Average of Metadata-wise time taken :: 3.2591877460479735
#                      hamiltonian15 --> score:: 0.987366609406728       SD :: 0.0030097323616704486
# -----------BACKEND-NAME ::  fake_quito ----------------
# 1 th iteration Execution time:: 0.08075881004333496
# 2 th iteration Execution time:: 0.08719015121459961
# 3 th iteration Execution time:: 0.09591197967529297
# 4 th iteration Execution time:: 0.07982254028320312
# 5 th iteration Execution time:: 0.08837461471557617
#                       Average of Metadata-wise time taken :: 0.08641161918640136
#                      hamiltonian3 --> score:: 0.8909132760733927       SD :: 0.007878522140040676
# 1 th iteration Execution time:: 0.08684635162353516
# 2 th iteration Execution time:: 1.0721383094787598
# 3 th iteration Execution time:: 0.12662792205810547
# 4 th iteration Execution time:: 0.1154327392578125
# 5 th iteration Execution time:: 0.11376285552978516
#                       Average of Metadata-wise time taken :: 0.3029616355895996
#                      hamiltonian6 --> score:: 0.9173466094067256       SD :: 0.005550375362681947
# 1 th iteration Execution time:: 0.8330473899841309
# 2 th iteration Execution time:: 0.9806153774261475
# 3 th iteration Execution time:: 0.8407914638519287
# 4 th iteration Execution time:: 0.6818881034851074
# 5 th iteration Execution time:: 0.798316478729248
#                       Average of Metadata-wise time taken :: 0.8269317626953125
#                      hamiltonian9 --> score:: 0.9464243871845035       SD :: 0.004380315113530886
# 1 th iteration Execution time:: 0.6658885478973389
# 2 th iteration Execution time:: 0.6979377269744873
# 3 th iteration Execution time:: 0.673466682434082
# 4 th iteration Execution time:: 0.6927971839904785
# 5 th iteration Execution time:: 0.7050085067749023
#                       Average of Metadata-wise time taken :: 0.6870197296142578
#                      hamiltonian12 --> score:: 0.9586632760733942       SD :: 0.002123676058159528
# 1 th iteration Execution time:: 3.358855962753296
# 2 th iteration Execution time:: 2.904970169067383
# 3 th iteration Execution time:: 3.018533706665039
# 4 th iteration Execution time:: 3.522233724594116
# 5 th iteration Execution time:: 3.1656696796417236
#                       Average of Metadata-wise time taken :: 3.1940526485443117
#                      hamiltonian15 --> score:: 0.9680599427400616       SD :: 0.002904219153040649
# -----------BACKEND-NAME ::  fake_burlington ----------------
# 1 th iteration Execution time:: 0.07007074356079102
# 2 th iteration Execution time:: 0.07413434982299805
# 3 th iteration Execution time:: 0.06017351150512695
# 4 th iteration Execution time:: 0.06795978546142578
# 5 th iteration Execution time:: 0.05959129333496094
#                       Average of Metadata-wise time taken :: 0.06638593673706054
#                      hamiltonian3 --> score:: 0.9453799427400593       SD :: 0.008483709880313772
# 1 th iteration Execution time:: 0.07169485092163086
# 2 th iteration Execution time:: 0.11119890213012695
# 3 th iteration Execution time:: 0.08391118049621582
# 4 th iteration Execution time:: 0.08457088470458984
# 5 th iteration Execution time:: 0.08579397201538086
#                       Average of Metadata-wise time taken :: 0.08743395805358886
#                      hamiltonian6 --> score:: 0.9596132760733923       SD :: 0.005361384564125592
# 1 th iteration Execution time:: 0.7670450210571289
# 2 th iteration Execution time:: 0.6425669193267822
# 3 th iteration Execution time:: 0.6766324043273926
# 4 th iteration Execution time:: 0.7614989280700684
# 5 th iteration Execution time:: 0.8618679046630859
#                       Average of Metadata-wise time taken :: 0.7419222354888916
#                      hamiltonian9 --> score:: 0.9738910538511701       SD :: 0.004232735449176576
# 1 th iteration Execution time:: 0.7606246471405029
# 2 th iteration Execution time:: 0.7699480056762695
# 3 th iteration Execution time:: 0.7514333724975586
# 4 th iteration Execution time:: 0.9028136730194092
# 5 th iteration Execution time:: 0.7549104690551758
#                       Average of Metadata-wise time taken :: 0.7879460334777832
#                      hamiltonian12 --> score:: 0.9783299427400607       SD :: 0.0020101133190831445
# 1 th iteration Execution time:: 4.3271567821502686
# 2 th iteration Execution time:: 3.053846597671509
# 3 th iteration Execution time:: 2.9711759090423584
# 4 th iteration Execution time:: 3.167813539505005
# 5 th iteration Execution time:: 3.1123688220977783
#                       Average of Metadata-wise time taken :: 3.3264723300933836
#                      hamiltonian15 --> score:: 0.983753276073395       SD :: 0.001074636889579165

# %%
all_scores={}  
all_fake_names=[]
all_fake_scores=[]
for i in selected_fakes:
    fakes=i
    #print("SELCETED_FAKES:: ",i)
    i={}
    for label,benchmark,backend,job,score,sd in jobs:
        #supermarq.plotting.plot_results([score], [label])
        if fakes == backend:
            i[label] = score
    device_scores = 'device_score_' +str(fakes().name)
    all_scores[device_scores]= i
    all_fake_scores.append(i)
    all_fake_names.append(device_scores)   
#print(all_scores)

# %%
for label,benchmark,backend,job,score,sd in jobs:
    print("USED BACKEND::",backend().name,"; CIRCUIT_NAME:",label, "; SCORE =",score)
    supermarq.plotting.plot_results([score], [label])
    print("-----------------------------------------------------------")
# Out:
# USED BACKEND:: fake_cambridge ; CIRCUIT_NAME: hamiltonian3 ; SCORE = 0.9266466094067258
# -----------------------------------------------------------
# USED BACKEND:: fake_cambridge ; CIRCUIT_NAME: hamiltonian6 ; SCORE = 0.9205466094067256
# -----------------------------------------------------------
# USED BACKEND:: fake_cambridge ; CIRCUIT_NAME: hamiltonian9 ; SCORE = 0.9210910538511703
# -----------------------------------------------------------
# USED BACKEND:: fake_cambridge ; CIRCUIT_NAME: hamiltonian12 ; SCORE = 0.8619299427400605
# -----------------------------------------------------------
# USED BACKEND:: fake_cambridge ; CIRCUIT_NAME: hamiltonian15 ; SCORE = 0.8707132760733923
# -----------------------------------------------------------
# USED BACKEND:: fake_singapore ; CIRCUIT_NAME: hamiltonian3 ; SCORE = 0.9296466094067259
# -----------------------------------------------------------
# USED BACKEND:: fake_singapore ; CIRCUIT_NAME: hamiltonian6 ; SCORE = 0.935879942740059
# -----------------------------------------------------------
# USED BACKEND:: fake_singapore ; CIRCUIT_NAME: hamiltonian9 ; SCORE = 0.9323799427400592
# -----------------------------------------------------------
# USED BACKEND:: fake_singapore ; CIRCUIT_NAME: hamiltonian12 ; SCORE = 0.926113276073394
# -----------------------------------------------------------
# USED BACKEND:: fake_singapore ; CIRCUIT_NAME: hamiltonian15 ; SCORE = 0.9255399427400601
# -----------------------------------------------------------
# USED BACKEND:: fake_rome ; CIRCUIT_NAME: hamiltonian3 ; SCORE = 0.9525132760733926
# -----------------------------------------------------------
# USED BACKEND:: fake_rome ; CIRCUIT_NAME: hamiltonian6 ; SCORE = 0.9596132760733923
# -----------------------------------------------------------
# USED BACKEND:: fake_rome ; CIRCUIT_NAME: hamiltonian9 ; SCORE = 0.9752021649622813
# -----------------------------------------------------------
# USED BACKEND:: fake_rome ; CIRCUIT_NAME: hamiltonian12 ; SCORE = 0.9801966094067275
# -----------------------------------------------------------
# USED BACKEND:: fake_rome ; CIRCUIT_NAME: hamiltonian15 ; SCORE = 0.987366609406728
# -----------------------------------------------------------
# USED BACKEND:: fake_quito ; CIRCUIT_NAME: hamiltonian3 ; SCORE = 0.8909132760733927
# -----------------------------------------------------------
# USED BACKEND:: fake_quito ; CIRCUIT_NAME: hamiltonian6 ; SCORE = 0.9173466094067256
# -----------------------------------------------------------
# USED BACKEND:: fake_quito ; CIRCUIT_NAME: hamiltonian9 ; SCORE = 0.9464243871845035
# -----------------------------------------------------------
# USED BACKEND:: fake_quito ; CIRCUIT_NAME: hamiltonian12 ; SCORE = 0.9586632760733942
# -----------------------------------------------------------
# USED BACKEND:: fake_quito ; CIRCUIT_NAME: hamiltonian15 ; SCORE = 0.9680599427400616
# -----------------------------------------------------------
# USED BACKEND:: fake_burlington ; CIRCUIT_NAME: hamiltonian3 ; SCORE = 0.9453799427400593
# -----------------------------------------------------------
# USED BACKEND:: fake_burlington ; CIRCUIT_NAME: hamiltonian6 ; SCORE = 0.9596132760733923
# -----------------------------------------------------------
# USED BACKEND:: fake_burlington ; CIRCUIT_NAME: hamiltonian9 ; SCORE = 0.9738910538511701
# -----------------------------------------------------------
# USED BACKEND:: fake_burlington ; CIRCUIT_NAME: hamiltonian12 ; SCORE = 0.9783299427400607
# -----------------------------------------------------------
# USED BACKEND:: fake_burlington ; CIRCUIT_NAME: hamiltonian15 ; SCORE = 0.983753276073395
# -----------------------------------------------------------

# %%
names=[]
scores=[]
X="A "+name_of_algo+' Benchamrk'
for i,j in benchmark_features.items():
    names.append(i)
    scores.append(j)
supermarq.plotting.plot_benchmark([X,names,scores],
        spoke_labels=["PC", "CD", "Ent", "Liv", "Mea", "Par"],show=True)

# %%
supermarq.plotting.plot_correlations(benchmark_features,all_fake_scores,["PC", "CD", "Ent", "Liv", "Mea", "Par"],device_name=all_fake_names,show=True,)

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 
import numpy as np
all_fake_names=[]
all_score=[]
all_sd=[]
all_ckt=[]
v='Plot of '+name_of_algo+' over'+str(lower_limit)+' to '+str(upper_limit)+ ' Qubits'
for i in selected_fakes:
    all_fake_names.append(i().name)    
for benchmark, label in benchmarks:
    i=[]
    j=[]
    k=[]
    for ckt,benchmark,backend,job,score,sd in jobs:
        if ckt == label:
            i.append(score)
            j.append(sd)
    all_ckt.append(label)
    all_score.append(i)
    all_sd.append(j)
num_bars = len(all_score)
width = 0.1
x = np.arange(len(all_fake_names)) # x-axis positions for each bar
fig, ax = plt.subplots()
for i in range(num_bars):               # Create bars for each category with appropriate offsets
    ax.bar(x + i * width, all_score[i], width=width, label=f'Bar {i+1}', 
           yerr=all_sd[i],align='center',alpha=0.9,ecolor='black',capsize=2)
ax.set_xlabel('Name of Fake Backends',fontweight ='bold',fontsize = 12)
ax.set_ylabel('Scores',fontweight ='bold',fontsize = 12)
ax.set_title(v)
ax.set_xticks(x + (num_bars - 1) * width / 2)
ax.set_xticklabels(all_fake_names)
ax.legend(all_ckt,loc="lower left")
#ax.grid(True)
plt.show()
