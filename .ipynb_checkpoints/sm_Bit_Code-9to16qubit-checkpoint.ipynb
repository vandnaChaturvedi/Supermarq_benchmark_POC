# %%
from qiskit_aer import AerSimulator
from qiskit import *
import supermarq
from qiskit.providers.fake_provider import *
import numpy as np 
import os
import random
########## INPUT ############
f=5 # number of fake_backend want to choose
lower_limit= 3 # the lower limit of qubits for the circuit
upper_limit= 9 # the lower limit of qubits for the circuit
steps= 1 #jump in qubit numbers
name_of_algo='bitcode'

# %%
all_fakes=[FakeAlmadenV2,FakeArmonkV2,FakeAthensV2,FakeAuckland,FakeBelemV2,FakeBoeblingenV2,FakeBogotaV2,FakeBrooklynV2,FakeBurlingtonV2,FakeCairoV2,FakeCambridgeV2,FakeCasablancaV2,FakeEssexV2,FakeGeneva,FakeGuadalupeV2,FakeHanoiV2,FakeJakartaV2,FakeJohannesburgV2,FakeKolkataV2,FakeLagosV2,FakeLimaV2,FakeLondonV2,FakeManhattanV2,FakeManilaV2,FakeMelbourneV2,FakeMontrealV2,FakeMumbaiV2,FakeNairobiV2,FakeOslo,FakeOurenseV2,FakeParisV2,FakePerth,FakePrague,FakePoughkeepsieV2,FakeQuitoV2,FakeRochesterV2,FakeRomeV2,FakeSantiagoV2,FakeSherbrooke,FakeSingaporeV2,FakeSydneyV2,FakeTorontoV2,FakeValenciaV2,FakeVigoV2,FakeWashingtonV2,FakeYorktownV2]
selected_fakes = random.sample(all_fakes, f)
selected_fakes  # having any randomly selected 5 fake backends out of 46 mentioned in the inital list
# Out:
# [qiskit.providers.fake_provider.backends.paris.fake_paris.FakeParisV2,
#  qiskit.providers.fake_provider.backends.cambridge.fake_cambridge.FakeCambridgeV2,
#  qiskit.providers.fake_provider.backends.washington.fake_washington.FakeWashingtonV2,
#  qiskit.providers.fake_provider.backends.ourense.fake_ourense.FakeOurenseV2,
#  qiskit.providers.fake_provider.backends.london.fake_london.FakeLondonV2]

# %%
benchmarks=[]
for i in range(lower_limit,upper_limit,steps):
    label = name_of_algo+str(i)
    rand_list=[]
    for j in range(i):       
        rand_list.append(random.randint(0,1))
    print("i=",i,"i-1=",i-1,"rand_list=",rand_list)
    benchmarks.append((supermarq.bit_code.BitCode(i,i-1,rand_list),label))
for i in benchmarks:
    circuit=i[0].qiskit_circuit()
    print("--------------------------",i[1],"---------------------------")
    #circuit.draw(output="mpl")
    print(circuit.draw())
# Out:
# i= 3 i-1= 2 rand_list= [1, 1, 0]
# i= 4 i-1= 3 rand_list= [0, 0, 0, 1]
# i= 5 i-1= 4 rand_list= [1, 0, 1, 0, 0]
# i= 6 i-1= 5 rand_list= [0, 1, 1, 1, 1, 0]
# i= 7 i-1= 6 rand_list= [1, 0, 0, 0, 0, 0, 0]
# i= 8 i-1= 7 rand_list= [1, 0, 0, 0, 0, 0, 1, 0]
# -------------------------- bitcode3 ---------------------------
#               ┌───┐                                 ┌─┐
#          q_0: ┤ X ├──■─────────────────■────────────┤M├──────────────────────
#               └───┘┌─┴─┐┌───┐┌─┐     ┌─┴─┐     ┌───┐└╥┘┌─┐             ┌─┐
#          q_1: ─────┤ X ├┤ X ├┤M├─|0>─┤ X ├─────┤ X ├─╫─┤M├─|0>─────────┤M├───
#               ┌───┐└───┘└─┬─┘└╥┘     └───┘     └─┬─┘ ║ └╥┘     ┌─┐     └╥┘
#          q_2: ┤ X ├──■────■───╫─────────────■────■───╫──╫──────┤M├──────╫────
#               └───┘┌─┴─┐┌───┐ ║  ┌─┐      ┌─┴─┐┌───┐ ║  ║  ┌─┐ └╥┘      ║ ┌─┐
#          q_3: ─────┤ X ├┤ X ├─╫──┤M├──|0>─┤ X ├┤ X ├─╫──╫──┤M├──╫──|0>──╫─┤M├
#                    └───┘└─┬─┘ ║  └╥┘      └───┘└─┬─┘ ║  ║  └╥┘  ║  ┌─┐  ║ └╥┘
#          q_4: ────────────■───╫───╫──────────────■───╫──╫───╫───╫──┤M├──╫──╫─
#                               ║   ║                  ║  ║   ║   ║  └╥┘  ║  ║
#     m_mcm0: 2/════════════════╩═══╩══════════════════╬══╬═══╬═══╬═══╬═══╬══╬═
#                               0   1                  ║  ║   ║   ║   ║   ║  ║
#     m_mcm1: 2/═══════════════════════════════════════╬══╩═══╩═══╬═══╬═══╬══╬═
#                                                      ║  0   1   ║   ║   ║  ║
# m_meas_all: 5/═══════════════════════════════════════╩══════════╩═══╩═══╩══╩═
#                                                      0          2   4   1  3
# -------------------------- bitcode4 ---------------------------
#                                                                            »
#          q_0: ──■─────────────────■───────────────────────────■────────────»
#               ┌─┴─┐┌───┐┌─┐     ┌─┴─┐     ┌───┐     ┌─┐     ┌─┴─┐     ┌───┐»
#          q_1: ┤ X ├┤ X ├┤M├─|0>─┤ X ├─────┤ X ├─────┤M├─|0>─┤ X ├─────┤ X ├»
#               └───┘└─┬─┘└╥┘     └───┘     └─┬─┘     └╥┘     └───┘     └─┬─┘»
#          q_2: ──■────■───╫─────────────■────■────────╫─────────────■────■──»
#               ┌─┴─┐┌───┐ ║  ┌─┐      ┌─┴─┐     ┌───┐ ║  ┌─┐      ┌─┴─┐     »
#          q_3: ┤ X ├┤ X ├─╫──┤M├──|0>─┤ X ├─────┤ X ├─╫──┤M├──|0>─┤ X ├─────»
#               └───┘└─┬─┘ ║  └╥┘      └───┘     └─┬─┘ ║  └╥┘      └───┘     »
#          q_4: ──■────■───╫───╫──────────────■────■───╫───╫──────────────■──»
#               ┌─┴─┐┌───┐ ║   ║   ┌─┐      ┌─┴─┐┌───┐ ║   ║   ┌─┐      ┌─┴─┐»
#          q_5: ┤ X ├┤ X ├─╫───╫───┤M├──|0>─┤ X ├┤ X ├─╫───╫───┤M├──|0>─┤ X ├»
#               ├───┤└─┬─┘ ║   ║   └╥┘      └───┘└─┬─┘ ║   ║   └╥┘      └───┘»
#          q_6: ┤ X ├──■───╫───╫────╫──────────────■───╫───╫────╫────────────»
#               └───┘      ║   ║    ║                  ║   ║    ║            »
#     m_mcm0: 3/═══════════╩═══╩════╩══════════════════╬═══╬════╬════════════»
#                          0   1    2                  ║   ║    ║            »
#     m_mcm1: 3/═══════════════════════════════════════╩═══╩════╩════════════»
#                                                      0   1    2            »
#     m_mcm2: 3/═════════════════════════════════════════════════════════════»
#                                                                            »
# m_meas_all: 7/═════════════════════════════════════════════════════════════»
#                                                                            »
# «                   ┌─┐
# «         q_0: ─────┤M├─────────────────────────────────
# «                   └╥┘┌─┐                     ┌─┐
# «         q_1: ──────╫─┤M├─|0>─────────────────┤M├──────
# «                    ║ └╥┘          ┌─┐        └╥┘
# «         q_2: ──────╫──╫───────────┤M├─────────╫───────
# «              ┌───┐ ║  ║  ┌─┐      └╥┘         ║ ┌─┐
# «         q_3: ┤ X ├─╫──╫──┤M├──|0>──╫──────────╫─┤M├───
# «              └─┬─┘ ║  ║  └╥┘       ║ ┌─┐      ║ └╥┘
# «         q_4: ──■───╫──╫───╫────────╫─┤M├──────╫──╫────
# «              ┌───┐ ║  ║   ║   ┌─┐  ║ └╥┘      ║  ║ ┌─┐
# «         q_5: ┤ X ├─╫──╫───╫───┤M├──╫──╫──|0>──╫──╫─┤M├
# «              └─┬─┘ ║  ║   ║   └╥┘  ║  ║  ┌─┐  ║  ║ └╥┘
# «         q_6: ──■───╫──╫───╫────╫───╫──╫──┤M├──╫──╫──╫─
# «                    ║  ║   ║    ║   ║  ║  └╥┘  ║  ║  ║
# «    m_mcm0: 3/══════╬══╬═══╬════╬═══╬══╬═══╬═══╬══╬══╬═
# «                    ║  ║   ║    ║   ║  ║   ║   ║  ║  ║
# «    m_mcm1: 3/══════╬══╬═══╬════╬═══╬══╬═══╬═══╬══╬══╬═
# «                    ║  ║   ║    ║   ║  ║   ║   ║  ║  ║
# «    m_mcm2: 3/══════╬══╩═══╩════╩═══╬══╬═══╬═══╬══╬══╬═
# «                    ║  0   1    2   ║  ║   ║   ║  ║  ║
# «m_meas_all: 7/══════╩═══════════════╩══╩═══╩═══╩══╩══╩═
# «                    0               2  4   6   1  3  5
# -------------------------- bitcode5 ---------------------------
#               ┌───┐                                                           »
#          q_0: ┤ X ├──■─────────────────■──────────────────────────────■───────»
#               └───┘┌─┴─┐┌───┐┌─┐     ┌─┴─┐     ┌───┐        ┌─┐     ┌─┴─┐     »
#          q_1: ─────┤ X ├┤ X ├┤M├─|0>─┤ X ├─────┤ X ├────────┤M├─|0>─┤ X ├─────»
#                    └───┘└─┬─┘└╥┘     └───┘     └─┬─┘        └╥┘     └───┘     »
#          q_2: ──■─────────■───╫─────────────■────■───────────╫─────────────■──»
#               ┌─┴─┐     ┌───┐ ║  ┌─┐      ┌─┴─┐     ┌───┐    ║  ┌─┐      ┌─┴─┐»
#          q_3: ┤ X ├─────┤ X ├─╫──┤M├──|0>─┤ X ├─────┤ X ├────╫──┤M├──|0>─┤ X ├»
#               ├───┤     └─┬─┘ ║  └╥┘      └───┘     └─┬─┘    ║  └╥┘      └───┘»
#          q_4: ┤ X ├──■────■───╫───╫──────────────■────■──────╫───╫────────────»
#               └───┘┌─┴─┐┌───┐ ║   ║   ┌─┐      ┌─┴─┐┌───┐    ║   ║   ┌─┐      »
#          q_5: ─────┤ X ├┤ X ├─╫───╫───┤M├──|0>─┤ X ├┤ X ├────╫───╫───┤M├──|0>─»
#                    └───┘└─┬─┘ ║   ║   └╥┘      └───┘└─┬─┘    ║   ║   └╥┘      »
#          q_6: ──■─────────■───╫───╫────╫─────────■────■──────╫───╫────╫───────»
#               ┌─┴─┐┌───┐ ┌─┐  ║   ║    ║       ┌─┴─┐┌───┐┌─┐ ║   ║    ║       »
#          q_7: ┤ X ├┤ X ├─┤M├──╫───╫────╫───|0>─┤ X ├┤ X ├┤M├─╫───╫────╫───|0>─»
#               └───┘└─┬─┘ └╥┘  ║   ║    ║       └───┘└─┬─┘└╥┘ ║   ║    ║       »
#          q_8: ───────■────╫───╫───╫────╫──────────────■───╫──╫───╫────╫───────»
#                           ║   ║   ║    ║                  ║  ║   ║    ║       »
#     m_mcm0: 4/════════════╩═══╩═══╩════╩══════════════════╬══╬═══╬════╬═══════»
#                           3   0   1    2                  ║  ║   ║    ║       »
#     m_mcm1: 4/════════════════════════════════════════════╩══╩═══╩════╩═══════»
#                                                           3  0   1    2       »
#     m_mcm2: 4/════════════════════════════════════════════════════════════════»
#                                                                               »
#     m_mcm3: 4/════════════════════════════════════════════════════════════════»
#                                                                               »
# m_meas_all: 9/════════════════════════════════════════════════════════════════»
#                                                                               »
# «                                                          ┌─┐             »
# «         q_0: ───────────────────────■────────────────────┤M├─────────────»
# «              ┌───┐        ┌─┐     ┌─┴─┐     ┌───┐        └╥┘     ┌─┐     »
# «         q_1: ┤ X ├────────┤M├─|0>─┤ X ├─────┤ X ├─────────╫──────┤M├─|0>─»
# «              └─┬─┘        └╥┘     └───┘     └─┬─┘         ║      └╥┘     »
# «         q_2: ──■───────────╫─────────────■────■───────────╫───────╫──────»
# «                   ┌───┐    ║  ┌─┐      ┌─┴─┐     ┌───┐    ║       ║  ┌─┐ »
# «         q_3: ─────┤ X ├────╫──┤M├──|0>─┤ X ├─────┤ X ├────╫───────╫──┤M├─»
# «                   └─┬─┘    ║  └╥┘      └───┘     └─┬─┘    ║       ║  └╥┘ »
# «         q_4: ──■────■──────╫───╫──────────────■────■──────╫───────╫───╫──»
# «              ┌─┴─┐┌───┐    ║   ║   ┌─┐      ┌─┴─┐┌───┐    ║       ║   ║  »
# «         q_5: ┤ X ├┤ X ├────╫───╫───┤M├──|0>─┤ X ├┤ X ├────╫───────╫───╫──»
# «              └───┘└─┬─┘    ║   ║   └╥┘      └───┘└─┬─┘    ║       ║   ║  »
# «         q_6: ──■────■──────╫───╫────╫─────────■────■──────╫───────╫───╫──»
# «              ┌─┴─┐┌───┐┌─┐ ║   ║    ║       ┌─┴─┐┌───┐┌─┐ ║       ║   ║  »
# «         q_7: ┤ X ├┤ X ├┤M├─╫───╫────╫───|0>─┤ X ├┤ X ├┤M├─╫──|0>──╫───╫──»
# «              └───┘└─┬─┘└╥┘ ║   ║    ║       └───┘└─┬─┘└╥┘ ║  ┌─┐  ║   ║  »
# «         q_8: ───────■───╫──╫───╫────╫──────────────■───╫──╫──┤M├──╫───╫──»
# «                         ║  ║   ║    ║                  ║  ║  └╥┘  ║   ║  »
# «    m_mcm0: 4/═══════════╬══╬═══╬════╬══════════════════╬══╬═══╬═══╬═══╬══»
# «                         ║  ║   ║    ║                  ║  ║   ║   ║   ║  »
# «    m_mcm1: 4/═══════════╬══╬═══╬════╬══════════════════╬══╬═══╬═══╬═══╬══»
# «                         ║  ║   ║    ║                  ║  ║   ║   ║   ║  »
# «    m_mcm2: 4/═══════════╩══╩═══╩════╩══════════════════╬══╬═══╬═══╬═══╬══»
# «                         3  0   1    2                  ║  ║   ║   ║   ║  »
# «    m_mcm3: 4/══════════════════════════════════════════╩══╬═══╬═══╩═══╩══»
# «                                                        3  ║   ║   0   1  »
# «m_meas_all: 9/═════════════════════════════════════════════╩═══╩══════════»
# «                                                           0   8          »
# «
# «         q_0: ────────────────────────────
# «                                 ┌─┐
# «         q_1: ───────────────────┤M├──────
# «                   ┌─┐           └╥┘
# «         q_2: ─────┤M├────────────╫───────
# «                   └╥┘            ║ ┌─┐
# «         q_3: ─|0>──╫─────────────╫─┤M├───
# «                    ║ ┌─┐         ║ └╥┘
# «         q_4: ──────╫─┤M├─────────╫──╫────
# «               ┌─┐  ║ └╥┘         ║  ║ ┌─┐
# «         q_5: ─┤M├──╫──╫──|0>─────╫──╫─┤M├
# «               └╥┘  ║  ║  ┌─┐     ║  ║ └╥┘
# «         q_6: ──╫───╫──╫──┤M├─────╫──╫──╫─
# «                ║   ║  ║  └╥┘ ┌─┐ ║  ║  ║
# «         q_7: ──╫───╫──╫───╫──┤M├─╫──╫──╫─
# «                ║   ║  ║   ║  └╥┘ ║  ║  ║
# «         q_8: ──╫───╫──╫───╫───╫──╫──╫──╫─
# «                ║   ║  ║   ║   ║  ║  ║  ║
# «    m_mcm0: 4/══╬═══╬══╬═══╬═══╬══╬══╬══╬═
# «                ║   ║  ║   ║   ║  ║  ║  ║
# «    m_mcm1: 4/══╬═══╬══╬═══╬═══╬══╬══╬══╬═
# «                ║   ║  ║   ║   ║  ║  ║  ║
# «    m_mcm2: 4/══╬═══╬══╬═══╬═══╬══╬══╬══╬═
# «                ║   ║  ║   ║   ║  ║  ║  ║
# «    m_mcm3: 4/══╩═══╬══╬═══╬═══╬══╬══╬══╬═
# «                2   ║  ║   ║   ║  ║  ║  ║
# «m_meas_all: 9/══════╩══╩═══╩═══╩══╩══╩══╩═
# «                    2  4   6   7  1  3  5
# -------------------------- bitcode6 ---------------------------
#                                                                             »
#           q_0: ──■──────────────────────■───────────────────────────────────»
#                ┌─┴─┐     ┌───┐┌─┐     ┌─┴─┐     ┌───┐               ┌─┐     »
#           q_1: ┤ X ├─────┤ X ├┤M├─|0>─┤ X ├─────┤ X ├───────────────┤M├─|0>─»
#                ├───┤     └─┬─┘└╥┘     └───┘     └─┬─┘               └╥┘     »
#           q_2: ┤ X ├──■────■───╫─────────────■────■──────────────────╫──────»
#                └───┘┌─┴─┐┌───┐ ║  ┌─┐      ┌─┴─┐     ┌───┐           ║  ┌─┐ »
#           q_3: ─────┤ X ├┤ X ├─╫──┤M├──|0>─┤ X ├─────┤ X ├───────────╫──┤M├─»
#                ┌───┐└───┘└─┬─┘ ║  └╥┘      └───┘     └─┬─┘           ║  └╥┘ »
#           q_4: ┤ X ├──■────■───╫───╫──────────────■────■─────────────╫───╫──»
#                └───┘┌─┴─┐┌───┐ ║   ║   ┌─┐      ┌─┴─┐     ┌───┐      ║   ║  »
#           q_5: ─────┤ X ├┤ X ├─╫───╫───┤M├──|0>─┤ X ├─────┤ X ├──────╫───╫──»
#                ┌───┐└───┘└─┬─┘ ║   ║   └╥┘      └───┘     └─┬─┘      ║   ║  »
#           q_6: ┤ X ├──■────■───╫───╫────╫──────────────■────■────────╫───╫──»
#                └───┘┌─┴─┐┌───┐ ║   ║    ║   ┌─┐      ┌─┴─┐     ┌───┐ ║   ║  »
#           q_7: ─────┤ X ├┤ X ├─╫───╫────╫───┤M├──|0>─┤ X ├─────┤ X ├─╫───╫──»
#                ┌───┐└───┘└─┬─┘ ║   ║    ║   └╥┘      └───┘     └─┬─┘ ║   ║  »
#           q_8: ┤ X ├──■────■───╫───╫────╫────╫──────────────■────■───╫───╫──»
#                └───┘┌─┴─┐┌───┐ ║   ║    ║    ║   ┌─┐      ┌─┴─┐┌───┐ ║   ║  »
#           q_9: ─────┤ X ├┤ X ├─╫───╫────╫────╫───┤M├──|0>─┤ X ├┤ X ├─╫───╫──»
#                     └───┘└─┬─┘ ║   ║    ║    ║   └╥┘      └───┘└─┬─┘ ║   ║  »
#          q_10: ────────────■───╫───╫────╫────╫────╫──────────────■───╫───╫──»
#                                ║   ║    ║    ║    ║                  ║   ║  »
#      m_mcm0: 5/════════════════╩═══╩════╩════╩════╩══════════════════╬═══╬══»
#                                0   1    2    3    4                  ║   ║  »
#      m_mcm1: 5/══════════════════════════════════════════════════════╩═══╩══»
#                                                                      0   1  »
#      m_mcm2: 5/═════════════════════════════════════════════════════════════»
#                                                                             »
#      m_mcm3: 5/═════════════════════════════════════════════════════════════»
#                                                                             »
#      m_mcm4: 5/═════════════════════════════════════════════════════════════»
#                                                                             »
# m_meas_all: 11/═════════════════════════════════════════════════════════════»
#                                                                             »
# «                                                                              »
# «          q_0: ──■─────────────────────────────────────■──────────────────────»
# «               ┌─┴─┐     ┌───┐               ┌─┐     ┌─┴─┐     ┌───┐          »
# «          q_1: ┤ X ├─────┤ X ├───────────────┤M├─|0>─┤ X ├─────┤ X ├──────────»
# «               └───┘     └─┬─┘               └╥┘     └───┘     └─┬─┘          »
# «          q_2: ───────■────■──────────────────╫─────────────■────■────────────»
# «                    ┌─┴─┐     ┌───┐           ║  ┌─┐      ┌─┴─┐     ┌───┐     »
# «          q_3: ─|0>─┤ X ├─────┤ X ├───────────╫──┤M├──|0>─┤ X ├─────┤ X ├─────»
# «                    └───┘     └─┬─┘           ║  └╥┘      └───┘     └─┬─┘     »
# «          q_4: ────────────■────■─────────────╫───╫──────────────■────■───────»
# «                ┌─┐      ┌─┴─┐     ┌───┐      ║   ║   ┌─┐      ┌─┴─┐     ┌───┐»
# «          q_5: ─┤M├──|0>─┤ X ├─────┤ X ├──────╫───╫───┤M├──|0>─┤ X ├─────┤ X ├»
# «                └╥┘      └───┘     └─┬─┘      ║   ║   └╥┘      └───┘     └─┬─┘»
# «          q_6: ──╫──────────────■────■────────╫───╫────╫──────────────■────■──»
# «                 ║   ┌─┐      ┌─┴─┐     ┌───┐ ║   ║    ║   ┌─┐      ┌─┴─┐     »
# «          q_7: ──╫───┤M├──|0>─┤ X ├─────┤ X ├─╫───╫────╫───┤M├──|0>─┤ X ├─────»
# «                 ║   └╥┘      └───┘     └─┬─┘ ║   ║    ║   └╥┘      └───┘     »
# «          q_8: ──╫────╫──────────────■────■───╫───╫────╫────╫──────────────■──»
# «                 ║    ║   ┌─┐      ┌─┴─┐┌───┐ ║   ║    ║    ║   ┌─┐      ┌─┴─┐»
# «          q_9: ──╫────╫───┤M├──|0>─┤ X ├┤ X ├─╫───╫────╫────╫───┤M├──|0>─┤ X ├»
# «                 ║    ║   └╥┘      └───┘└─┬─┘ ║   ║    ║    ║   └╥┘      └───┘»
# «         q_10: ──╫────╫────╫──────────────■───╫───╫────╫────╫────╫────────────»
# «                 ║    ║    ║                  ║   ║    ║    ║    ║            »
# «     m_mcm0: 5/══╬════╬════╬══════════════════╬═══╬════╬════╬════╬════════════»
# «                 ║    ║    ║                  ║   ║    ║    ║    ║            »
# «     m_mcm1: 5/══╩════╩════╩══════════════════╬═══╬════╬════╬════╬════════════»
# «                 2    3    4                  ║   ║    ║    ║    ║            »
# «     m_mcm2: 5/═══════════════════════════════╩═══╩════╩════╩════╩════════════»
# «                                              0   1    2    3    4            »
# «     m_mcm3: 5/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «     m_mcm4: 5/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «m_meas_all: 11/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «                                                          ┌─┐             »
# «          q_0: ───────────────■───────────────────────────┤M├─────────────»
# «                    ┌─┐     ┌─┴─┐     ┌───┐               └╥┘┌─┐          »
# «          q_1: ─────┤M├─|0>─┤ X ├─────┤ X ├────────────────╫─┤M├─|0>──────»
# «                    └╥┘     └───┘     └─┬─┘                ║ └╥┘          »
# «          q_2: ──────╫─────────────■────■──────────────────╫──╫───────────»
# «                     ║  ┌─┐      ┌─┴─┐     ┌───┐           ║  ║  ┌─┐      »
# «          q_3: ──────╫──┤M├──|0>─┤ X ├─────┤ X ├───────────╫──╫──┤M├──|0>─»
# «                     ║  └╥┘      └───┘     └─┬─┘           ║  ║  └╥┘      »
# «          q_4: ──────╫───╫──────────────■────■─────────────╫──╫───╫───────»
# «                     ║   ║   ┌─┐      ┌─┴─┐     ┌───┐      ║  ║   ║   ┌─┐ »
# «          q_5: ──────╫───╫───┤M├──|0>─┤ X ├─────┤ X ├──────╫──╫───╫───┤M├─»
# «                     ║   ║   └╥┘      └───┘     └─┬─┘      ║  ║   ║   └╥┘ »
# «          q_6: ──────╫───╫────╫──────────────■────■────────╫──╫───╫────╫──»
# «               ┌───┐ ║   ║    ║   ┌─┐      ┌─┴─┐     ┌───┐ ║  ║   ║    ║  »
# «          q_7: ┤ X ├─╫───╫────╫───┤M├──|0>─┤ X ├─────┤ X ├─╫──╫───╫────╫──»
# «               └─┬─┘ ║   ║    ║   └╥┘      └───┘     └─┬─┘ ║  ║   ║    ║  »
# «          q_8: ──■───╫───╫────╫────╫──────────────■────■───╫──╫───╫────╫──»
# «               ┌───┐ ║   ║    ║    ║   ┌─┐      ┌─┴─┐┌───┐ ║  ║   ║    ║  »
# «          q_9: ┤ X ├─╫───╫────╫────╫───┤M├──|0>─┤ X ├┤ X ├─╫──╫───╫────╫──»
# «               └─┬─┘ ║   ║    ║    ║   └╥┘      └───┘└─┬─┘ ║  ║   ║    ║  »
# «         q_10: ──■───╫───╫────╫────╫────╫──────────────■───╫──╫───╫────╫──»
# «                     ║   ║    ║    ║    ║                  ║  ║   ║    ║  »
# «     m_mcm0: 5/══════╬═══╬════╬════╬════╬══════════════════╬══╬═══╬════╬══»
# «                     ║   ║    ║    ║    ║                  ║  ║   ║    ║  »
# «     m_mcm1: 5/══════╬═══╬════╬════╬════╬══════════════════╬══╬═══╬════╬══»
# «                     ║   ║    ║    ║    ║                  ║  ║   ║    ║  »
# «     m_mcm2: 5/══════╬═══╬════╬════╬════╬══════════════════╬══╬═══╬════╬══»
# «                     ║   ║    ║    ║    ║                  ║  ║   ║    ║  »
# «     m_mcm3: 5/══════╩═══╩════╩════╩════╩══════════════════╬══╬═══╬════╬══»
# «                     0   1    2    3    4                  ║  ║   ║    ║  »
# «     m_mcm4: 5/════════════════════════════════════════════╬══╩═══╩════╩══»
# «                                                           ║  0   1    2  »
# «m_meas_all: 11/════════════════════════════════════════════╩══════════════»
# «                                                           0              »
# «
# «          q_0: ──────────────────────────────────────────
# «                                          ┌─┐
# «          q_1: ───────────────────────────┤M├────────────
# «                         ┌─┐              └╥┘
# «          q_2: ──────────┤M├───────────────╫─────────────
# «                         └╥┘               ║ ┌─┐
# «          q_3: ───────────╫────────────────╫─┤M├─────────
# «                          ║ ┌─┐            ║ └╥┘
# «          q_4: ───────────╫─┤M├────────────╫──╫──────────
# «                          ║ └╥┘            ║  ║ ┌─┐
# «          q_5: ─|0>───────╫──╫─────────────╫──╫─┤M├──────
# «                          ║  ║ ┌─┐         ║  ║ └╥┘
# «          q_6: ───────────╫──╫─┤M├─────────╫──╫──╫───────
# «                ┌─┐       ║  ║ └╥┘         ║  ║  ║ ┌─┐
# «          q_7: ─┤M├──|0>──╫──╫──╫──────────╫──╫──╫─┤M├───
# «                └╥┘       ║  ║  ║ ┌─┐      ║  ║  ║ └╥┘
# «          q_8: ──╫────────╫──╫──╫─┤M├──────╫──╫──╫──╫────
# «                 ║   ┌─┐  ║  ║  ║ └╥┘      ║  ║  ║  ║ ┌─┐
# «          q_9: ──╫───┤M├──╫──╫──╫──╫──|0>──╫──╫──╫──╫─┤M├
# «                 ║   └╥┘  ║  ║  ║  ║  ┌─┐  ║  ║  ║  ║ └╥┘
# «         q_10: ──╫────╫───╫──╫──╫──╫──┤M├──╫──╫──╫──╫──╫─
# «                 ║    ║   ║  ║  ║  ║  └╥┘  ║  ║  ║  ║  ║
# «     m_mcm0: 5/══╬════╬═══╬══╬══╬══╬═══╬═══╬══╬══╬══╬══╬═
# «                 ║    ║   ║  ║  ║  ║   ║   ║  ║  ║  ║  ║
# «     m_mcm1: 5/══╬════╬═══╬══╬══╬══╬═══╬═══╬══╬══╬══╬══╬═
# «                 ║    ║   ║  ║  ║  ║   ║   ║  ║  ║  ║  ║
# «     m_mcm2: 5/══╬════╬═══╬══╬══╬══╬═══╬═══╬══╬══╬══╬══╬═
# «                 ║    ║   ║  ║  ║  ║   ║   ║  ║  ║  ║  ║
# «     m_mcm3: 5/══╬════╬═══╬══╬══╬══╬═══╬═══╬══╬══╬══╬══╬═
# «                 ║    ║   ║  ║  ║  ║   ║   ║  ║  ║  ║  ║
# «     m_mcm4: 5/══╩════╩═══╬══╬══╬══╬═══╬═══╬══╬══╬══╬══╬═
# «                 3    4   ║  ║  ║  ║   ║   ║  ║  ║  ║  ║
# «m_meas_all: 11/═══════════╩══╩══╩══╩═══╩═══╩══╩══╩══╩══╩═
# «                          2  4  6  8   10  1  3  5  7  9
# -------------------------- bitcode7 ---------------------------
#                ┌───┐                                                        »
#           q_0: ┤ X ├──■─────────────────────────────────────■───────────────»
#                └───┘┌─┴─┐┌───┐                    ┌─┐     ┌─┴─┐┌───┐        »
#           q_1: ─────┤ X ├┤ X ├────────────────────┤M├─|0>─┤ X ├┤ X ├────────»
#                     └───┘└─┬─┘                    └╥┘     └───┘└─┬─┘        »
#           q_2: ──■─────────■─────────■─────────────╫─────────────■──────────»
#                ┌─┴─┐┌───┐ ┌─┐      ┌─┴─┐     ┌───┐ ║                ┌─┐     »
#           q_3: ┤ X ├┤ X ├─┤M├──|0>─┤ X ├─────┤ X ├─╫────────────────┤M├─|0>─»
#                └───┘└─┬─┘ └╥┘      └───┘     └─┬─┘ ║                └╥┘     »
#           q_4: ──■────■────╫──────────────■────■───╫─────────────────╫──────»
#                ┌─┴─┐┌───┐  ║   ┌─┐      ┌─┴─┐      ║ ┌───┐           ║  ┌─┐ »
#           q_5: ┤ X ├┤ X ├──╫───┤M├──|0>─┤ X ├──────╫─┤ X ├───────────╫──┤M├─»
#                └───┘└─┬─┘  ║   └╥┘      └───┘      ║ └─┬─┘           ║  └╥┘ »
#           q_6: ──■────■────╫────╫──────────────■───╫───■─────────────╫───╫──»
#                ┌─┴─┐┌───┐  ║    ║   ┌─┐      ┌─┴─┐ ║      ┌───┐      ║   ║  »
#           q_7: ┤ X ├┤ X ├──╫────╫───┤M├──|0>─┤ X ├─╫──────┤ X ├──────╫───╫──»
#                └───┘└─┬─┘  ║    ║   └╥┘      └───┘ ║      └─┬─┘      ║   ║  »
#           q_8: ──■────■────╫────╫────╫─────────────╫───■────■────────╫───╫──»
#                ┌─┴─┐┌───┐  ║    ║    ║   ┌─┐       ║ ┌─┴─┐     ┌───┐ ║   ║  »
#           q_9: ┤ X ├┤ X ├──╫────╫────╫───┤M├──|0>──╫─┤ X ├─────┤ X ├─╫───╫──»
#                └───┘└─┬─┘  ║    ║    ║   └╥┘       ║ └───┘     └─┬─┘ ║   ║  »
#          q_10: ──■────■────╫────╫────╫────╫────────╫────────■────■───╫───╫──»
#                ┌─┴─┐┌───┐  ║    ║    ║    ║   ┌─┐  ║      ┌─┴─┐┌───┐ ║   ║  »
#          q_11: ┤ X ├┤ X ├──╫────╫────╫────╫───┤M├──╫──|0>─┤ X ├┤ X ├─╫───╫──»
#                └───┘└─┬─┘  ║    ║    ║    ║   └╥┘  ║      └───┘└─┬─┘ ║   ║  »
#          q_12: ───────■────╫────╫────╫────╫────╫───╫─────────────■───╫───╫──»
#                            ║    ║    ║    ║    ║   ║                 ║   ║  »
#      m_mcm0: 6/════════════╩════╩════╩════╩════╩═══╩═════════════════╬═══╬══»
#                            1    2    3    4    5   0                 ║   ║  »
#      m_mcm1: 6/══════════════════════════════════════════════════════╩═══╩══»
#                                                                      1   2  »
#      m_mcm2: 6/═════════════════════════════════════════════════════════════»
#                                                                             »
#      m_mcm3: 6/═════════════════════════════════════════════════════════════»
#                                                                             »
#      m_mcm4: 6/═════════════════════════════════════════════════════════════»
#                                                                             »
#      m_mcm5: 6/═════════════════════════════════════════════════════════════»
#                                                                             »
# m_meas_all: 13/═════════════════════════════════════════════════════════════»
#                                                                             »
# «                                                                          »
# «          q_0: ─────────────────────────■─────────────────────────────────»
# «                              ┌─┐     ┌─┴─┐┌───┐                       ┌─┐»
# «          q_1: ───────────────┤M├─|0>─┤ X ├┤ X ├───────────────────────┤M├»
# «                              └╥┘     └───┘└─┬─┘                       └╥┘»
# «          q_2: ──■─────────────╫─────────────■────────────■─────────────╫─»
# «               ┌─┴─┐     ┌───┐ ║                ┌─┐     ┌─┴─┐     ┌───┐ ║ »
# «          q_3: ┤ X ├─────┤ X ├─╫────────────────┤M├─|0>─┤ X ├─────┤ X ├─╫─»
# «               └───┘     └─┬─┘ ║                └╥┘     └───┘     └─┬─┘ ║ »
# «          q_4: ───────■────■───╫─────────────────╫─────────────■────■───╫─»
# «                    ┌─┴─┐      ║ ┌───┐           ║  ┌─┐      ┌─┴─┐      ║ »
# «          q_5: ─|0>─┤ X ├──────╫─┤ X ├───────────╫──┤M├──|0>─┤ X ├──────╫─»
# «                    └───┘      ║ └─┬─┘           ║  └╥┘      └───┘      ║ »
# «          q_6: ────────────■───╫───■─────────────╫───╫──────────────■───╫─»
# «                ┌─┐      ┌─┴─┐ ║      ┌───┐      ║   ║   ┌─┐      ┌─┴─┐ ║ »
# «          q_7: ─┤M├──|0>─┤ X ├─╫──────┤ X ├──────╫───╫───┤M├──|0>─┤ X ├─╫─»
# «                └╥┘      └───┘ ║      └─┬─┘      ║   ║   └╥┘      └───┘ ║ »
# «          q_8: ──╫─────────────╫───■────■────────╫───╫────╫─────────────╫─»
# «                 ║   ┌─┐       ║ ┌─┴─┐     ┌───┐ ║   ║    ║   ┌─┐       ║ »
# «          q_9: ──╫───┤M├──|0>──╫─┤ X ├─────┤ X ├─╫───╫────╫───┤M├──|0>──╫─»
# «                 ║   └╥┘       ║ └───┘     └─┬─┘ ║   ║    ║   └╥┘       ║ »
# «         q_10: ──╫────╫────────╫────────■────■───╫───╫────╫────╫────────╫─»
# «                 ║    ║   ┌─┐  ║      ┌─┴─┐┌───┐ ║   ║    ║    ║   ┌─┐  ║ »
# «         q_11: ──╫────╫───┤M├──╫──|0>─┤ X ├┤ X ├─╫───╫────╫────╫───┤M├──╫─»
# «                 ║    ║   └╥┘  ║      └───┘└─┬─┘ ║   ║    ║    ║   └╥┘  ║ »
# «         q_12: ──╫────╫────╫───╫─────────────■───╫───╫────╫────╫────╫───╫─»
# «                 ║    ║    ║   ║                 ║   ║    ║    ║    ║   ║ »
# «     m_mcm0: 6/══╬════╬════╬═══╬═════════════════╬═══╬════╬════╬════╬═══╬═»
# «                 ║    ║    ║   ║                 ║   ║    ║    ║    ║   ║ »
# «     m_mcm1: 6/══╩════╩════╩═══╩═════════════════╬═══╬════╬════╬════╬═══╬═»
# «                 3    4    5   0                 ║   ║    ║    ║    ║   ║ »
# «     m_mcm2: 6/══════════════════════════════════╩═══╩════╩════╩════╩═══╩═»
# «                                                 1   2    3    4    5   0 »
# «     m_mcm3: 6/═══════════════════════════════════════════════════════════»
# «                                                                          »
# «     m_mcm4: 6/═══════════════════════════════════════════════════════════»
# «                                                                          »
# «     m_mcm5: 6/═══════════════════════════════════════════════════════════»
# «                                                                          »
# «m_meas_all: 13/═══════════════════════════════════════════════════════════»
# «                                                                          »
# «                                                                          »
# «          q_0: ───────■────────────────────────────────────────■──────────»
# «                    ┌─┴─┐┌───┐                       ┌─┐     ┌─┴─┐┌───┐   »
# «          q_1: ─|0>─┤ X ├┤ X ├───────────────────────┤M├─|0>─┤ X ├┤ X ├───»
# «                    └───┘└─┬─┘                       └╥┘     └───┘└─┬─┘   »
# «          q_2: ────────────■────────────■─────────────╫─────────────■─────»
# «                              ┌─┐     ┌─┴─┐     ┌───┐ ║                ┌─┐»
# «          q_3: ───────────────┤M├─|0>─┤ X ├─────┤ X ├─╫────────────────┤M├»
# «                              └╥┘     └───┘     └─┬─┘ ║                └╥┘»
# «          q_4: ────────────────╫─────────────■────■───╫─────────────────╫─»
# «               ┌───┐           ║  ┌─┐      ┌─┴─┐      ║ ┌───┐           ║ »
# «          q_5: ┤ X ├───────────╫──┤M├──|0>─┤ X ├──────╫─┤ X ├───────────╫─»
# «               └─┬─┘           ║  └╥┘      └───┘      ║ └─┬─┘           ║ »
# «          q_6: ──■─────────────╫───╫──────────────■───╫───■─────────────╫─»
# «                    ┌───┐      ║   ║   ┌─┐      ┌─┴─┐ ║      ┌───┐      ║ »
# «          q_7: ─────┤ X ├──────╫───╫───┤M├──|0>─┤ X ├─╫──────┤ X ├──────╫─»
# «                    └─┬─┘      ║   ║   └╥┘      └───┘ ║      └─┬─┘      ║ »
# «          q_8: ──■────■────────╫───╫────╫─────────────╫───■────■────────╫─»
# «               ┌─┴─┐     ┌───┐ ║   ║    ║   ┌─┐       ║ ┌─┴─┐     ┌───┐ ║ »
# «          q_9: ┤ X ├─────┤ X ├─╫───╫────╫───┤M├──|0>──╫─┤ X ├─────┤ X ├─╫─»
# «               └───┘     └─┬─┘ ║   ║    ║   └╥┘       ║ └───┘     └─┬─┘ ║ »
# «         q_10: ───────■────■───╫───╫────╫────╫────────╫────────■────■───╫─»
# «                    ┌─┴─┐┌───┐ ║   ║    ║    ║   ┌─┐  ║      ┌─┴─┐┌───┐ ║ »
# «         q_11: ─|0>─┤ X ├┤ X ├─╫───╫────╫────╫───┤M├──╫──|0>─┤ X ├┤ X ├─╫─»
# «                    └───┘└─┬─┘ ║   ║    ║    ║   └╥┘  ║      └───┘└─┬─┘ ║ »
# «         q_12: ────────────■───╫───╫────╫────╫────╫───╫─────────────■───╫─»
# «                               ║   ║    ║    ║    ║   ║                 ║ »
# «     m_mcm0: 6/════════════════╬═══╬════╬════╬════╬═══╬═════════════════╬═»
# «                               ║   ║    ║    ║    ║   ║                 ║ »
# «     m_mcm1: 6/════════════════╬═══╬════╬════╬════╬═══╬═════════════════╬═»
# «                               ║   ║    ║    ║    ║   ║                 ║ »
# «     m_mcm2: 6/════════════════╬═══╬════╬════╬════╬═══╬═════════════════╬═»
# «                               ║   ║    ║    ║    ║   ║                 ║ »
# «     m_mcm3: 6/════════════════╩═══╩════╩════╩════╩═══╩═════════════════╬═»
# «                               1   2    3    4    5   0                 ║ »
# «     m_mcm4: 6/═════════════════════════════════════════════════════════╩═»
# «                                                                        1 »
# «     m_mcm5: 6/═══════════════════════════════════════════════════════════»
# «                                                                          »
# «m_meas_all: 13/═══════════════════════════════════════════════════════════»
# «                                                                          »
# «                                                                            »
# «          q_0: ──────────────────────────────■──────────────────────────────»
# «                                   ┌─┐     ┌─┴─┐┌───┐                       »
# «          q_1: ────────────────────┤M├─|0>─┤ X ├┤ X ├───────────────────────»
# «                                   └╥┘     └───┘└─┬─┘                       »
# «          q_2: ───────■─────────────╫─────────────■─────────────────────────»
# «                    ┌─┴─┐     ┌───┐ ║                ┌─┐                    »
# «          q_3: ─|0>─┤ X ├─────┤ X ├─╫────────────────┤M├─|0>────────────────»
# «                    └───┘     └─┬─┘ ║                └╥┘                    »
# «          q_4: ────────────■────■───╫─────────────────╫─────────────────────»
# «                ┌─┐      ┌─┴─┐      ║ ┌───┐           ║  ┌─┐                »
# «          q_5: ─┤M├──|0>─┤ X ├──────╫─┤ X ├───────────╫──┤M├──|0>───────────»
# «                └╥┘      └───┘      ║ └─┬─┘           ║  └╥┘                »
# «          q_6: ──╫──────────────■───╫───■─────────────╫───╫─────────────────»
# «                 ║   ┌─┐      ┌─┴─┐ ║      ┌───┐      ║   ║   ┌─┐           »
# «          q_7: ──╫───┤M├──|0>─┤ X ├─╫──────┤ X ├──────╫───╫───┤M├──|0>──────»
# «                 ║   └╥┘      └───┘ ║      └─┬─┘      ║   ║   └╥┘           »
# «          q_8: ──╫────╫─────────────╫───■────■────────╫───╫────╫────────────»
# «                 ║    ║   ┌─┐       ║ ┌─┴─┐     ┌───┐ ║   ║    ║   ┌─┐      »
# «          q_9: ──╫────╫───┤M├──|0>──╫─┤ X ├─────┤ X ├─╫───╫────╫───┤M├──|0>─»
# «                 ║    ║   └╥┘       ║ └───┘     └─┬─┘ ║   ║    ║   └╥┘      »
# «         q_10: ──╫────╫────╫────────╫────────■────■───╫───╫────╫────╫───────»
# «                 ║    ║    ║   ┌─┐  ║      ┌─┴─┐┌───┐ ║   ║    ║    ║   ┌─┐ »
# «         q_11: ──╫────╫────╫───┤M├──╫──|0>─┤ X ├┤ X ├─╫───╫────╫────╫───┤M├─»
# «                 ║    ║    ║   └╥┘  ║      └───┘└─┬─┘ ║   ║    ║    ║   └╥┘ »
# «         q_12: ──╫────╫────╫────╫───╫─────────────■───╫───╫────╫────╫────╫──»
# «                 ║    ║    ║    ║   ║                 ║   ║    ║    ║    ║  »
# «     m_mcm0: 6/══╬════╬════╬════╬═══╬═════════════════╬═══╬════╬════╬════╬══»
# «                 ║    ║    ║    ║   ║                 ║   ║    ║    ║    ║  »
# «     m_mcm1: 6/══╬════╬════╬════╬═══╬═════════════════╬═══╬════╬════╬════╬══»
# «                 ║    ║    ║    ║   ║                 ║   ║    ║    ║    ║  »
# «     m_mcm2: 6/══╬════╬════╬════╬═══╬═════════════════╬═══╬════╬════╬════╬══»
# «                 ║    ║    ║    ║   ║                 ║   ║    ║    ║    ║  »
# «     m_mcm3: 6/══╬════╬════╬════╬═══╬═════════════════╬═══╬════╬════╬════╬══»
# «                 ║    ║    ║    ║   ║                 ║   ║    ║    ║    ║  »
# «     m_mcm4: 6/══╩════╩════╩════╩═══╩═════════════════╬═══╬════╬════╬════╬══»
# «                 2    3    4    5   0                 ║   ║    ║    ║    ║  »
# «     m_mcm5: 6/═══════════════════════════════════════╩═══╩════╩════╩════╩══»
# «                                                      1   2    3    4    5  »
# «m_meas_all: 13/═════════════════════════════════════════════════════════════»
# «                                                                            »
# «               ┌─┐
# «          q_0: ┤M├───────────────────────────────────────────
# «               └╥┘                 ┌─┐                    ┌─┐
# «          q_1: ─╫──────────────────┤M├─|0>────────────────┤M├
# «                ║                  └╥┘ ┌─┐                └╥┘
# «          q_2: ─╫───────────────────╫──┤M├─────────────────╫─
# «                ║                   ║  └╥┘ ┌─┐             ║
# «          q_3: ─╫───────────────────╫───╫──┤M├─────────────╫─
# «                ║ ┌─┐               ║   ║  └╥┘             ║
# «          q_4: ─╫─┤M├───────────────╫───╫───╫──────────────╫─
# «                ║ └╥┘               ║   ║   ║ ┌─┐          ║
# «          q_5: ─╫──╫────────────────╫───╫───╫─┤M├──────────╫─
# «                ║  ║ ┌─┐            ║   ║   ║ └╥┘          ║
# «          q_6: ─╫──╫─┤M├────────────╫───╫───╫──╫───────────╫─
# «                ║  ║ └╥┘            ║   ║   ║  ║ ┌─┐       ║
# «          q_7: ─╫──╫──╫─────────────╫───╫───╫──╫─┤M├───────╫─
# «                ║  ║  ║ ┌─┐         ║   ║   ║  ║ └╥┘       ║
# «          q_8: ─╫──╫──╫─┤M├─────────╫───╫───╫──╫──╫────────╫─
# «                ║  ║  ║ └╥┘         ║   ║   ║  ║  ║ ┌─┐    ║
# «          q_9: ─╫──╫──╫──╫──────────╫───╫───╫──╫──╫─┤M├────╫─
# «                ║  ║  ║  ║ ┌─┐      ║   ║   ║  ║  ║ └╥┘    ║
# «         q_10: ─╫──╫──╫──╫─┤M├──────╫───╫───╫──╫──╫──╫─────╫─
# «                ║  ║  ║  ║ └╥┘      ║   ║   ║  ║  ║  ║ ┌─┐ ║
# «         q_11: ─╫──╫──╫──╫──╫──|0>──╫───╫───╫──╫──╫──╫─┤M├─╫─
# «                ║  ║  ║  ║  ║  ┌─┐  ║   ║   ║  ║  ║  ║ └╥┘ ║
# «         q_12: ─╫──╫──╫──╫──╫──┤M├──╫───╫───╫──╫──╫──╫──╫──╫─
# «                ║  ║  ║  ║  ║  └╥┘  ║   ║   ║  ║  ║  ║  ║  ║
# «     m_mcm0: 6/═╬══╬══╬══╬══╬═══╬═══╬═══╬═══╬══╬══╬══╬══╬══╬═
# «                ║  ║  ║  ║  ║   ║   ║   ║   ║  ║  ║  ║  ║  ║
# «     m_mcm1: 6/═╬══╬══╬══╬══╬═══╬═══╬═══╬═══╬══╬══╬══╬══╬══╬═
# «                ║  ║  ║  ║  ║   ║   ║   ║   ║  ║  ║  ║  ║  ║
# «     m_mcm2: 6/═╬══╬══╬══╬══╬═══╬═══╬═══╬═══╬══╬══╬══╬══╬══╬═
# «                ║  ║  ║  ║  ║   ║   ║   ║   ║  ║  ║  ║  ║  ║
# «     m_mcm3: 6/═╬══╬══╬══╬══╬═══╬═══╬═══╬═══╬══╬══╬══╬══╬══╬═
# «                ║  ║  ║  ║  ║   ║   ║   ║   ║  ║  ║  ║  ║  ║
# «     m_mcm4: 6/═╬══╬══╬══╬══╬═══╬═══╬═══╬═══╬══╬══╬══╬══╬══╬═
# «                ║  ║  ║  ║  ║   ║   ║   ║   ║  ║  ║  ║  ║  ║
# «     m_mcm5: 6/═╬══╬══╬══╬══╬═══╬═══╩═══╬═══╬══╬══╬══╬══╬══╬═
# «                ║  ║  ║  ║  ║   ║   0   ║   ║  ║  ║  ║  ║  ║
# «m_meas_all: 13/═╩══╩══╩══╩══╩═══╩═══════╩═══╩══╩══╩══╩══╩══╩═
# «                0  4  6  8  10  12      2   3  5  7  9  11 1
# -------------------------- bitcode8 ---------------------------
#                ┌───┐                                                           »
#           q_0: ┤ X ├──■───────────────────────────────────■────────────────────»
#                └───┘┌─┴─┐┌───┐                  ┌─┐     ┌─┴─┐┌───┐             »
#           q_1: ─────┤ X ├┤ X ├──────────────────┤M├─|0>─┤ X ├┤ X ├─────────────»
#                     └───┘└─┬─┘                  └╥┘     └───┘└─┬─┘             »
#           q_2: ──■─────────■────────────■────────╫─────────────■───────────────»
#                ┌─┴─┐┌───┐     ┌─┐     ┌─┴─┐      ║ ┌───┐                    ┌─┐»
#           q_3: ┤ X ├┤ X ├─────┤M├─|0>─┤ X ├──────╫─┤ X ├────────────────────┤M├»
#                └───┘└─┬─┘     └╥┘     └───┘      ║ └─┬─┘                    └╥┘»
#           q_4: ──■────■────────╫─────────────■───╫───■───────────────────────╫─»
#                ┌─┴─┐┌───┐      ║  ┌─┐      ┌─┴─┐ ║      ┌───┐                ║ »
#           q_5: ┤ X ├┤ X ├──────╫──┤M├──|0>─┤ X ├─╫──────┤ X ├────────────────╫─»
#                └───┘└─┬─┘      ║  └╥┘      └───┘ ║      └─┬─┘                ║ »
#           q_6: ──■────■────────╫───╫─────────────╫───■────■──────────────────╫─»
#                ┌─┴─┐┌───┐      ║   ║   ┌─┐       ║ ┌─┴─┐     ┌───┐           ║ »
#           q_7: ┤ X ├┤ X ├──────╫───╫───┤M├──|0>──╫─┤ X ├─────┤ X ├───────────╫─»
#                └───┘└─┬─┘      ║   ║   └╥┘       ║ └───┘     └─┬─┘           ║ »
#           q_8: ──■────■────────╫───╫────╫────────╫────────■────■─────────────╫─»
#                ┌─┴─┐┌───┐      ║   ║    ║   ┌─┐  ║      ┌─┴─┐     ┌───┐      ║ »
#           q_9: ┤ X ├┤ X ├──────╫───╫────╫───┤M├──╫──|0>─┤ X ├─────┤ X ├──────╫─»
#                └───┘└─┬─┘      ║   ║    ║   └╥┘  ║      └───┘     └─┬─┘      ║ »
#          q_10: ──■────■────────╫───╫────╫────╫───╫─────────────■────■────────╫─»
#                ┌─┴─┐     ┌───┐ ║   ║    ║    ║   ║  ┌─┐      ┌─┴─┐     ┌───┐ ║ »
#          q_11: ┤ X ├─────┤ X ├─╫───╫────╫────╫───╫──┤M├──|0>─┤ X ├─────┤ X ├─╫─»
#                ├───┤     └─┬─┘ ║   ║    ║    ║   ║  └╥┘      └───┘     └─┬─┘ ║ »
#          q_12: ┤ X ├──■────■───╫───╫────╫────╫───╫───╫──────────────■────■───╫─»
#                └───┘┌─┴─┐┌───┐ ║   ║    ║    ║   ║   ║   ┌─┐      ┌─┴─┐┌───┐ ║ »
#          q_13: ─────┤ X ├┤ X ├─╫───╫────╫────╫───╫───╫───┤M├──|0>─┤ X ├┤ X ├─╫─»
#                     └───┘└─┬─┘ ║   ║    ║    ║   ║   ║   └╥┘      └───┘└─┬─┘ ║ »
#          q_14: ────────────■───╫───╫────╫────╫───╫───╫────╫──────────────■───╫─»
#                                ║   ║    ║    ║   ║   ║    ║                  ║ »
#      m_mcm0: 7/════════════════╩═══╩════╩════╩═══╩═══╩════╩══════════════════╬═»
#                                1   2    3    4   0   5    6                  ║ »
#      m_mcm1: 7/══════════════════════════════════════════════════════════════╩═»
#                                                                              1 »
#      m_mcm2: 7/════════════════════════════════════════════════════════════════»
#                                                                                »
#      m_mcm3: 7/════════════════════════════════════════════════════════════════»
#                                                                                »
#      m_mcm4: 7/════════════════════════════════════════════════════════════════»
#                                                                                »
#      m_mcm5: 7/════════════════════════════════════════════════════════════════»
#                                                                                »
#      m_mcm6: 7/════════════════════════════════════════════════════════════════»
#                                                                                »
# m_meas_all: 15/════════════════════════════════════════════════════════════════»
#                                                                                »
# «                                                                          »
# «          q_0: ────────────────────■──────────────────────────────────────»
# «                         ┌─┐     ┌─┴─┐┌───┐                       ┌─┐     »
# «          q_1: ──────────┤M├─|0>─┤ X ├┤ X ├───────────────────────┤M├─|0>─»
# «                         └╥┘     └───┘└─┬─┘                       └╥┘     »
# «          q_2: ───────■───╫─────────────■──────────────────────────╫───■──»
# «                    ┌─┴─┐ ║      ┌───┐                    ┌─┐      ║ ┌─┴─┐»
# «          q_3: ─|0>─┤ X ├─╫──────┤ X ├────────────────────┤M├─|0>──╫─┤ X ├»
# «                    └───┘ ║      └─┬─┘                    └╥┘      ║ └───┘»
# «          q_4: ───────────╫───■────■───────────────────────╫───────╫──────»
# «                ┌─┐       ║ ┌─┴─┐     ┌───┐                ║  ┌─┐  ║      »
# «          q_5: ─┤M├──|0>──╫─┤ X ├─────┤ X ├────────────────╫──┤M├──╫──|0>─»
# «                └╥┘       ║ └───┘     └─┬─┘                ║  └╥┘  ║      »
# «          q_6: ──╫────────╫────────■────■──────────────────╫───╫───╫──────»
# «                 ║   ┌─┐  ║      ┌─┴─┐     ┌───┐           ║   ║   ║  ┌─┐ »
# «          q_7: ──╫───┤M├──╫──|0>─┤ X ├─────┤ X ├───────────╫───╫───╫──┤M├─»
# «                 ║   └╥┘  ║      └───┘     └─┬─┘           ║   ║   ║  └╥┘ »
# «          q_8: ──╫────╫───╫─────────────■────■─────────────╫───╫───╫───╫──»
# «                 ║    ║   ║  ┌─┐      ┌─┴─┐     ┌───┐      ║   ║   ║   ║  »
# «          q_9: ──╫────╫───╫──┤M├──|0>─┤ X ├─────┤ X ├──────╫───╫───╫───╫──»
# «                 ║    ║   ║  └╥┘      └───┘     └─┬─┘      ║   ║   ║   ║  »
# «         q_10: ──╫────╫───╫───╫──────────────■────■────────╫───╫───╫───╫──»
# «                 ║    ║   ║   ║   ┌─┐      ┌─┴─┐     ┌───┐ ║   ║   ║   ║  »
# «         q_11: ──╫────╫───╫───╫───┤M├──|0>─┤ X ├─────┤ X ├─╫───╫───╫───╫──»
# «                 ║    ║   ║   ║   └╥┘      └───┘     └─┬─┘ ║   ║   ║   ║  »
# «         q_12: ──╫────╫───╫───╫────╫──────────────■────■───╫───╫───╫───╫──»
# «                 ║    ║   ║   ║    ║   ┌─┐      ┌─┴─┐┌───┐ ║   ║   ║   ║  »
# «         q_13: ──╫────╫───╫───╫────╫───┤M├──|0>─┤ X ├┤ X ├─╫───╫───╫───╫──»
# «                 ║    ║   ║   ║    ║   └╥┘      └───┘└─┬─┘ ║   ║   ║   ║  »
# «         q_14: ──╫────╫───╫───╫────╫────╫──────────────■───╫───╫───╫───╫──»
# «                 ║    ║   ║   ║    ║    ║                  ║   ║   ║   ║  »
# «     m_mcm0: 7/══╬════╬═══╬═══╬════╬════╬══════════════════╬═══╬═══╬═══╬══»
# «                 ║    ║   ║   ║    ║    ║                  ║   ║   ║   ║  »
# «     m_mcm1: 7/══╩════╩═══╩═══╩════╩════╩══════════════════╬═══╬═══╬═══╬══»
# «                 2    3   0   4    5    6                  ║   ║   ║   ║  »
# «     m_mcm2: 7/════════════════════════════════════════════╩═══╩═══╩═══╩══»
# «                                                           1   2   0   3  »
# «     m_mcm3: 7/═══════════════════════════════════════════════════════════»
# «                                                                          »
# «     m_mcm4: 7/═══════════════════════════════════════════════════════════»
# «                                                                          »
# «     m_mcm5: 7/═══════════════════════════════════════════════════════════»
# «                                                                          »
# «     m_mcm6: 7/═══════════════════════════════════════════════════════════»
# «                                                                          »
# «m_meas_all: 15/═══════════════════════════════════════════════════════════»
# «                                                                          »
# «                                                                            »
# «          q_0: ──■────────────────────────────────────────■─────────────────»
# «               ┌─┴─┐┌───┐                       ┌─┐     ┌─┴─┐┌───┐          »
# «          q_1: ┤ X ├┤ X ├───────────────────────┤M├─|0>─┤ X ├┤ X ├──────────»
# «               └───┘└─┬─┘                       └╥┘     └───┘└─┬─┘          »
# «          q_2: ───────■──────────────────────────╫────────■────■────────────»
# «                    ┌───┐                    ┌─┐ ║      ┌─┴─┐     ┌───┐     »
# «          q_3: ─────┤ X ├────────────────────┤M├─╫──|0>─┤ X ├─────┤ X ├─────»
# «                    └─┬─┘                    └╥┘ ║      └───┘     └─┬─┘     »
# «          q_4: ──■────■───────────────────────╫──╫─────────────■────■───────»
# «               ┌─┴─┐     ┌───┐                ║  ║  ┌─┐      ┌─┴─┐     ┌───┐»
# «          q_5: ┤ X ├─────┤ X ├────────────────╫──╫──┤M├──|0>─┤ X ├─────┤ X ├»
# «               └───┘     └─┬─┘                ║  ║  └╥┘      └───┘     └─┬─┘»
# «          q_6: ───────■────■──────────────────╫──╫───╫──────────────■────■──»
# «                    ┌─┴─┐     ┌───┐           ║  ║   ║   ┌─┐      ┌─┴─┐     »
# «          q_7: ─|0>─┤ X ├─────┤ X ├───────────╫──╫───╫───┤M├──|0>─┤ X ├─────»
# «                    └───┘     └─┬─┘           ║  ║   ║   └╥┘      └───┘     »
# «          q_8: ────────────■────■─────────────╫──╫───╫────╫──────────────■──»
# «                ┌─┐      ┌─┴─┐     ┌───┐      ║  ║   ║    ║   ┌─┐      ┌─┴─┐»
# «          q_9: ─┤M├──|0>─┤ X ├─────┤ X ├──────╫──╫───╫────╫───┤M├──|0>─┤ X ├»
# «                └╥┘      └───┘     └─┬─┘      ║  ║   ║    ║   └╥┘      └───┘»
# «         q_10: ──╫──────────────■────■────────╫──╫───╫────╫────╫────────────»
# «                 ║   ┌─┐      ┌─┴─┐     ┌───┐ ║  ║   ║    ║    ║   ┌─┐      »
# «         q_11: ──╫───┤M├──|0>─┤ X ├─────┤ X ├─╫──╫───╫────╫────╫───┤M├──|0>─»
# «                 ║   └╥┘      └───┘     └─┬─┘ ║  ║   ║    ║    ║   └╥┘      »
# «         q_12: ──╫────╫──────────────■────■───╫──╫───╫────╫────╫────╫───────»
# «                 ║    ║   ┌─┐      ┌─┴─┐┌───┐ ║  ║   ║    ║    ║    ║   ┌─┐ »
# «         q_13: ──╫────╫───┤M├──|0>─┤ X ├┤ X ├─╫──╫───╫────╫────╫────╫───┤M├─»
# «                 ║    ║   └╥┘      └───┘└─┬─┘ ║  ║   ║    ║    ║    ║   └╥┘ »
# «         q_14: ──╫────╫────╫──────────────■───╫──╫───╫────╫────╫────╫────╫──»
# «                 ║    ║    ║                  ║  ║   ║    ║    ║    ║    ║  »
# «     m_mcm0: 7/══╬════╬════╬══════════════════╬══╬═══╬════╬════╬════╬════╬══»
# «                 ║    ║    ║                  ║  ║   ║    ║    ║    ║    ║  »
# «     m_mcm1: 7/══╬════╬════╬══════════════════╬══╬═══╬════╬════╬════╬════╬══»
# «                 ║    ║    ║                  ║  ║   ║    ║    ║    ║    ║  »
# «     m_mcm2: 7/══╩════╩════╩══════════════════╬══╬═══╬════╬════╬════╬════╬══»
# «                 4    5    6                  ║  ║   ║    ║    ║    ║    ║  »
# «     m_mcm3: 7/═══════════════════════════════╩══╩═══╩════╩════╩════╩════╩══»
# «                                              1  0   2    3    4    5    6  »
# «     m_mcm4: 7/═════════════════════════════════════════════════════════════»
# «                                                                            »
# «     m_mcm5: 7/═════════════════════════════════════════════════════════════»
# «                                                                            »
# «     m_mcm6: 7/═════════════════════════════════════════════════════════════»
# «                                                                            »
# «m_meas_all: 15/═════════════════════════════════════════════════════════════»
# «                                                                            »
# «                                                                              »
# «          q_0: ─────────────────────────■─────────────────────────────────────»
# «                              ┌─┐     ┌─┴─┐     ┌───┐                         »
# «          q_1: ───────────────┤M├─|0>─┤ X ├─────┤ X ├─────────────────────────»
# «                              └╥┘     └───┘     └─┬─┘                         »
# «          q_2: ────────────────╫─────────────■────■───────────────────────────»
# «                               ║  ┌─┐      ┌─┴─┐     ┌───┐                    »
# «          q_3: ────────────────╫──┤M├──|0>─┤ X ├─────┤ X ├────────────────────»
# «                               ║  └╥┘      └───┘     └─┬─┘                    »
# «          q_4: ────────────────╫───╫──────────────■────■──────────────────────»
# «                               ║   ║   ┌─┐      ┌─┴─┐     ┌───┐               »
# «          q_5: ────────────────╫───╫───┤M├──|0>─┤ X ├─────┤ X ├───────────────»
# «                               ║   ║   └╥┘      └───┘     └─┬─┘               »
# «          q_6: ────────────────╫───╫────╫──────────────■────■─────────────────»
# «               ┌───┐           ║   ║    ║   ┌─┐      ┌─┴─┐     ┌───┐          »
# «          q_7: ┤ X ├───────────╫───╫────╫───┤M├──|0>─┤ X ├─────┤ X ├──────────»
# «               └─┬─┘           ║   ║    ║   └╥┘      └───┘     └─┬─┘          »
# «          q_8: ──■─────────────╫───╫────╫────╫──────────────■────■────────────»
# «                    ┌───┐      ║   ║    ║    ║   ┌─┐      ┌─┴─┐     ┌───┐     »
# «          q_9: ─────┤ X ├──────╫───╫────╫────╫───┤M├──|0>─┤ X ├─────┤ X ├─────»
# «                    └─┬─┘      ║   ║    ║    ║   └╥┘      └───┘     └─┬─┘     »
# «         q_10: ──■────■────────╫───╫────╫────╫────╫──────────────■────■───────»
# «               ┌─┴─┐     ┌───┐ ║   ║    ║    ║    ║   ┌─┐      ┌─┴─┐     ┌───┐»
# «         q_11: ┤ X ├─────┤ X ├─╫───╫────╫────╫────╫───┤M├──|0>─┤ X ├─────┤ X ├»
# «               └───┘     └─┬─┘ ║   ║    ║    ║    ║   └╥┘      └───┘     └─┬─┘»
# «         q_12: ───────■────■───╫───╫────╫────╫────╫────╫──────────────■────■──»
# «                    ┌─┴─┐┌───┐ ║   ║    ║    ║    ║    ║   ┌─┐      ┌─┴─┐┌───┐»
# «         q_13: ─|0>─┤ X ├┤ X ├─╫───╫────╫────╫────╫────╫───┤M├──|0>─┤ X ├┤ X ├»
# «                    └───┘└─┬─┘ ║   ║    ║    ║    ║    ║   └╥┘      └───┘└─┬─┘»
# «         q_14: ────────────■───╫───╫────╫────╫────╫────╫────╫──────────────■──»
# «                               ║   ║    ║    ║    ║    ║    ║                 »
# «     m_mcm0: 7/════════════════╬═══╬════╬════╬════╬════╬════╬═════════════════»
# «                               ║   ║    ║    ║    ║    ║    ║                 »
# «     m_mcm1: 7/════════════════╬═══╬════╬════╬════╬════╬════╬═════════════════»
# «                               ║   ║    ║    ║    ║    ║    ║                 »
# «     m_mcm2: 7/════════════════╬═══╬════╬════╬════╬════╬════╬═════════════════»
# «                               ║   ║    ║    ║    ║    ║    ║                 »
# «     m_mcm3: 7/════════════════╬═══╬════╬════╬════╬════╬════╬═════════════════»
# «                               ║   ║    ║    ║    ║    ║    ║                 »
# «     m_mcm4: 7/════════════════╩═══╩════╩════╩════╩════╩════╩═════════════════»
# «                               0   1    2    3    4    5    6                 »
# «     m_mcm5: 7/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «     m_mcm6: 7/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «m_meas_all: 15/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «                                                               ┌─┐        »
# «          q_0: ──────────■─────────────────────────────────────┤M├────────»
# «               ┌─┐     ┌─┴─┐     ┌───┐                         └╥┘┌─┐     »
# «          q_1: ┤M├─|0>─┤ X ├─────┤ X ├──────────────────────────╫─┤M├─|0>─»
# «               └╥┘     └───┘     └─┬─┘                          ║ └╥┘     »
# «          q_2: ─╫─────────────■────■────────────────────────────╫──╫──────»
# «                ║  ┌─┐      ┌─┴─┐     ┌───┐                     ║  ║  ┌─┐ »
# «          q_3: ─╫──┤M├──|0>─┤ X ├─────┤ X ├─────────────────────╫──╫──┤M├─»
# «                ║  └╥┘      └───┘     └─┬─┘                     ║  ║  └╥┘ »
# «          q_4: ─╫───╫──────────────■────■───────────────────────╫──╫───╫──»
# «                ║   ║   ┌─┐      ┌─┴─┐     ┌───┐                ║  ║   ║  »
# «          q_5: ─╫───╫───┤M├──|0>─┤ X ├─────┤ X ├────────────────╫──╫───╫──»
# «                ║   ║   └╥┘      └───┘     └─┬─┘                ║  ║   ║  »
# «          q_6: ─╫───╫────╫──────────────■────■──────────────────╫──╫───╫──»
# «                ║   ║    ║   ┌─┐      ┌─┴─┐     ┌───┐           ║  ║   ║  »
# «          q_7: ─╫───╫────╫───┤M├──|0>─┤ X ├─────┤ X ├───────────╫──╫───╫──»
# «                ║   ║    ║   └╥┘      └───┘     └─┬─┘           ║  ║   ║  »
# «          q_8: ─╫───╫────╫────╫──────────────■────■─────────────╫──╫───╫──»
# «                ║   ║    ║    ║   ┌─┐      ┌─┴─┐     ┌───┐      ║  ║   ║  »
# «          q_9: ─╫───╫────╫────╫───┤M├──|0>─┤ X ├─────┤ X ├──────╫──╫───╫──»
# «                ║   ║    ║    ║   └╥┘      └───┘     └─┬─┘      ║  ║   ║  »
# «         q_10: ─╫───╫────╫────╫────╫──────────────■────■────────╫──╫───╫──»
# «                ║   ║    ║    ║    ║   ┌─┐      ┌─┴─┐     ┌───┐ ║  ║   ║  »
# «         q_11: ─╫───╫────╫────╫────╫───┤M├──|0>─┤ X ├─────┤ X ├─╫──╫───╫──»
# «                ║   ║    ║    ║    ║   └╥┘      └───┘     └─┬─┘ ║  ║   ║  »
# «         q_12: ─╫───╫────╫────╫────╫────╫──────────────■────■───╫──╫───╫──»
# «                ║   ║    ║    ║    ║    ║   ┌─┐      ┌─┴─┐┌───┐ ║  ║   ║  »
# «         q_13: ─╫───╫────╫────╫────╫────╫───┤M├──|0>─┤ X ├┤ X ├─╫──╫───╫──»
# «                ║   ║    ║    ║    ║    ║   └╥┘      └───┘└─┬─┘ ║  ║   ║  »
# «         q_14: ─╫───╫────╫────╫────╫────╫────╫──────────────■───╫──╫───╫──»
# «                ║   ║    ║    ║    ║    ║    ║                  ║  ║   ║  »
# «     m_mcm0: 7/═╬═══╬════╬════╬════╬════╬════╬══════════════════╬══╬═══╬══»
# «                ║   ║    ║    ║    ║    ║    ║                  ║  ║   ║  »
# «     m_mcm1: 7/═╬═══╬════╬════╬════╬════╬════╬══════════════════╬══╬═══╬══»
# «                ║   ║    ║    ║    ║    ║    ║                  ║  ║   ║  »
# «     m_mcm2: 7/═╬═══╬════╬════╬════╬════╬════╬══════════════════╬══╬═══╬══»
# «                ║   ║    ║    ║    ║    ║    ║                  ║  ║   ║  »
# «     m_mcm3: 7/═╬═══╬════╬════╬════╬════╬════╬══════════════════╬══╬═══╬══»
# «                ║   ║    ║    ║    ║    ║    ║                  ║  ║   ║  »
# «     m_mcm4: 7/═╬═══╬════╬════╬════╬════╬════╬══════════════════╬══╬═══╬══»
# «                ║   ║    ║    ║    ║    ║    ║                  ║  ║   ║  »
# «     m_mcm5: 7/═╩═══╩════╩════╩════╩════╩════╩══════════════════╬══╬═══╬══»
# «                0   1    2    3    4    5    6                  ║  ║   ║  »
# «     m_mcm6: 7/═════════════════════════════════════════════════╬══╩═══╩══»
# «                                                                ║  0   1  »
# «m_meas_all: 15/═════════════════════════════════════════════════╩═════════»
# «                                                                0         »
# «                                                                              »
# «          q_0: ───────────────────────────────────────────────────────────────»
# «                                                               ┌─┐            »
# «          q_1: ────────────────────────────────────────────────┤M├────────────»
# «                                        ┌─┐                    └╥┘            »
# «          q_2: ─────────────────────────┤M├─────────────────────╫─────────────»
# «                                        └╥┘                     ║ ┌─┐         »
# «          q_3: ─|0>──────────────────────╫──────────────────────╫─┤M├─────────»
# «                                         ║ ┌─┐                  ║ └╥┘         »
# «          q_4: ──────────────────────────╫─┤M├──────────────────╫──╫──────────»
# «                ┌─┐                      ║ └╥┘                  ║  ║ ┌─┐      »
# «          q_5: ─┤M├──|0>─────────────────╫──╫───────────────────╫──╫─┤M├──────»
# «                └╥┘                      ║  ║ ┌─┐               ║  ║ └╥┘      »
# «          q_6: ──╫───────────────────────╫──╫─┤M├───────────────╫──╫──╫───────»
# «                 ║   ┌─┐                 ║  ║ └╥┘               ║  ║  ║ ┌─┐   »
# «          q_7: ──╫───┤M├──|0>────────────╫──╫──╫────────────────╫──╫──╫─┤M├───»
# «                 ║   └╥┘                 ║  ║  ║ ┌─┐            ║  ║  ║ └╥┘   »
# «          q_8: ──╫────╫──────────────────╫──╫──╫─┤M├────────────╫──╫──╫──╫────»
# «                 ║    ║   ┌─┐            ║  ║  ║ └╥┘            ║  ║  ║  ║ ┌─┐»
# «          q_9: ──╫────╫───┤M├──|0>───────╫──╫──╫──╫─────────────╫──╫──╫──╫─┤M├»
# «                 ║    ║   └╥┘            ║  ║  ║  ║ ┌─┐         ║  ║  ║  ║ └╥┘»
# «         q_10: ──╫────╫────╫─────────────╫──╫──╫──╫─┤M├─────────╫──╫──╫──╫──╫─»
# «                 ║    ║    ║   ┌─┐       ║  ║  ║  ║ └╥┘         ║  ║  ║  ║  ║ »
# «         q_11: ──╫────╫────╫───┤M├──|0>──╫──╫──╫──╫──╫──────────╫──╫──╫──╫──╫─»
# «                 ║    ║    ║   └╥┘       ║  ║  ║  ║  ║ ┌─┐      ║  ║  ║  ║  ║ »
# «         q_12: ──╫────╫────╫────╫────────╫──╫──╫──╫──╫─┤M├──────╫──╫──╫──╫──╫─»
# «                 ║    ║    ║    ║   ┌─┐  ║  ║  ║  ║  ║ └╥┘      ║  ║  ║  ║  ║ »
# «         q_13: ──╫────╫────╫────╫───┤M├──╫──╫──╫──╫──╫──╫──|0>──╫──╫──╫──╫──╫─»
# «                 ║    ║    ║    ║   └╥┘  ║  ║  ║  ║  ║  ║  ┌─┐  ║  ║  ║  ║  ║ »
# «         q_14: ──╫────╫────╫────╫────╫───╫──╫──╫──╫──╫──╫──┤M├──╫──╫──╫──╫──╫─»
# «                 ║    ║    ║    ║    ║   ║  ║  ║  ║  ║  ║  └╥┘  ║  ║  ║  ║  ║ »
# «     m_mcm0: 7/══╬════╬════╬════╬════╬═══╬══╬══╬══╬══╬══╬═══╬═══╬══╬══╬══╬══╬═»
# «                 ║    ║    ║    ║    ║   ║  ║  ║  ║  ║  ║   ║   ║  ║  ║  ║  ║ »
# «     m_mcm1: 7/══╬════╬════╬════╬════╬═══╬══╬══╬══╬══╬══╬═══╬═══╬══╬══╬══╬══╬═»
# «                 ║    ║    ║    ║    ║   ║  ║  ║  ║  ║  ║   ║   ║  ║  ║  ║  ║ »
# «     m_mcm2: 7/══╬════╬════╬════╬════╬═══╬══╬══╬══╬══╬══╬═══╬═══╬══╬══╬══╬══╬═»
# «                 ║    ║    ║    ║    ║   ║  ║  ║  ║  ║  ║   ║   ║  ║  ║  ║  ║ »
# «     m_mcm3: 7/══╬════╬════╬════╬════╬═══╬══╬══╬══╬══╬══╬═══╬═══╬══╬══╬══╬══╬═»
# «                 ║    ║    ║    ║    ║   ║  ║  ║  ║  ║  ║   ║   ║  ║  ║  ║  ║ »
# «     m_mcm4: 7/══╬════╬════╬════╬════╬═══╬══╬══╬══╬══╬══╬═══╬═══╬══╬══╬══╬══╬═»
# «                 ║    ║    ║    ║    ║   ║  ║  ║  ║  ║  ║   ║   ║  ║  ║  ║  ║ »
# «     m_mcm5: 7/══╬════╬════╬════╬════╬═══╬══╬══╬══╬══╬══╬═══╬═══╬══╬══╬══╬══╬═»
# «                 ║    ║    ║    ║    ║   ║  ║  ║  ║  ║  ║   ║   ║  ║  ║  ║  ║ »
# «     m_mcm6: 7/══╩════╩════╩════╩════╩═══╬══╬══╬══╬══╬══╬═══╬═══╬══╬══╬══╬══╬═»
# «                 2    3    4    5    6   ║  ║  ║  ║  ║  ║   ║   ║  ║  ║  ║  ║ »
# «m_meas_all: 15/══════════════════════════╩══╩══╩══╩══╩══╩═══╩═══╩══╩══╩══╩══╩═»
# «                                         2  4  6  8  10 12  14  1  3  5  7  9 »
# «
# «          q_0: ──────
# «
# «          q_1: ──────
# «
# «          q_2: ──────
# «
# «          q_3: ──────
# «
# «          q_4: ──────
# «
# «          q_5: ──────
# «
# «          q_6: ──────
# «
# «          q_7: ──────
# «
# «          q_8: ──────
# «
# «          q_9: ──────
# «
# «         q_10: ──────
# «               ┌─┐
# «         q_11: ┤M├───
# «               └╥┘
# «         q_12: ─╫────
# «                ║ ┌─┐
# «         q_13: ─╫─┤M├
# «                ║ └╥┘
# «         q_14: ─╫──╫─
# «                ║  ║
# «     m_mcm0: 7/═╬══╬═
# «                ║  ║
# «     m_mcm1: 7/═╬══╬═
# «                ║  ║
# «     m_mcm2: 7/═╬══╬═
# «                ║  ║
# «     m_mcm3: 7/═╬══╬═
# «                ║  ║
# «     m_mcm4: 7/═╬══╬═
# «                ║  ║
# «     m_mcm5: 7/═╬══╬═
# «                ║  ║
# «     m_mcm6: 7/═╬══╬═
# «                ║  ║
# «m_meas_all: 15/═╩══╩═
# «                11 13

# %%
benchmark_features = {}
for benchmark, label in benchmarks:
    benchmark_features[label] = [
        supermarq.converters.compute_communication_with_qiskit(benchmark.qiskit_circuit()),
        supermarq.converters.compute_depth_with_qiskit(benchmark.qiskit_circuit()),
        supermarq.converters.compute_entanglement_with_qiskit(benchmark.qiskit_circuit()),
        supermarq.converters.compute_liveness_with_qiskit(benchmark.qiskit_circuit()),
        supermarq.converters.compute_measurement_with_qiskit(benchmark.qiskit_circuit()),
        supermarq.converters.compute_parallelism_with_qiskit(benchmark.qiskit_circuit()),]
print(benchmark_features)
# Out:
# {'bitcode3': [0.4, 0.5, 0.8, 0.62, 0.2222222222222222, 0.0], 'bitcode4': [0.2857142857142857, 0.2777777777777778, 0.9473684210526315, 0.6813186813186813, 0.25, 0.07692307692307691], 'bitcode5': [0.2222222222222222, 0.25, 0.9411764705882353, 0.6604938271604939, 0.47058823529411764, 0.1111111111111111], 'bitcode6': [0.18181818181818182, 0.2, 0.9259259259259259, 0.6818181818181818, 0.23809523809523808, 0.14545454545454545], 'bitcode7': [0.15384615384615385, 0.16666666666666666, 0.9863013698630136, 0.6804733727810651, 0.48, 0.15064102564102563], 'bitcode8': [0.13333333333333333, 0.14285714285714285, 0.98, 0.6911111111111111, 0.3793103448275862, 0.16666666666666669]}

# %%
jobs =[]
print("=============SCORES OF ALL THE CIRCUITS=============")    
for backend in selected_fakes:
    print("------------------------BACKEND-NAME :: ", backend().name)
    for benchmark, label in benchmarks:
        circuit=benchmark.qiskit_circuit()
        score_list=[]
        for i in range(0,5):
            job = backend().run(circuit, shots=1000)
            result=job.result()
            #print(result)
            counts = job.result(0).get_counts()
            score = benchmark.score(counts)
            score_list.append(score)
        score = np.mean(score_list) 
        sd = np.std(score_list)
        print(label," --> score :: ",score,"           SD :: ",sd,"  time_taken= ",job.result(0).time_taken)
        #counts=job.result(0).count()
        jobs.append((label,benchmark,backend,job,score,sd))
#jobs
# Out:
# =============SCORES OF ALL THE CIRCUITS=============
# ------------------------BACKEND-NAME ::  fake_paris
# bitcode3  --> score ::  0.0            SD ::  0.0   time_taken=  0.2057325839996338
# bitcode4  --> score ::  9.860761315262648e-33            SD ::  1.97215226305253e-32   time_taken=  0.12828803062438965
# bitcode5  --> score ::  0.0            SD ::  0.0   time_taken=  0.2942676544189453
# bitcode6  --> score ::  1.5777218104420237e-31            SD ::  7.88860905221012e-32   time_taken=  0.541649580001831
# bitcode7  --> score ::  1.9721522630525295e-31            SD ::  0.0   time_taken=  1.2246479988098145

# %%
all_scores={}  
all_fake_names=[]
all_fake_scores=[]
for i in selected_fakes:
    fakes=i
    i={}
    for label,benchmark,backend,job,score,sd in jobs:
        #supermarq.plotting.plot_results([score], [label])
        if fakes == backend:
            i[label] = score
    device_scores = 'device_score_' +str(fakes().name)
    all_scores[device_scores]= i
    all_fake_scores.append(i)
    all_fake_names.append(device_scores)

# %%
for label,benchmark,backend,job,score,sd in jobs:
    print("USED BACKEND::",backend().name,"; CIRCUIT_NAME:",label, "; SCORE =",score)
    supermarq.plotting.plot_results([score], [label])
    print("-----------------------------------------------------------")

# %%
names=[]
scores=[]
X="A "+name_of_algo+' Benchamrk'
for i,j in benchmark_features.items():
    names.append(i)
    scores.append(j)
supermarq.plotting.plot_benchmark(
        [X,names,scores],
        spoke_labels=["PC", "CD", "Ent", "Liv", "Mea", "Par"],
        show=True)

# %%
supermarq.plotting.plot_correlations(benchmark_features,all_fake_scores,["PC", "CD", "Ent", "Liv", "Mea", "Par"],device_name=all_fake_names,show=True,)

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 
import numpy as np
all_fake_names=[]
all_score=[]
all_sd=[]
all_ckt=[]
for i in selected_fakes:
    all_fake_names.append(i().name)    
for benchmark, label in benchmarks:
    i=[]
    j=[]
    k=[]
    for ckt,benchmark,backend,job,score,sd in jobs:
        if ckt == label:
            i.append(score)
            j.append(sd)
    all_ckt.append(label)
    all_score.append(i)
    all_sd.append(j)
num_bars = len(all_score)
width = 0.1
x = np.arange(len(all_fake_names)) # x-axis positions for each bar
fig, ax = plt.subplots()
for i in range(num_bars):               # Create bars for each category with appropriate offsets
    ax.bar(x + i * width, all_score[i], width=width, label=f'Bar {i+1}', 
           yerr=all_sd[i],align='center',alpha=0.9,ecolor='black',capsize=2)
ax.set_xlabel('Name of Fake Backends',fontweight ='bold',fontsize = 12)
ax.set_ylabel('Scores',fontweight ='bold',fontsize = 12)
ax.set_title('Plot of GHZ over Multiple Qubits')
ax.set_xticks(x + (num_bars - 1) * width / 2)
ax.set_xticklabels(all_fake_names)
ax.legend(all_ckt,loc="lower left")
#ax.grid(True)
plt.show()
