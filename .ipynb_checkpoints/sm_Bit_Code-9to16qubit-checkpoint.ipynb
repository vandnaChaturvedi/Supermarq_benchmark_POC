# %%
from qiskit_aer import AerSimulator
from qiskit import *
import supermarq
from qiskit.providers.fake_provider import *
import numpy as np 
import os
import random
########## INPUT ############
f=5 # number of fake_backend want to choose
lower_limit= 3 # the lower limit of qubits for the circuit
upper_limit= 6 # the lower limit of qubits for the circuit
steps= 1 #jump in qubit numbers
name_of_algo='bitcode'

# %%
all_fakes=[FakeAlmadenV2,FakeArmonkV2,FakeAthensV2,FakeAuckland,FakeBelemV2,FakeBoeblingenV2,FakeBogotaV2,FakeBrooklynV2,FakeBurlingtonV2,FakeCairoV2,FakeCambridgeV2,FakeCasablancaV2,FakeEssexV2,FakeGeneva,FakeGuadalupeV2,FakeHanoiV2,FakeJakartaV2,FakeJohannesburgV2,FakeKolkataV2,FakeLagosV2,FakeLimaV2,FakeLondonV2,FakeManhattanV2,FakeManilaV2,FakeMelbourneV2,FakeMontrealV2,FakeMumbaiV2,FakeNairobiV2,FakeOslo,FakeOurenseV2,FakeParisV2,FakePerth,FakePrague,FakePoughkeepsieV2,FakeQuitoV2,FakeRochesterV2,FakeRomeV2,FakeSantiagoV2,FakeSherbrooke,FakeSingaporeV2,FakeSydneyV2,FakeTorontoV2,FakeValenciaV2,FakeVigoV2,FakeWashingtonV2,FakeYorktownV2]
selected_fakes = random.sample(all_fakes, f)
selected_fakes  # having any randomly selected 5 fake backends out of 46 mentioned in the inital list
# Out:
# [qiskit.providers.fake_provider.backends.armonk.fake_armonk.FakeArmonkV2,
#  qiskit.providers.fake_provider.backends.mumbai.fake_mumbai.FakeMumbaiV2,
#  qiskit.providers.fake_provider.backends.manila.fake_manila.FakeManilaV2,
#  qiskit.providers.fake_provider.backends.yorktown.fake_yorktown.FakeYorktownV2,
#  qiskit.providers.fake_provider.backends.almaden.fake_almaden.FakeAlmadenV2]

# %%
benchmarks=[]
for i in range(lower_limit,upper_limit,steps):
    label = name_of_algo+str(i)
    rand_list=[]
    for j in range(i):       
        rand_list.append(random.randint(0,1))
    print("i=",i,"i-1=",i-1,"rand_list=",rand_list)
    
    benchmarks.append((supermarq.bit_code.BitCode(i,i-1,rand_list),label))
for i in benchmarks:
    circuit=i[0].qiskit_circuit()
    print("--------------------------",i[1],"---------------------------")
    #circuit.draw(output="mpl")
    print(circuit.draw())
# Out:
# i= 3 i-1= 2 rand_list= [1, 1, 1]
# i= 4 i-1= 3 rand_list= [1, 0, 1, 1]
# i= 5 i-1= 4 rand_list= [0, 0, 1, 1, 1]
# -------------------------- bitcode3 ---------------------------
#               ┌───┐                                 ┌─┐
#          q_0: ┤ X ├──■─────────────────■────────────┤M├──────────────────────
#               └───┘┌─┴─┐┌───┐┌─┐     ┌─┴─┐     ┌───┐└╥┘┌─┐             ┌─┐
#          q_1: ─────┤ X ├┤ X ├┤M├─|0>─┤ X ├─────┤ X ├─╫─┤M├─|0>─────────┤M├───
#               ┌───┐└───┘└─┬─┘└╥┘     └───┘     └─┬─┘ ║ └╥┘     ┌─┐     └╥┘
#          q_2: ┤ X ├──■────■───╫─────────────■────■───╫──╫──────┤M├──────╫────
#               └───┘┌─┴─┐┌───┐ ║  ┌─┐      ┌─┴─┐┌───┐ ║  ║  ┌─┐ └╥┘      ║ ┌─┐
#          q_3: ─────┤ X ├┤ X ├─╫──┤M├──|0>─┤ X ├┤ X ├─╫──╫──┤M├──╫──|0>──╫─┤M├
#               ┌───┐└───┘└─┬─┘ ║  └╥┘      └───┘└─┬─┘ ║  ║  └╥┘  ║  ┌─┐  ║ └╥┘
#          q_4: ┤ X ├───────■───╫───╫──────────────■───╫──╫───╫───╫──┤M├──╫──╫─
#               └───┘           ║   ║                  ║  ║   ║   ║  └╥┘  ║  ║
#     m_mcm0: 2/════════════════╩═══╩══════════════════╬══╬═══╬═══╬═══╬═══╬══╬═
#                               0   1                  ║  ║   ║   ║   ║   ║  ║
#     m_mcm1: 2/═══════════════════════════════════════╬══╩═══╩═══╬═══╬═══╬══╬═
#                                                      ║  0   1   ║   ║   ║  ║
# m_meas_all: 5/═══════════════════════════════════════╩══════════╩═══╩═══╩══╩═
#                                                      0          2   4   1  3
# -------------------------- bitcode4 ---------------------------
#               ┌───┐                                                        »
#          q_0: ┤ X ├──■─────────────────■───────────────────────────■───────»
#               └───┘┌─┴─┐┌───┐┌─┐     ┌─┴─┐     ┌───┐     ┌─┐     ┌─┴─┐     »
#          q_1: ─────┤ X ├┤ X ├┤M├─|0>─┤ X ├─────┤ X ├─────┤M├─|0>─┤ X ├─────»
#                    └───┘└─┬─┘└╥┘     └───┘     └─┬─┘     └╥┘     └───┘     »
#          q_2: ──■─────────■───╫─────────────■────■────────╫─────────────■──»
#               ┌─┴─┐     ┌───┐ ║  ┌─┐      ┌─┴─┐     ┌───┐ ║  ┌─┐      ┌─┴─┐»
#          q_3: ┤ X ├─────┤ X ├─╫──┤M├──|0>─┤ X ├─────┤ X ├─╫──┤M├──|0>─┤ X ├»
#               ├───┤     └─┬─┘ ║  └╥┘      └───┘     └─┬─┘ ║  └╥┘      └───┘»
#          q_4: ┤ X ├──■────■───╫───╫──────────────■────■───╫───╫────────────»
#               └───┘┌─┴─┐┌───┐ ║   ║   ┌─┐      ┌─┴─┐┌───┐ ║   ║   ┌─┐      »
#          q_5: ─────┤ X ├┤ X ├─╫───╫───┤M├──|0>─┤ X ├┤ X ├─╫───╫───┤M├──|0>─»
#               ┌───┐└───┘└─┬─┘ ║   ║   └╥┘      └───┘└─┬─┘ ║   ║   └╥┘      »
#          q_6: ┤ X ├───────■───╫───╫────╫──────────────■───╫───╫────╫───────»
#               └───┘           ║   ║    ║                  ║   ║    ║       »
#     m_mcm0: 3/════════════════╩═══╩════╩══════════════════╬═══╬════╬═══════»
#                               0   1    2                  ║   ║    ║       »
#     m_mcm1: 3/════════════════════════════════════════════╩═══╩════╩═══════»
#                                                           0   1    2       »
#     m_mcm2: 3/═════════════════════════════════════════════════════════════»
#                                                                            »
# m_meas_all: 7/═════════════════════════════════════════════════════════════»
#                                                                            »
# «                        ┌─┐
# «         q_0: ──────────┤M├─────────────────────────────────
# «              ┌───┐     └╥┘┌─┐                     ┌─┐
# «         q_1: ┤ X ├──────╫─┤M├─|0>─────────────────┤M├──────
# «              └─┬─┘      ║ └╥┘          ┌─┐        └╥┘
# «         q_2: ──■────────╫──╫───────────┤M├─────────╫───────
# «                   ┌───┐ ║  ║  ┌─┐      └╥┘         ║ ┌─┐
# «         q_3: ─────┤ X ├─╫──╫──┤M├──|0>──╫──────────╫─┤M├───
# «                   └─┬─┘ ║  ║  └╥┘       ║ ┌─┐      ║ └╥┘
# «         q_4: ──■────■───╫──╫───╫────────╫─┤M├──────╫──╫────
# «              ┌─┴─┐┌───┐ ║  ║   ║   ┌─┐  ║ └╥┘      ║  ║ ┌─┐
# «         q_5: ┤ X ├┤ X ├─╫──╫───╫───┤M├──╫──╫──|0>──╫──╫─┤M├
# «              └───┘└─┬─┘ ║  ║   ║   └╥┘  ║  ║  ┌─┐  ║  ║ └╥┘
# «         q_6: ───────■───╫──╫───╫────╫───╫──╫──┤M├──╫──╫──╫─
# «                         ║  ║   ║    ║   ║  ║  └╥┘  ║  ║  ║
# «    m_mcm0: 3/═══════════╬══╬═══╬════╬═══╬══╬═══╬═══╬══╬══╬═
# «                         ║  ║   ║    ║   ║  ║   ║   ║  ║  ║
# «    m_mcm1: 3/═══════════╬══╬═══╬════╬═══╬══╬═══╬═══╬══╬══╬═
# «                         ║  ║   ║    ║   ║  ║   ║   ║  ║  ║
# «    m_mcm2: 3/═══════════╬══╩═══╩════╩═══╬══╬═══╬═══╬══╬══╬═
# «                         ║  0   1    2   ║  ║   ║   ║  ║  ║
# «m_meas_all: 7/═══════════╩═══════════════╩══╩═══╩═══╩══╩══╩═
# «                         0               2  4   6   1  3  5
# -------------------------- bitcode5 ---------------------------
#                                                                            »
#          q_0: ──■──────────────────────■────────────────────────────────■──»
#               ┌─┴─┐┌───┐     ┌─┐     ┌─┴─┐     ┌───┐          ┌─┐     ┌─┴─┐»
#          q_1: ┤ X ├┤ X ├─────┤M├─|0>─┤ X ├─────┤ X ├──────────┤M├─|0>─┤ X ├»
#               └───┘└─┬─┘     └╥┘     └───┘     └─┬─┘          └╥┘     └───┘»
#          q_2: ──■────■────────╫─────────────■────■─────────────╫───────────»
#               ┌─┴─┐     ┌───┐ ║  ┌─┐      ┌─┴─┐     ┌───┐      ║  ┌─┐      »
#          q_3: ┤ X ├─────┤ X ├─╫──┤M├──|0>─┤ X ├─────┤ X ├──────╫──┤M├──|0>─»
#               ├───┤     └─┬─┘ ║  └╥┘      └───┘     └─┬─┘      ║  └╥┘      »
#          q_4: ┤ X ├──■────■───╫───╫──────────────■────■────────╫───╫───────»
#               └───┘┌─┴─┐┌───┐ ║   ║   ┌─┐      ┌─┴─┐     ┌───┐ ║   ║   ┌─┐ »
#          q_5: ─────┤ X ├┤ X ├─╫───╫───┤M├──|0>─┤ X ├─────┤ X ├─╫───╫───┤M├─»
#               ┌───┐└───┘└─┬─┘ ║   ║   └╥┘      └───┘     └─┬─┘ ║   ║   └╥┘ »
#          q_6: ┤ X ├──■────■───╫───╫────╫──────────────■────■───╫───╫────╫──»
#               └───┘┌─┴─┐┌───┐ ║   ║    ║   ┌─┐      ┌─┴─┐┌───┐ ║   ║    ║  »
#          q_7: ─────┤ X ├┤ X ├─╫───╫────╫───┤M├──|0>─┤ X ├┤ X ├─╫───╫────╫──»
#               ┌───┐└───┘└─┬─┘ ║   ║    ║   └╥┘      └───┘└─┬─┘ ║   ║    ║  »
#          q_8: ┤ X ├───────■───╫───╫────╫────╫──────────────■───╫───╫────╫──»
#               └───┘           ║   ║    ║    ║                  ║   ║    ║  »
#     m_mcm0: 4/════════════════╩═══╩════╩════╩══════════════════╬═══╬════╬══»
#                               0   1    2    3                  ║   ║    ║  »
#     m_mcm1: 4/═════════════════════════════════════════════════╩═══╩════╩══»
#                                                                0   1    2  »
#     m_mcm2: 4/═════════════════════════════════════════════════════════════»
#                                                                            »
#     m_mcm3: 4/═════════════════════════════════════════════════════════════»
#                                                                            »
# m_meas_all: 9/═════════════════════════════════════════════════════════════»
#                                                                            »
# «                                                                   ┌─┐        »
# «         q_0: ──────────────────────────────■──────────────────────┤M├────────»
# «                   ┌───┐          ┌─┐     ┌─┴─┐     ┌───┐          └╥┘┌─┐     »
# «         q_1: ─────┤ X ├──────────┤M├─|0>─┤ X ├─────┤ X ├───────────╫─┤M├─|0>─»
# «                   └─┬─┘          └╥┘     └───┘     └─┬─┘           ║ └╥┘     »
# «         q_2: ──■────■─────────────╫─────────────■────■─────────────╫──╫──────»
# «              ┌─┴─┐     ┌───┐      ║  ┌─┐      ┌─┴─┐     ┌───┐      ║  ║  ┌─┐ »
# «         q_3: ┤ X ├─────┤ X ├──────╫──┤M├──|0>─┤ X ├─────┤ X ├──────╫──╫──┤M├─»
# «              └───┘     └─┬─┘      ║  └╥┘      └───┘     └─┬─┘      ║  ║  └╥┘ »
# «         q_4: ───────■────■────────╫───╫──────────────■────■────────╫──╫───╫──»
# «                   ┌─┴─┐     ┌───┐ ║   ║   ┌─┐      ┌─┴─┐     ┌───┐ ║  ║   ║  »
# «         q_5: ─|0>─┤ X ├─────┤ X ├─╫───╫───┤M├──|0>─┤ X ├─────┤ X ├─╫──╫───╫──»
# «                   └───┘     └─┬─┘ ║   ║   └╥┘      └───┘     └─┬─┘ ║  ║   ║  »
# «         q_6: ────────────■────■───╫───╫────╫──────────────■────■───╫──╫───╫──»
# «               ┌─┐      ┌─┴─┐┌───┐ ║   ║    ║   ┌─┐      ┌─┴─┐┌───┐ ║  ║   ║  »
# «         q_7: ─┤M├──|0>─┤ X ├┤ X ├─╫───╫────╫───┤M├──|0>─┤ X ├┤ X ├─╫──╫───╫──»
# «               └╥┘      └───┘└─┬─┘ ║   ║    ║   └╥┘      └───┘└─┬─┘ ║  ║   ║  »
# «         q_8: ──╫──────────────■───╫───╫────╫────╫──────────────■───╫──╫───╫──»
# «                ║                  ║   ║    ║    ║                  ║  ║   ║  »
# «    m_mcm0: 4/══╬══════════════════╬═══╬════╬════╬══════════════════╬══╬═══╬══»
# «                ║                  ║   ║    ║    ║                  ║  ║   ║  »
# «    m_mcm1: 4/══╩══════════════════╬═══╬════╬════╬══════════════════╬══╬═══╬══»
# «                3                  ║   ║    ║    ║                  ║  ║   ║  »
# «    m_mcm2: 4/═════════════════════╩═══╩════╩════╩══════════════════╬══╬═══╬══»
# «                                   0   1    2    3                  ║  ║   ║  »
# «    m_mcm3: 4/══════════════════════════════════════════════════════╬══╩═══╩══»
# «                                                                    ║  0   1  »
# «m_meas_all: 9/══════════════════════════════════════════════════════╩═════════»
# «                                                                    0         »
# «
# «         q_0: ────────────────────────────────────
# «                                      ┌─┐
# «         q_1: ────────────────────────┤M├─────────
# «                        ┌─┐           └╥┘
# «         q_2: ──────────┤M├────────────╫──────────
# «                        └╥┘            ║ ┌─┐
# «         q_3: ─|0>───────╫─────────────╫─┤M├──────
# «                         ║ ┌─┐         ║ └╥┘
# «         q_4: ───────────╫─┤M├─────────╫──╫───────
# «               ┌─┐       ║ └╥┘         ║  ║ ┌─┐
# «         q_5: ─┤M├──|0>──╫──╫──────────╫──╫─┤M├───
# «               └╥┘       ║  ║ ┌─┐      ║  ║ └╥┘
# «         q_6: ──╫────────╫──╫─┤M├──────╫──╫──╫────
# «                ║   ┌─┐  ║  ║ └╥┘      ║  ║  ║ ┌─┐
# «         q_7: ──╫───┤M├──╫──╫──╫──|0>──╫──╫──╫─┤M├
# «                ║   └╥┘  ║  ║  ║  ┌─┐  ║  ║  ║ └╥┘
# «         q_8: ──╫────╫───╫──╫──╫──┤M├──╫──╫──╫──╫─
# «                ║    ║   ║  ║  ║  └╥┘  ║  ║  ║  ║
# «    m_mcm0: 4/══╬════╬═══╬══╬══╬═══╬═══╬══╬══╬══╬═
# «                ║    ║   ║  ║  ║   ║   ║  ║  ║  ║
# «    m_mcm1: 4/══╬════╬═══╬══╬══╬═══╬═══╬══╬══╬══╬═
# «                ║    ║   ║  ║  ║   ║   ║  ║  ║  ║
# «    m_mcm2: 4/══╬════╬═══╬══╬══╬═══╬═══╬══╬══╬══╬═
# «                ║    ║   ║  ║  ║   ║   ║  ║  ║  ║
# «    m_mcm3: 4/══╩════╩═══╬══╬══╬═══╬═══╬══╬══╬══╬═
# «                2    3   ║  ║  ║   ║   ║  ║  ║  ║
# «m_meas_all: 9/═══════════╩══╩══╩═══╩═══╩══╩══╩══╩═
# «                         2  4  6   8   1  3  5  7

# %%
benchmark_features = {}
for benchmark, label in benchmarks:
    benchmark_features[label] = [
        supermarq.converters.compute_communication_with_qiskit(benchmark.qiskit_circuit()),
        supermarq.converters.compute_depth_with_qiskit(benchmark.qiskit_circuit()),
        supermarq.converters.compute_entanglement_with_qiskit(benchmark.qiskit_circuit()),
        supermarq.converters.compute_liveness_with_qiskit(benchmark.qiskit_circuit()),
        supermarq.converters.compute_measurement_with_qiskit(benchmark.qiskit_circuit()),
        supermarq.converters.compute_parallelism_with_qiskit(benchmark.qiskit_circuit()),]
print(benchmark_features)
# Out:
# {'bitcode3': [0.4, 0.5, 0.7272727272727273, 0.64, 0.2222222222222222, 0.025000000000000022], 'bitcode4': [0.2857142857142857, 0.3333333333333333, 0.8571428571428571, 0.6530612244897959, 0.23076923076923078, 0.08333333333333333], 'bitcode5': [0.2222222222222222, 0.25, 0.9142857142857143, 0.6666666666666666, 0.29411764705882354, 0.11805555555555555]}

# %%
# %time
import time
jobs =[]
print("=============SCORES OF ALL THE CIRCUITS=============")    
for backend in selected_fakes:
    print("------------------------BACKEND-NAME :: ", backend().name)
    for benchmark, label in benchmarks:
        circuit=benchmark.qiskit_circuit()
        score_list=[]
        for i in range(0,5):
            start=time.time()
            job = backend().run(circuit, shots=1000)
            total_time=time.time()-start
            result=job.result()
            print("\nTime_Taken (in seconds):  ", total_time,"\n")
            counts = job.result(0).get_counts()
            score = benchmark.score(counts)
            score_list.append(score)
        score = np.mean(score_list) 
        sd = np.std(score_list)
        print(label," --> score :: ",score,"           SD :: ",sd,"  time_taken(in seconds)= ",job.result(0).time_taken)
        #counts=job.result(0).count()
        jobs.append((label,benchmark,backend,job,score,sd))
#jobs
# Out:
# CPU times: user 1 µs, sys: 1 µs, total: 2 µs
# Wall time: 4.05 µs
# =============SCORES OF ALL THE CIRCUITS=============
# ------------------------BACKEND-NAME ::  fake_armonk
#
# Time_Taken (in seconds):   0.016301631927490234
#
#
# Time_Taken (in seconds):   0.0067255496978759766
#
#
# Time_Taken (in seconds):   0.008277177810668945
#
#
# Time_Taken (in seconds):   0.007254600524902344
#
#
# Time_Taken (in seconds):   0.010511398315429688
#
# bitcode3  --> score ::  0.0            SD ::  0.0   time_taken(in seconds)=  0.006005764007568359
#
# Time_Taken (in seconds):   0.009828805923461914
#
#
# Time_Taken (in seconds):   0.010136127471923828
#
#
# Time_Taken (in seconds):   0.006791114807128906
#
#
# Time_Taken (in seconds):   0.006903648376464844
#
#
# Time_Taken (in seconds):   0.006720066070556641
#
# bitcode4  --> score ::  0.0            SD ::  0.0   time_taken(in seconds)=  0.014771461486816406
#
# Time_Taken (in seconds):   0.006568431854248047
#
#
# Time_Taken (in seconds):   0.010341644287109375
#
#
# Time_Taken (in seconds):   0.007094144821166992
#
#
# Time_Taken (in seconds):   0.010645151138305664
#
#
# Time_Taken (in seconds):   0.010675907135009766
#
# bitcode5  --> score ::  0.0            SD ::  0.0   time_taken(in seconds)=  0.019170284271240234
# ------------------------BACKEND-NAME ::  fake_mumbai
#
# Time_Taken (in seconds):   0.3668177127838135
#
#
# Time_Taken (in seconds):   0.38085103034973145
#
#
# Time_Taken (in seconds):   0.3830125331878662
#
#
# Time_Taken (in seconds):   0.3701155185699463
#
#
# Time_Taken (in seconds):   0.3709549903869629
#
# bitcode3  --> score ::  0.0            SD ::  0.0   time_taken(in seconds)=  0.17496705055236816
#
# Time_Taken (in seconds):   0.37676548957824707
#
#
# Time_Taken (in seconds):   0.4119541645050049
#
#
# Time_Taken (in seconds):   0.4038712978363037
#
#
# Time_Taken (in seconds):   0.399965763092041
#
#
# Time_Taken (in seconds):   0.3866586685180664
#
# bitcode4  --> score ::  0.0            SD ::  0.0   time_taken(in seconds)=  0.1876692771911621
#
# Time_Taken (in seconds):   0.38873767852783203
#
#
# Time_Taken (in seconds):   0.3079519271850586
#
#
# Time_Taken (in seconds):   0.4346802234649658
#
#
# Time_Taken (in seconds):   0.4262528419494629
#
#
# Time_Taken (in seconds):   0.40966320037841797
#
# bitcode5  --> score ::  0.0            SD ::  0.0   time_taken(in seconds)=  0.2437899112701416
# ------------------------BACKEND-NAME ::  fake_manila
#
# Time_Taken (in seconds):   0.048399925231933594
#
#
# Time_Taken (in seconds):   0.04794621467590332
#
#
# Time_Taken (in seconds):   0.049246788024902344
#
#
# Time_Taken (in seconds):   0.05098557472229004
#
#
# Time_Taken (in seconds):   0.049288272857666016
#
# bitcode3  --> score ::  0.0            SD ::  0.0   time_taken(in seconds)=  0.017978429794311523
#
# Time_Taken (in seconds):   0.04836392402648926
#
#
# Time_Taken (in seconds):   0.1604917049407959
#
#
# Time_Taken (in seconds):   0.048970937728881836
#
#
# Time_Taken (in seconds):   0.059098005294799805
#
#
# Time_Taken (in seconds):   0.048824310302734375
#
# bitcode4  --> score ::  0.0            SD ::  0.0   time_taken(in seconds)=  0.019201040267944336
#
# Time_Taken (in seconds):   0.048525094985961914
#
#
# Time_Taken (in seconds):   0.04805469512939453
#
#
# Time_Taken (in seconds):   0.05158662796020508
#
#
# Time_Taken (in seconds):   0.0505220890045166
#
#
# Time_Taken (in seconds):   0.052910566329956055
#
# bitcode5  --> score ::  0.0            SD ::  0.0   time_taken(in seconds)=  0.03754591941833496
# ------------------------BACKEND-NAME ::  fake_yorktown
#
# Time_Taken (in seconds):   0.06143760681152344
#
#
# Time_Taken (in seconds):   0.06385016441345215
#
#
# Time_Taken (in seconds):   0.06569266319274902
#
#
# Time_Taken (in seconds):   0.06290960311889648
#
#
# Time_Taken (in seconds):   0.17681336402893066
#
# bitcode3  --> score ::  0.0            SD ::  0.0   time_taken(in seconds)=  0.025008440017700195
#
# Time_Taken (in seconds):   0.06015133857727051
#
#
# Time_Taken (in seconds):   0.062134742736816406
#
#
# Time_Taken (in seconds):   0.06595897674560547
#
#
# Time_Taken (in seconds):   0.06654834747314453
#
#
# Time_Taken (in seconds):   0.06334614753723145
#
# bitcode4  --> score ::  0.0            SD ::  0.0   time_taken(in seconds)=  0.026799917221069336
#
# Time_Taken (in seconds):   0.0650026798248291
#
#
# Time_Taken (in seconds):   0.06499528884887695
#
#
# Time_Taken (in seconds):   0.06142401695251465
#
#
# Time_Taken (in seconds):   0.06469583511352539
#
#
# Time_Taken (in seconds):   0.06919121742248535
#
# bitcode5  --> score ::  0.0            SD ::  0.0   time_taken(in seconds)=  0.0487217903137207
# ------------------------BACKEND-NAME ::  fake_almaden
#
# Time_Taken (in seconds):   0.2535984516143799
#
#
# Time_Taken (in seconds):   0.2743642330169678
#
#
# Time_Taken (in seconds):   0.2597944736480713
#
#
# Time_Taken (in seconds):   0.4020404815673828
#
#
# Time_Taken (in seconds):   0.4048888683319092
#
# bitcode3  --> score ::  0.0            SD ::  0.0   time_taken(in seconds)=  0.11705589294433594
#
# Time_Taken (in seconds):   0.4165623188018799
#
#
# Time_Taken (in seconds):   0.2566976547241211
#
#
# Time_Taken (in seconds):   0.2617964744567871
#
#
# Time_Taken (in seconds):   0.25342345237731934
#
#
# Time_Taken (in seconds):   0.4299454689025879
#
# bitcode4  --> score ::  0.0            SD ::  0.0   time_taken(in seconds)=  0.11693668365478516
#
# Time_Taken (in seconds):   0.42833542823791504
#
#
# Time_Taken (in seconds):   0.2516450881958008
#
#
# Time_Taken (in seconds):   0.25815796852111816
#
#
# Time_Taken (in seconds):   0.4419741630554199
#
#
# Time_Taken (in seconds):   0.2584376335144043
#
# bitcode5  --> score ::  0.0            SD ::  0.0   time_taken(in seconds)=  0.3191964626312256

# %%
all_scores={}  
all_fake_names=[]
all_fake_scores=[]
for i in selected_fakes:
    fakes=i
    i={}
    for label,benchmark,backend,job,score,sd in jobs:
        #supermarq.plotting.plot_results([score], [label])
        if fakes == backend:
            i[label] = score
    device_scores = 'device_score_' +str(fakes().name)
    all_scores[device_scores]= i
    all_fake_scores.append(i)
    all_fake_names.append(device_scores)

# %%
for label,benchmark,backend,job,score,sd in jobs:
    print("USED BACKEND::",backend().name,"; CIRCUIT_NAME:",label, "; SCORE =",score)
    supermarq.plotting.plot_results([score], [label])
    print("-----------------------------------------------------------")
# Out:
# USED BACKEND:: fake_armonk ; CIRCUIT_NAME: bitcode3 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_armonk ; CIRCUIT_NAME: bitcode4 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_armonk ; CIRCUIT_NAME: bitcode5 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_mumbai ; CIRCUIT_NAME: bitcode3 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_mumbai ; CIRCUIT_NAME: bitcode4 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_mumbai ; CIRCUIT_NAME: bitcode5 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_manila ; CIRCUIT_NAME: bitcode3 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_manila ; CIRCUIT_NAME: bitcode4 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_manila ; CIRCUIT_NAME: bitcode5 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_yorktown ; CIRCUIT_NAME: bitcode3 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_yorktown ; CIRCUIT_NAME: bitcode4 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_yorktown ; CIRCUIT_NAME: bitcode5 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_almaden ; CIRCUIT_NAME: bitcode3 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_almaden ; CIRCUIT_NAME: bitcode4 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_almaden ; CIRCUIT_NAME: bitcode5 ; SCORE = 0.0
# -----------------------------------------------------------

# %%
names=[]
scores=[]
X="A "+name_of_algo+' Benchamrk'
for i,j in benchmark_features.items():
    names.append(i)
    scores.append(j)
supermarq.plotting.plot_benchmark(
        [X,names,scores],
        spoke_labels=["PC", "CD", "Ent", "Liv", "Mea", "Par"],
        show=True)

# %%
supermarq.plotting.plot_correlations(benchmark_features,all_fake_scores,["PC", "CD", "Ent", "Liv", "Mea", "Par"],device_name=all_fake_names,show=True,)

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 
import numpy as np
all_fake_names=[]
all_score=[]
all_sd=[]
all_ckt=[]
for i in selected_fakes:
    all_fake_names.append(i().name)    
for benchmark, label in benchmarks:
    i=[]
    j=[]
    k=[]
    for ckt,benchmark,backend,job,score,sd in jobs:
        if ckt == label:
            i.append(score)
            j.append(sd)
    all_ckt.append(label)
    all_score.append(i)
    all_sd.append(j)
num_bars = len(all_score)
width = 0.1
x = np.arange(len(all_fake_names)) # x-axis positions for each bar
fig, ax = plt.subplots()
for i in range(num_bars):               # Create bars for each category with appropriate offsets
    ax.bar(x + i * width, all_score[i], width=width, label=f'Bar {i+1}', 
           yerr=all_sd[i],align='center',alpha=0.9,ecolor='black',capsize=2)
ax.set_xlabel('Name of Fake Backends',fontweight ='bold',fontsize = 12)
ax.set_ylabel('Scores',fontweight ='bold',fontsize = 12)
ax.set_title('Plot of GHZ over Multiple Qubits')
ax.set_xticks(x + (num_bars - 1) * width / 2)
ax.set_xticklabels(all_fake_names)
ax.legend(all_ckt,loc="lower left")
#ax.grid(True)
plt.show()
