# %%
from qiskit_aer import AerSimulator
from qiskit import *
import supermarq
from qiskit.providers.fake_provider import *
import numpy as np 
import os
import random
########## INPUT ############
f=5 # number of fake_backend want to choose
lower_limit= 9 # the lower limit of qubits for the circuit
upper_limit= 16 # the lower limit of qubits for the circuit
steps= 1 #jump in qubit numbers
name_of_algo='phase_code'

# %%
all_fakes=[FakeAlmadenV2,FakeArmonkV2,FakeAthensV2,FakeAuckland,FakeBelemV2,FakeBoeblingenV2,FakeBogotaV2,FakeBrooklynV2,FakeBurlingtonV2,FakeCairoV2,FakeCambridgeV2,FakeCasablancaV2,FakeEssexV2,FakeGeneva,FakeGuadalupeV2,FakeHanoiV2,FakeJakartaV2,FakeJohannesburgV2,FakeKolkataV2,FakeLagosV2,FakeLimaV2,FakeLondonV2,FakeManhattanV2,FakeManilaV2,FakeMelbourneV2,FakeMontrealV2,FakeMumbaiV2,FakeNairobiV2,FakeOslo,FakeOurenseV2,FakeParisV2,FakePerth,FakePrague,FakePoughkeepsieV2,FakeQuitoV2,FakeRochesterV2,FakeRomeV2,FakeSantiagoV2,FakeSherbrooke,FakeSingaporeV2,FakeSydneyV2,FakeTorontoV2,FakeValenciaV2,FakeVigoV2,FakeWashingtonV2,FakeYorktownV2]
selected_fakes = random.sample(all_fakes, f)
selected_fakes  # having any randomly selected 5 fake backends out of 46 mentioned in the inital list
# Out:
# [qiskit.providers.fake_provider.backends.quito.fake_quito.FakeQuitoV2,
#  qiskit.providers.fake_provider.backends.essex.fake_essex.FakeEssexV2,
#  qiskit.providers.fake_provider.backends.armonk.fake_armonk.FakeArmonkV2,
#  qiskit.providers.fake_provider.backends.prague.fake_prague.FakePrague,
#  qiskit.providers.fake_provider.backends.santiago.fake_santiago.FakeSantiagoV2]

# %%
benchmarks=[]
for i in range(lower_limit,upper_limit,steps):
    label = name_of_algo+str(i)
    rand_list=[]
    for j in range(i):       
        rand_list.append(random.randint(0,1))
    print("i=",i,"i-1=",i-1,"rand_list=",rand_list)
    benchmarks.append((supermarq.phase_code.PhaseCode(i,i-1,rand_list),label))
for i in benchmarks:
    circuit=i[0].qiskit_circuit()
    print("--------------------------",i[1],"---------------------------")
    #circuit.draw(output="mpl")
    print(circuit.draw())
# Out:
# i= 3 i-1= 2 rand_list= [0, 0, 1]
# i= 4 i-1= 3 rand_list= [0, 1, 0, 1]
# i= 5 i-1= 4 rand_list= [0, 1, 1, 1, 1]
# i= 6 i-1= 5 rand_list= [1, 1, 1, 1, 0, 1]
# i= 7 i-1= 6 rand_list= [1, 0, 0, 1, 1, 0, 0]
# i= 8 i-1= 7 rand_list= [1, 0, 1, 0, 0, 0, 1, 0]
# -------------------------- phase_code3 ---------------------------
#               ┌───┐┌───┐     ┌───┐┌───┐                  ┌───┐┌───┐        »
#          q_0: ┤ H ├┤ H ├──■──┤ H ├┤ H ├───────────────■──┤ H ├┤ H ├────────»
#               ├───┤└───┘  │  └───┘├───┤┌─┐     ┌───┐  │  └───┘└───┘┌───┐┌─┐»
#          q_1: ┤ H ├───────■────■──┤ H ├┤M├─|0>─┤ H ├──■─────────■──┤ H ├┤M├»
#               ├───┤┌───┐       │  ├───┤└╥┘┌───┐└───┘            │  ├───┤└╥┘»
#          q_2: ┤ H ├┤ H ├──■────■──┤ H ├─╫─┤ H ├────────────■────■──┤ H ├─╫─»
#               ├───┤└───┘  │       ├───┤ ║ └┬─┬┘     ┌───┐  │       ├───┤ ║ »
#          q_3: ┤ H ├───────■────■──┤ H ├─╫──┤M├──|0>─┤ H ├──■────■──┤ H ├─╫─»
#               ├───┤┌───┐┌───┐  │  ├───┤ ║  └╥┘ ┌───┐└───┘       │  ├───┤ ║ »
#          q_4: ┤ X ├┤ H ├┤ H ├──■──┤ H ├─╫───╫──┤ H ├────────────■──┤ H ├─╫─»
#               └───┘└───┘└───┘     └───┘ ║   ║  └───┘               └───┘ ║ »
#     m_mcm0: 2/══════════════════════════╩═══╩════════════════════════════╬═»
#                                         0   1                            ║ »
#     m_mcm1: 2/═══════════════════════════════════════════════════════════╩═»
#                                                                          0 »
# m_meas_all: 5/═════════════════════════════════════════════════════════════»
#                                                                            »
# «                        ┌─┐
# «         q_0: ──────────┤M├────────────
# «                        └╥┘      ┌─┐
# «         q_1: ─|0>───────╫───────┤M├───
# «              ┌───┐      ║ ┌─┐   └╥┘
# «         q_2: ┤ H ├──────╫─┤M├────╫────
# «              └┬─┬┘      ║ └╥┘    ║ ┌─┐
# «         q_3: ─┤M├──|0>──╫──╫─────╫─┤M├
# «               └╥┘ ┌───┐ ║  ║ ┌─┐ ║ └╥┘
# «         q_4: ──╫──┤ H ├─╫──╫─┤M├─╫──╫─
# «                ║  └───┘ ║  ║ └╥┘ ║  ║
# «    m_mcm0: 2/══╬════════╬══╬══╬══╬══╬═
# «                ║        ║  ║  ║  ║  ║
# «    m_mcm1: 2/══╩════════╬══╬══╬══╬══╬═
# «                1        ║  ║  ║  ║  ║
# «m_meas_all: 5/═══════════╩══╩══╩══╩══╩═
# «                         0  2  4  1  3
# -------------------------- phase_code4 ---------------------------
#               ┌───┐┌───┐     ┌───┐┌───┐                            ┌───┐┌───┐»
#          q_0: ┤ H ├┤ H ├──■──┤ H ├┤ H ├─────────────────────────■──┤ H ├┤ H ├»
#               ├───┤└───┘  │  └───┘└───┘┌───┐     ┌─┐     ┌───┐  │  └───┘└───┘»
#          q_1: ┤ H ├───────■─────────■──┤ H ├─────┤M├─|0>─┤ H ├──■─────────■──»
#               ├───┤┌───┐┌───┐       │  ├───┤┌───┐└╥┘     └───┘            │  »
#          q_2: ┤ X ├┤ H ├┤ H ├──■────■──┤ H ├┤ H ├─╫──────────────────■────■──»
#               ├───┤└───┘└───┘  │       ├───┤└───┘ ║  ┌─┐      ┌───┐  │       »
#          q_3: ┤ H ├────────────■────■──┤ H ├──────╫──┤M├──|0>─┤ H ├──■────■──»
#               ├───┤┌───┐            │  ├───┤┌───┐ ║  └╥┘      └───┘       │  »
#          q_4: ┤ H ├┤ H ├──■─────────■──┤ H ├┤ H ├─╫───╫──────────────■────■──»
#               ├───┤└───┘  │       ┌───┐└───┘└┬─┬┘ ║   ║       ┌───┐  │       »
#          q_5: ┤ H ├───────■────■──┤ H ├──────┤M├──╫───╫───|0>─┤ H ├──■────■──»
#               ├───┤┌───┐┌───┐  │  ├───┤┌───┐ └╥┘  ║   ║       └───┘       │  »
#          q_6: ┤ X ├┤ H ├┤ H ├──■──┤ H ├┤ H ├──╫───╫───╫───────────────────■──»
#               └───┘└───┘└───┘     └───┘└───┘  ║   ║   ║                      »
#     m_mcm0: 3/════════════════════════════════╩═══╩═══╩══════════════════════»
#                                               2   0   1                      »
#     m_mcm1: 3/═══════════════════════════════════════════════════════════════»
#                                                                              »
#     m_mcm2: 3/═══════════════════════════════════════════════════════════════»
#                                                                              »
# m_meas_all: 7/═══════════════════════════════════════════════════════════════»
#                                                                              »
# «                                               ┌───┐┌───┐                  ┌─┐»
# «         q_0: ──────────────────────────────■──┤ H ├┤ H ├──────────────────┤M├»
# «              ┌───┐          ┌─┐     ┌───┐  │  └───┘└───┘┌───┐     ┌─┐     └╥┘»
# «         q_1: ┤ H ├──────────┤M├─|0>─┤ H ├──■─────────■──┤ H ├─────┤M├─|0>──╫─»
# «              ├───┤┌───┐     └╥┘     └───┘            │  ├───┤┌───┐└╥┘      ║ »
# «         q_2: ┤ H ├┤ H ├──────╫──────────────────■────■──┤ H ├┤ H ├─╫───────╫─»
# «              ├───┤└───┘      ║  ┌─┐      ┌───┐  │       ├───┤└───┘ ║  ┌─┐  ║ »
# «         q_3: ┤ H ├───────────╫──┤M├──|0>─┤ H ├──■────■──┤ H ├──────╫──┤M├──╫─»
# «              ├───┤┌───┐      ║  └╥┘      └───┘       │  ├───┤┌───┐ ║  └╥┘  ║ »
# «         q_4: ┤ H ├┤ H ├──────╫───╫─────────■─────────■──┤ H ├┤ H ├─╫───╫───╫─»
# «              ├───┤└┬─┬┘      ║   ║  ┌───┐  │       ┌───┐└┬─┬┘└───┘ ║   ║   ║ »
# «         q_5: ┤ H ├─┤M├──|0>──╫───╫──┤ H ├──■────■──┤ H ├─┤M├──|0>──╫───╫───╫─»
# «              ├───┤ └╥┘ ┌───┐ ║   ║  └───┘       │  ├───┤ └╥┘ ┌───┐ ║   ║   ║ »
# «         q_6: ┤ H ├──╫──┤ H ├─╫───╫──────────────■──┤ H ├──╫──┤ H ├─╫───╫───╫─»
# «              └───┘  ║  └───┘ ║   ║                 └───┘  ║  └───┘ ║   ║   ║ »
# «    m_mcm0: 3/═══════╬════════╬═══╬════════════════════════╬════════╬═══╬═══╬═»
# «                     ║        ║   ║                        ║        ║   ║   ║ »
# «    m_mcm1: 3/═══════╩════════╩═══╩════════════════════════╬════════╬═══╬═══╬═»
# «                     2        0   1                        ║        ║   ║   ║ »
# «    m_mcm2: 3/═════════════════════════════════════════════╩════════╩═══╩═══╬═»
# «                                                           2        0   1   ║ »
# «m_meas_all: 7/══════════════════════════════════════════════════════════════╩═»
# «                                                                            0 »
# «
# «         q_0: ────────────────────
# «                            ┌─┐
# «         q_1: ──────────────┤M├───
# «                   ┌─┐      └╥┘
# «         q_2: ─────┤M├───────╫────
# «                   └╥┘       ║ ┌─┐
# «         q_3: ─|0>──╫────────╫─┤M├
# «                    ║ ┌─┐    ║ └╥┘
# «         q_4: ──────╫─┤M├────╫──╫─
# «                    ║ └╥┘┌─┐ ║  ║
# «         q_5: ──────╫──╫─┤M├─╫──╫─
# «               ┌─┐  ║  ║ └╥┘ ║  ║
# «         q_6: ─┤M├──╫──╫──╫──╫──╫─
# «               └╥┘  ║  ║  ║  ║  ║
# «    m_mcm0: 3/══╬═══╬══╬══╬══╬══╬═
# «                ║   ║  ║  ║  ║  ║
# «    m_mcm1: 3/══╬═══╬══╬══╬══╬══╬═
# «                ║   ║  ║  ║  ║  ║
# «    m_mcm2: 3/══╬═══╬══╬══╬══╬══╬═
# «                ║   ║  ║  ║  ║  ║
# «m_meas_all: 7/══╩═══╩══╩══╩══╩══╩═
# «                6   2  4  5  1  3
# -------------------------- phase_code5 ---------------------------
#               ┌───┐┌───┐     ┌───┐┌───┐                       ┌───┐┌───┐     »
#          q_0: ┤ H ├┤ H ├──■──┤ H ├┤ H ├────────────────────■──┤ H ├┤ H ├─────»
#               ├───┤└───┘  │  └───┘└───┘┌───┐┌─┐     ┌───┐  │  └───┘└───┘┌───┐»
#          q_1: ┤ H ├───────■─────────■──┤ H ├┤M├─|0>─┤ H ├──■─────────■──┤ H ├»
#               ├───┤┌───┐┌───┐       │  ├───┤└╥┘┌───┐└───┘            │  ├───┤»
#          q_2: ┤ X ├┤ H ├┤ H ├──■────■──┤ H ├─╫─┤ H ├────────────■────■──┤ H ├»
#               ├───┤└───┘└───┘  │       ├───┤ ║ └┬─┬┘     ┌───┐  │       └───┘»
#          q_3: ┤ H ├────────────■────■──┤ H ├─╫──┤M├──|0>─┤ H ├──■─────────■──»
#               ├───┤┌───┐┌───┐       │  ├───┤ ║  └╥┘ ┌───┐└───┘            │  »
#          q_4: ┤ X ├┤ H ├┤ H ├──■────■──┤ H ├─╫───╫──┤ H ├────────────■────■──»
#               ├───┤└───┘└───┘  │       ├───┤ ║   ║  └┬─┬┘     ┌───┐  │       »
#          q_5: ┤ H ├────────────■────■──┤ H ├─╫───╫───┤M├──|0>─┤ H ├──■───────»
#               ├───┤┌───┐┌───┐       │  ├───┤ ║   ║   └╥┘ ┌───┐└───┘          »
#          q_6: ┤ X ├┤ H ├┤ H ├──■────■──┤ H ├─╫───╫────╫──┤ H ├────────────■──»
#               ├───┤└───┘└───┘  │       ├───┤ ║   ║    ║  └┬─┬┘     ┌───┐  │  »
#          q_7: ┤ H ├────────────■────■──┤ H ├─╫───╫────╫───┤M├──|0>─┤ H ├──■──»
#               ├───┤┌───┐┌───┐       │  ├───┤ ║   ║    ║   └╥┘ ┌───┐└───┘     »
#          q_8: ┤ X ├┤ H ├┤ H ├───────■──┤ H ├─╫───╫────╫────╫──┤ H ├──────────»
#               └───┘└───┘└───┘          └───┘ ║   ║    ║    ║  └───┘          »
#     m_mcm0: 4/═══════════════════════════════╩═══╩════╩════╩═════════════════»
#                                              0   1    2    3                 »
#     m_mcm1: 4/═══════════════════════════════════════════════════════════════»
#                                                                              »
#     m_mcm2: 4/═══════════════════════════════════════════════════════════════»
#                                                                              »
#     m_mcm3: 4/═══════════════════════════════════════════════════════════════»
#                                                                              »
# m_meas_all: 9/═══════════════════════════════════════════════════════════════»
#                                                                              »
# «                                          ┌───┐┌───┐                       »
# «         q_0: ─────────────────────────■──┤ H ├┤ H ├───────────────────────»
# «                        ┌─┐     ┌───┐  │  └───┘└───┘┌───┐          ┌─┐     »
# «         q_1: ──────────┤M├─|0>─┤ H ├──■─────────■──┤ H ├──────────┤M├─|0>─»
# «              ┌───┐     └╥┘     └───┘            │  ├───┤┌───┐     └╥┘     »
# «         q_2: ┤ H ├──────╫──────────────────■────■──┤ H ├┤ H ├──────╫──────»
# «              ├───┤      ║  ┌─┐      ┌───┐  │       └───┘├───┤      ║  ┌─┐ »
# «         q_3: ┤ H ├──────╫──┤M├──|0>─┤ H ├──■─────────■──┤ H ├──────╫──┤M├─»
# «              ├───┤┌───┐ ║  └╥┘      └───┘            │  ├───┤┌───┐ ║  └╥┘ »
# «         q_4: ┤ H ├┤ H ├─╫───╫───────────────────■────■──┤ H ├┤ H ├─╫───╫──»
# «              └───┘├───┤ ║   ║   ┌─┐      ┌───┐  │       └───┘├───┤ ║   ║  »
# «         q_5: ──■──┤ H ├─╫───╫───┤M├──|0>─┤ H ├──■─────────■──┤ H ├─╫───╫──»
# «                │  ├───┤ ║   ║   └╥┘ ┌───┐└───┘            │  ├───┤ ║   ║  »
# «         q_6: ──■──┤ H ├─╫───╫────╫──┤ H ├────────────■────■──┤ H ├─╫───╫──»
# «                   ├───┤ ║   ║    ║  └┬─┬┘     ┌───┐  │       ├───┤ ║   ║  »
# «         q_7: ──■──┤ H ├─╫───╫────╫───┤M├──|0>─┤ H ├──■────■──┤ H ├─╫───╫──»
# «                │  ├───┤ ║   ║    ║   └╥┘ ┌───┐└───┘       │  ├───┤ ║   ║  »
# «         q_8: ──■──┤ H ├─╫───╫────╫────╫──┤ H ├────────────■──┤ H ├─╫───╫──»
# «                   └───┘ ║   ║    ║    ║  └───┘               └───┘ ║   ║  »
# «    m_mcm0: 4/═══════════╬═══╬════╬════╬════════════════════════════╬═══╬══»
# «                         ║   ║    ║    ║                            ║   ║  »
# «    m_mcm1: 4/═══════════╩═══╩════╩════╩════════════════════════════╬═══╬══»
# «                         0   1    2    3                            ║   ║  »
# «    m_mcm2: 4/══════════════════════════════════════════════════════╩═══╩══»
# «                                                                    0   1  »
# «    m_mcm3: 4/═════════════════════════════════════════════════════════════»
# «                                                                           »
# «m_meas_all: 9/═════════════════════════════════════════════════════════════»
# «                                                                           »
# «                        ┌───┐┌───┐                                      ┌─┐   »
# «         q_0: ───────■──┤ H ├┤ H ├──────────────────────────────────────┤M├───»
# «              ┌───┐  │  └───┘└───┘┌───┐          ┌─┐                    └╥┘   »
# «         q_1: ┤ H ├──■─────────■──┤ H ├──────────┤M├─|0>─────────────────╫────»
# «              └───┘            │  ├───┤┌───┐     └╥┘                     ║ ┌─┐»
# «         q_2: ────────────■────■──┤ H ├┤ H ├──────╫──────────────────────╫─┤M├»
# «                   ┌───┐  │       └───┘├───┤      ║  ┌─┐                 ║ └╥┘»
# «         q_3: ─|0>─┤ H ├──■─────────■──┤ H ├──────╫──┤M├──|0>────────────╫──╫─»
# «                   └───┘            │  ├───┤┌───┐ ║  └╥┘                 ║  ║ »
# «         q_4: ─────────────────■────■──┤ H ├┤ H ├─╫───╫──────────────────╫──╫─»
# «               ┌─┐      ┌───┐  │       └───┘├───┤ ║   ║   ┌─┐            ║  ║ »
# «         q_5: ─┤M├──|0>─┤ H ├──■─────────■──┤ H ├─╫───╫───┤M├──|0>───────╫──╫─»
# «               └╥┘ ┌───┐└───┘            │  ├───┤ ║   ║   └╥┘ ┌───┐      ║  ║ »
# «         q_6: ──╫──┤ H ├────────────■────■──┤ H ├─╫───╫────╫──┤ H ├──────╫──╫─»
# «                ║  └┬─┬┘     ┌───┐  │       ├───┤ ║   ║    ║  └┬─┬┘      ║  ║ »
# «         q_7: ──╫───┤M├──|0>─┤ H ├──■────■──┤ H ├─╫───╫────╫───┤M├──|0>──╫──╫─»
# «                ║   └╥┘ ┌───┐└───┘       │  ├───┤ ║   ║    ║   └╥┘ ┌───┐ ║  ║ »
# «         q_8: ──╫────╫──┤ H ├────────────■──┤ H ├─╫───╫────╫────╫──┤ H ├─╫──╫─»
# «                ║    ║  └───┘               └───┘ ║   ║    ║    ║  └───┘ ║  ║ »
# «    m_mcm0: 4/══╬════╬════════════════════════════╬═══╬════╬════╬════════╬══╬═»
# «                ║    ║                            ║   ║    ║    ║        ║  ║ »
# «    m_mcm1: 4/══╬════╬════════════════════════════╬═══╬════╬════╬════════╬══╬═»
# «                ║    ║                            ║   ║    ║    ║        ║  ║ »
# «    m_mcm2: 4/══╩════╩════════════════════════════╬═══╬════╬════╬════════╬══╬═»
# «                2    3                            ║   ║    ║    ║        ║  ║ »
# «    m_mcm3: 4/════════════════════════════════════╩═══╩════╩════╩════════╬══╬═»
# «                                                  0   1    2    3        ║  ║ »
# «m_meas_all: 9/═══════════════════════════════════════════════════════════╩══╩═»
# «                                                                         0  2 »
# «
# «         q_0: ─────────────────────
# «                       ┌─┐
# «         q_1: ─────────┤M├─────────
# «                       └╥┘
# «         q_2: ──────────╫──────────
# «                        ║ ┌─┐
# «         q_3: ──────────╫─┤M├──────
# «              ┌─┐       ║ └╥┘
# «         q_4: ┤M├───────╫──╫───────
# «              └╥┘       ║  ║ ┌─┐
# «         q_5: ─╫────────╫──╫─┤M├───
# «               ║ ┌─┐    ║  ║ └╥┘
# «         q_6: ─╫─┤M├────╫──╫──╫────
# «               ║ └╥┘    ║  ║  ║ ┌─┐
# «         q_7: ─╫──╫─────╫──╫──╫─┤M├
# «               ║  ║ ┌─┐ ║  ║  ║ └╥┘
# «         q_8: ─╫──╫─┤M├─╫──╫──╫──╫─
# «               ║  ║ └╥┘ ║  ║  ║  ║
# «    m_mcm0: 4/═╬══╬══╬══╬══╬══╬══╬═
# «               ║  ║  ║  ║  ║  ║  ║
# «    m_mcm1: 4/═╬══╬══╬══╬══╬══╬══╬═
# «               ║  ║  ║  ║  ║  ║  ║
# «    m_mcm2: 4/═╬══╬══╬══╬══╬══╬══╬═
# «               ║  ║  ║  ║  ║  ║  ║
# «    m_mcm3: 4/═╬══╬══╬══╬══╬══╬══╬═
# «               ║  ║  ║  ║  ║  ║  ║
# «m_meas_all: 9/═╩══╩══╩══╩══╩══╩══╩═
# «               4  6  8  1  3  5  7
# -------------------------- phase_code6 ---------------------------
#                ┌───┐┌───┐┌───┐   ┌───┐┌───┐                       ┌───┐┌───┐»
#           q_0: ┤ X ├┤ H ├┤ H ├─■─┤ H ├┤ H ├────────────────────■──┤ H ├┤ H ├»
#                ├───┤└───┘└───┘ │ └───┘├───┤     ┌─┐     ┌───┐  │  └───┘└───┘»
#           q_1: ┤ H ├───────────■───■──┤ H ├─────┤M├─|0>─┤ H ├──■─────────■──»
#                ├───┤┌───┐┌───┐     │  ├───┤┌───┐└╥┘     └───┘            │  »
#           q_2: ┤ X ├┤ H ├┤ H ├─■───■──┤ H ├┤ H ├─╫──────────────────■────■──»
#                ├───┤└───┘└───┘ │      ├───┤└───┘ ║  ┌─┐      ┌───┐  │       »
#           q_3: ┤ H ├───────────■───■──┤ H ├──────╫──┤M├──|0>─┤ H ├──■───────»
#                ├───┤┌───┐┌───┐     │  ├───┤┌───┐ ║  └╥┘      └───┘          »
#           q_4: ┤ X ├┤ H ├┤ H ├─■───■──┤ H ├┤ H ├─╫───╫───────────────────■──»
#                ├───┤└───┘└───┘ │      ├───┤└───┘ ║   ║   ┌─┐      ┌───┐  │  »
#           q_5: ┤ H ├───────────■───■──┤ H ├──────╫───╫───┤M├──|0>─┤ H ├──■──»
#                ├───┤┌───┐┌───┐     │  ├───┤┌───┐ ║   ║   └╥┘      └───┘     »
#           q_6: ┤ X ├┤ H ├┤ H ├─■───■──┤ H ├┤ H ├─╫───╫────╫─────────────────»
#                ├───┤└───┘└───┘ │      ├───┤└───┘ ║   ║    ║   ┌─┐      ┌───┐»
#           q_7: ┤ H ├───────────■───■──┤ H ├──────╫───╫────╫───┤M├──|0>─┤ H ├»
#                ├───┤┌───┐          │  ├───┤┌───┐ ║   ║    ║   └╥┘      └───┘»
#           q_8: ┤ H ├┤ H ├──■───────■──┤ H ├┤ H ├─╫───╫────╫────╫────────────»
#                ├───┤└───┘  │     ┌───┐└───┘└┬─┬┘ ║   ║    ║    ║       ┌───┐»
#           q_9: ┤ H ├───────■───■─┤ H ├──────┤M├──╫───╫────╫────╫───|0>─┤ H ├»
#                ├───┤┌───┐┌───┐ │ ├───┤┌───┐ └╥┘  ║   ║    ║    ║       └───┘»
#          q_10: ┤ X ├┤ H ├┤ H ├─■─┤ H ├┤ H ├──╫───╫───╫────╫────╫────────────»
#                └───┘└───┘└───┘   └───┘└───┘  ║   ║   ║    ║    ║            »
#      m_mcm0: 5/══════════════════════════════╩═══╩═══╩════╩════╩════════════»
#                                              4   0   1    2    3            »
#      m_mcm1: 5/═════════════════════════════════════════════════════════════»
#                                                                             »
#      m_mcm2: 5/═════════════════════════════════════════════════════════════»
#                                                                             »
#      m_mcm3: 5/═════════════════════════════════════════════════════════════»
#                                                                             »
#      m_mcm4: 5/═════════════════════════════════════════════════════════════»
#                                                                             »
# m_meas_all: 11/═════════════════════════════════════════════════════════════»
#                                                                             »
# «                                                          ┌───┐┌───┐          »
# «          q_0: ────────────────────────────────────────■──┤ H ├┤ H ├──────────»
# «               ┌───┐                    ┌─┐     ┌───┐  │  └───┘└───┘┌───┐     »
# «          q_1: ┤ H ├────────────────────┤M├─|0>─┤ H ├──■─────────■──┤ H ├─────»
# «               ├───┤┌───┐               └╥┘     └───┘            │  ├───┤┌───┐»
# «          q_2: ┤ H ├┤ H ├────────────────╫──────────────────■────■──┤ H ├┤ H ├»
# «               └───┘├───┤                ║  ┌─┐      ┌───┐  │       └───┘├───┤»
# «          q_3: ──■──┤ H ├────────────────╫──┤M├──|0>─┤ H ├──■─────────■──┤ H ├»
# «                 │  ├───┤┌───┐           ║  └╥┘      └───┘            │  ├───┤»
# «          q_4: ──■──┤ H ├┤ H ├───────────╫───╫───────────────────■────■──┤ H ├»
# «                    └───┘├───┤           ║   ║   ┌─┐      ┌───┐  │       └───┘»
# «          q_5: ───────■──┤ H ├───────────╫───╫───┤M├──|0>─┤ H ├──■─────────■──»
# «                      │  ├───┤┌───┐      ║   ║   └╥┘      └───┘            │  »
# «          q_6: ──■────■──┤ H ├┤ H ├──────╫───╫────╫───────────────────■────■──»
# «                 │       ├───┤└───┘      ║   ║    ║   ┌─┐      ┌───┐  │       »
# «          q_7: ──■────■──┤ H ├───────────╫───╫────╫───┤M├──|0>─┤ H ├──■────■──»
# «                      │  ├───┤┌───┐      ║   ║    ║   └╥┘      └───┘       │  »
# «          q_8: ──■────■──┤ H ├┤ H ├──────╫───╫────╫────╫─────────■─────────■──»
# «                 │       ├───┤└┬─┬┘      ║   ║    ║    ║  ┌───┐  │       ┌───┐»
# «          q_9: ──■────■──┤ H ├─┤M├──|0>──╫───╫────╫────╫──┤ H ├──■────■──┤ H ├»
# «                      │  ├───┤ └╥┘ ┌───┐ ║   ║    ║    ║  └───┘       │  ├───┤»
# «         q_10: ───────■──┤ H ├──╫──┤ H ├─╫───╫────╫────╫──────────────■──┤ H ├»
# «                         └───┘  ║  └───┘ ║   ║    ║    ║                 └───┘»
# «     m_mcm0: 5/═════════════════╬════════╬═══╬════╬════╬══════════════════════»
# «                                ║        ║   ║    ║    ║                      »
# «     m_mcm1: 5/═════════════════╩════════╩═══╩════╩════╩══════════════════════»
# «                                4        0   1    2    3                      »
# «     m_mcm2: 5/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «     m_mcm3: 5/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «     m_mcm4: 5/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «m_meas_all: 11/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «                                           ┌───┐┌───┐                       »
# «          q_0: ─────────────────────────■──┤ H ├┤ H ├───────────────────────»
# «                         ┌─┐     ┌───┐  │  └───┘└───┘┌───┐               ┌─┐»
# «          q_1: ──────────┤M├─|0>─┤ H ├──■─────────■──┤ H ├───────────────┤M├»
# «                         └╥┘     └───┘            │  ├───┤┌───┐          └╥┘»
# «          q_2: ───────────╫──────────────────■────■──┤ H ├┤ H ├───────────╫─»
# «                          ║  ┌─┐      ┌───┐  │       └───┘├───┤           ║ »
# «          q_3: ───────────╫──┤M├──|0>─┤ H ├──■─────────■──┤ H ├───────────╫─»
# «               ┌───┐      ║  └╥┘      └───┘            │  ├───┤┌───┐      ║ »
# «          q_4: ┤ H ├──────╫───╫───────────────────■────■──┤ H ├┤ H ├──────╫─»
# «               ├───┤      ║   ║   ┌─┐      ┌───┐  │       └───┘├───┤      ║ »
# «          q_5: ┤ H ├──────╫───╫───┤M├──|0>─┤ H ├──■─────────■──┤ H ├──────╫─»
# «               ├───┤┌───┐ ║   ║   └╥┘      └───┘            │  ├───┤┌───┐ ║ »
# «          q_6: ┤ H ├┤ H ├─╫───╫────╫───────────────────■────■──┤ H ├┤ H ├─╫─»
# «               ├───┤└───┘ ║   ║    ║   ┌─┐      ┌───┐  │       ├───┤└───┘ ║ »
# «          q_7: ┤ H ├──────╫───╫────╫───┤M├──|0>─┤ H ├──■────■──┤ H ├──────╫─»
# «               ├───┤┌───┐ ║   ║    ║   └╥┘      └───┘       │  ├───┤┌───┐ ║ »
# «          q_8: ┤ H ├┤ H ├─╫───╫────╫────╫─────────■─────────■──┤ H ├┤ H ├─╫─»
# «               └┬─┬┘└───┘ ║   ║    ║    ║  ┌───┐  │       ┌───┐└┬─┬┘└───┘ ║ »
# «          q_9: ─┤M├──|0>──╫───╫────╫────╫──┤ H ├──■────■──┤ H ├─┤M├──|0>──╫─»
# «                └╥┘ ┌───┐ ║   ║    ║    ║  └───┘       │  ├───┤ └╥┘ ┌───┐ ║ »
# «         q_10: ──╫──┤ H ├─╫───╫────╫────╫──────────────■──┤ H ├──╫──┤ H ├─╫─»
# «                 ║  └───┘ ║   ║    ║    ║                 └───┘  ║  └───┘ ║ »
# «     m_mcm0: 5/══╬════════╬═══╬════╬════╬════════════════════════╬════════╬═»
# «                 ║        ║   ║    ║    ║                        ║        ║ »
# «     m_mcm1: 5/══╬════════╬═══╬════╬════╬════════════════════════╬════════╬═»
# «                 ║        ║   ║    ║    ║                        ║        ║ »
# «     m_mcm2: 5/══╩════════╩═══╩════╩════╩════════════════════════╬════════╬═»
# «                 4        0   1    2    3                        ║        ║ »
# «     m_mcm3: 5/══════════════════════════════════════════════════╩════════╩═»
# «                                                                 4        0 »
# «     m_mcm4: 5/═════════════════════════════════════════════════════════════»
# «                                                                            »
# «m_meas_all: 11/═════════════════════════════════════════════════════════════»
# «                                                                            »
# «                              ┌───┐┌───┐                                      »
# «          q_0: ────────────■──┤ H ├┤ H ├──────────────────────────────────────»
# «                    ┌───┐  │  └───┘└───┘┌───┐               ┌─┐               »
# «          q_1: ─|0>─┤ H ├──■─────────■──┤ H ├───────────────┤M├─|0>───────────»
# «                    └───┘            │  ├───┤┌───┐          └╥┘               »
# «          q_2: ─────────────────■────■──┤ H ├┤ H ├───────────╫────────────────»
# «                ┌─┐      ┌───┐  │       └───┘├───┤           ║  ┌─┐           »
# «          q_3: ─┤M├──|0>─┤ H ├──■─────────■──┤ H ├───────────╫──┤M├──|0>──────»
# «                └╥┘      └───┘            │  ├───┤┌───┐      ║  └╥┘           »
# «          q_4: ──╫───────────────────■────■──┤ H ├┤ H ├──────╫───╫────────────»
# «                 ║   ┌─┐      ┌───┐  │       └───┘├───┤      ║   ║   ┌─┐      »
# «          q_5: ──╫───┤M├──|0>─┤ H ├──■─────────■──┤ H ├──────╫───╫───┤M├──|0>─»
# «                 ║   └╥┘      └───┘            │  ├───┤┌───┐ ║   ║   └╥┘      »
# «          q_6: ──╫────╫───────────────────■────■──┤ H ├┤ H ├─╫───╫────╫───────»
# «                 ║    ║   ┌─┐      ┌───┐  │       ├───┤└───┘ ║   ║    ║   ┌─┐ »
# «          q_7: ──╫────╫───┤M├──|0>─┤ H ├──■────■──┤ H ├──────╫───╫────╫───┤M├─»
# «                 ║    ║   └╥┘      └───┘       │  ├───┤┌───┐ ║   ║    ║   └╥┘ »
# «          q_8: ──╫────╫────╫─────────■─────────■──┤ H ├┤ H ├─╫───╫────╫────╫──»
# «                 ║    ║    ║  ┌───┐  │       ┌───┐└┬─┬┘└───┘ ║   ║    ║    ║  »
# «          q_9: ──╫────╫────╫──┤ H ├──■────■──┤ H ├─┤M├──|0>──╫───╫────╫────╫──»
# «                 ║    ║    ║  └───┘       │  ├───┤ └╥┘ ┌───┐ ║   ║    ║    ║  »
# «         q_10: ──╫────╫────╫──────────────■──┤ H ├──╫──┤ H ├─╫───╫────╫────╫──»
# «                 ║    ║    ║                 └───┘  ║  └───┘ ║   ║    ║    ║  »
# «     m_mcm0: 5/══╬════╬════╬════════════════════════╬════════╬═══╬════╬════╬══»
# «                 ║    ║    ║                        ║        ║   ║    ║    ║  »
# «     m_mcm1: 5/══╬════╬════╬════════════════════════╬════════╬═══╬════╬════╬══»
# «                 ║    ║    ║                        ║        ║   ║    ║    ║  »
# «     m_mcm2: 5/══╬════╬════╬════════════════════════╬════════╬═══╬════╬════╬══»
# «                 ║    ║    ║                        ║        ║   ║    ║    ║  »
# «     m_mcm3: 5/══╩════╩════╩════════════════════════╬════════╬═══╬════╬════╬══»
# «                 1    2    3                        ║        ║   ║    ║    ║  »
# «     m_mcm4: 5/═════════════════════════════════════╩════════╩═══╩════╩════╩══»
# «                                                    4        0   1    2    3  »
# «m_meas_all: 11/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «               ┌─┐
# «          q_0: ┤M├────────────────────────────────
# «               └╥┘                    ┌─┐
# «          q_1: ─╫─────────────────────┤M├─────────
# «                ║      ┌─┐            └╥┘
# «          q_2: ─╫──────┤M├─────────────╫──────────
# «                ║      └╥┘             ║ ┌─┐
# «          q_3: ─╫───────╫──────────────╫─┤M├──────
# «                ║       ║ ┌─┐          ║ └╥┘
# «          q_4: ─╫───────╫─┤M├──────────╫──╫───────
# «                ║       ║ └╥┘          ║  ║ ┌─┐
# «          q_5: ─╫───────╫──╫───────────╫──╫─┤M├───
# «                ║       ║  ║ ┌─┐       ║  ║ └╥┘
# «          q_6: ─╫───────╫──╫─┤M├───────╫──╫──╫────
# «                ║       ║  ║ └╥┘       ║  ║  ║ ┌─┐
# «          q_7: ─╫──|0>──╫──╫──╫────────╫──╫──╫─┤M├
# «                ║       ║  ║  ║ ┌─┐    ║  ║  ║ └╥┘
# «          q_8: ─╫───────╫──╫──╫─┤M├────╫──╫──╫──╫─
# «                ║       ║  ║  ║ └╥┘┌─┐ ║  ║  ║  ║
# «          q_9: ─╫───────╫──╫──╫──╫─┤M├─╫──╫──╫──╫─
# «                ║  ┌─┐  ║  ║  ║  ║ └╥┘ ║  ║  ║  ║
# «         q_10: ─╫──┤M├──╫──╫──╫──╫──╫──╫──╫──╫──╫─
# «                ║  └╥┘  ║  ║  ║  ║  ║  ║  ║  ║  ║
# «     m_mcm0: 5/═╬═══╬═══╬══╬══╬══╬══╬══╬══╬══╬══╬═
# «                ║   ║   ║  ║  ║  ║  ║  ║  ║  ║  ║
# «     m_mcm1: 5/═╬═══╬═══╬══╬══╬══╬══╬══╬══╬══╬══╬═
# «                ║   ║   ║  ║  ║  ║  ║  ║  ║  ║  ║
# «     m_mcm2: 5/═╬═══╬═══╬══╬══╬══╬══╬══╬══╬══╬══╬═
# «                ║   ║   ║  ║  ║  ║  ║  ║  ║  ║  ║
# «     m_mcm3: 5/═╬═══╬═══╬══╬══╬══╬══╬══╬══╬══╬══╬═
# «                ║   ║   ║  ║  ║  ║  ║  ║  ║  ║  ║
# «     m_mcm4: 5/═╬═══╬═══╬══╬══╬══╬══╬══╬══╬══╬══╬═
# «                ║   ║   ║  ║  ║  ║  ║  ║  ║  ║  ║
# «m_meas_all: 11/═╩═══╩═══╩══╩══╩══╩══╩══╩══╩══╩══╩═
# «                0   10  2  4  6  8  9  1  3  5  7
# -------------------------- phase_code7 ---------------------------
#                ┌───┐┌───┐┌───┐   ┌───┐┌───┐                            ┌───┐»
#           q_0: ┤ X ├┤ H ├┤ H ├─■─┤ H ├┤ H ├─────────────────────────■──┤ H ├»
#                ├───┤└───┘└───┘ │ └───┘├───┤          ┌─┐     ┌───┐  │  └───┘»
#           q_1: ┤ H ├───────────■───■──┤ H ├──────────┤M├─|0>─┤ H ├──■────■──»
#                ├───┤┌───┐          │  ├───┤┌───┐     └╥┘     └───┘       │  »
#           q_2: ┤ H ├┤ H ├──■───────■──┤ H ├┤ H ├──────╫────────■─────────■──»
#                ├───┤└───┘  │     ┌───┐└───┘└┬─┬┘      ║ ┌───┐  │            »
#           q_3: ┤ H ├───────■───■─┤ H ├──────┤M├──|0>──╫─┤ H ├──■────────────»
#                ├───┤┌───┐      │ ├───┤┌───┐ └╥┘       ║ └───┘               »
#           q_4: ┤ H ├┤ H ├──■───■─┤ H ├┤ H ├──╫────────╫──────────────────■──»
#                ├───┤└───┘  │     └───┘├───┤  ║        ║  ┌─┐      ┌───┐  │  »
#           q_5: ┤ H ├───────■───────■──┤ H ├──╫────────╫──┤M├──|0>─┤ H ├──■──»
#                ├───┤┌───┐┌───┐     │  ├───┤  ║  ┌───┐ ║  └╥┘      └───┘     »
#           q_6: ┤ X ├┤ H ├┤ H ├─■───■──┤ H ├──╫──┤ H ├─╫───╫─────────────────»
#                ├───┤└───┘└───┘ │      ├───┤  ║  └───┘ ║   ║   ┌─┐      ┌───┐»
#           q_7: ┤ H ├───────────■───■──┤ H ├──╫────────╫───╫───┤M├──|0>─┤ H ├»
#                ├───┤┌───┐┌───┐     │  ├───┤  ║  ┌───┐ ║   ║   └╥┘      └───┘»
#           q_8: ┤ X ├┤ H ├┤ H ├─■───■──┤ H ├──╫──┤ H ├─╫───╫────╫────────────»
#                ├───┤└───┘└───┘ │      ├───┤  ║  └───┘ ║   ║    ║   ┌─┐      »
#           q_9: ┤ H ├───────────■───■──┤ H ├──╫────────╫───╫────╫───┤M├──|0>─»
#                ├───┤┌───┐          │  ├───┤  ║  ┌───┐ ║   ║    ║   └╥┘      »
#          q_10: ┤ H ├┤ H ├──■───────■──┤ H ├──╫──┤ H ├─╫───╫────╫────╫───────»
#                ├───┤└───┘  │     ┌───┐└───┘  ║  └┬─┬┘ ║   ║    ║    ║       »
#          q_11: ┤ H ├───────■───■─┤ H ├───────╫───┤M├──╫───╫────╫────╫───|0>─»
#                ├───┤┌───┐      │ ├───┤┌───┐  ║   └╥┘  ║   ║    ║    ║       »
#          q_12: ┤ H ├┤ H ├──────■─┤ H ├┤ H ├──╫────╫───╫───╫────╫────╫───────»
#                └───┘└───┘        └───┘└───┘  ║    ║   ║   ║    ║    ║       »
#      m_mcm0: 6/══════════════════════════════╩════╩═══╩═══╩════╩════╩═══════»
#                                              1    5   0   2    3    4       »
#      m_mcm1: 6/═════════════════════════════════════════════════════════════»
#                                                                             »
#      m_mcm2: 6/═════════════════════════════════════════════════════════════»
#                                                                             »
#      m_mcm3: 6/═════════════════════════════════════════════════════════════»
#                                                                             »
#      m_mcm4: 6/═════════════════════════════════════════════════════════════»
#                                                                             »
#      m_mcm5: 6/═════════════════════════════════════════════════════════════»
#                                                                             »
# m_meas_all: 13/═════════════════════════════════════════════════════════════»
#                                                                             »
# «               ┌───┐                                           ┌───┐┌───┐     »
# «          q_0: ┤ H ├────────────────────────────────────────■──┤ H ├┤ H ├─────»
# «               ├───┤                         ┌─┐     ┌───┐  │  └───┘└───┘┌───┐»
# «          q_1: ┤ H ├─────────────────────────┤M├─|0>─┤ H ├──■─────────■──┤ H ├»
# «               ├───┤┌───┐                    └╥┘     └───┘            │  ├───┤»
# «          q_2: ┤ H ├┤ H ├─────────────────────╫──────────────────■────■──┤ H ├»
# «               └───┘├───┤                     ║  ┌─┐      ┌───┐  │       └───┘»
# «          q_3: ──■──┤ H ├─────────────────────╫──┤M├──|0>─┤ H ├──■─────────■──»
# «                 │  ├───┤┌───┐                ║  └╥┘      └───┘            │  »
# «          q_4: ──■──┤ H ├┤ H ├────────────────╫───╫───────────────────■────■──»
# «                    └───┘├───┤                ║   ║   ┌─┐      ┌───┐  │       »
# «          q_5: ───────■──┤ H ├────────────────╫───╫───┤M├──|0>─┤ H ├──■───────»
# «                      │  ├───┤┌───┐           ║   ║   └╥┘      └───┘          »
# «          q_6: ──■────■──┤ H ├┤ H ├───────────╫───╫────╫───────────────────■──»
# «                 │       └───┘├───┤           ║   ║    ║   ┌─┐      ┌───┐  │  »
# «          q_7: ──■─────────■──┤ H ├───────────╫───╫────╫───┤M├──|0>─┤ H ├──■──»
# «                           │  ├───┤┌───┐      ║   ║    ║   └╥┘      └───┘     »
# «          q_8: ───────■────■──┤ H ├┤ H ├──────╫───╫────╫────╫─────────────────»
# «               ┌───┐  │       ├───┤└───┘      ║   ║    ║    ║   ┌─┐      ┌───┐»
# «          q_9: ┤ H ├──■────■──┤ H ├───────────╫───╫────╫────╫───┤M├──|0>─┤ H ├»
# «               └───┘       │  ├───┤┌───┐      ║   ║    ║    ║   └╥┘      └───┘»
# «         q_10: ───────■────■──┤ H ├┤ H ├──────╫───╫────╫────╫────╫─────────■──»
# «               ┌───┐  │       ├───┤└┬─┬┘      ║   ║    ║    ║    ║  ┌───┐  │  »
# «         q_11: ┤ H ├──■────■──┤ H ├─┤M├──|0>──╫───╫────╫────╫────╫──┤ H ├──■──»
# «               └───┘       │  ├───┤ └╥┘ ┌───┐ ║   ║    ║    ║    ║  └───┘     »
# «         q_12: ────────────■──┤ H ├──╫──┤ H ├─╫───╫────╫────╫────╫────────────»
# «                              └───┘  ║  └───┘ ║   ║    ║    ║    ║            »
# «     m_mcm0: 6/══════════════════════╬════════╬═══╬════╬════╬════╬════════════»
# «                                     ║        ║   ║    ║    ║    ║            »
# «     m_mcm1: 6/══════════════════════╩════════╩═══╩════╩════╩════╩════════════»
# «                                     5        0   1    2    3    4            »
# «     m_mcm2: 6/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «     m_mcm3: 6/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «     m_mcm4: 6/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «     m_mcm5: 6/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «m_meas_all: 13/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «                                                     ┌───┐┌───┐               »
# «          q_0: ───────────────────────────────────■──┤ H ├┤ H ├───────────────»
# «                                   ┌─┐     ┌───┐  │  └───┘└───┘┌───┐          »
# «          q_1: ────────────────────┤M├─|0>─┤ H ├──■─────────■──┤ H ├──────────»
# «               ┌───┐               └╥┘     └───┘            │  ├───┤┌───┐     »
# «          q_2: ┤ H ├────────────────╫──────────────────■────■──┤ H ├┤ H ├─────»
# «               ├───┤                ║  ┌─┐      ┌───┐  │       └───┘├───┤     »
# «          q_3: ┤ H ├────────────────╫──┤M├──|0>─┤ H ├──■─────────■──┤ H ├─────»
# «               ├───┤┌───┐           ║  └╥┘      └───┘            │  ├───┤┌───┐»
# «          q_4: ┤ H ├┤ H ├───────────╫───╫───────────────────■────■──┤ H ├┤ H ├»
# «               └───┘├───┤           ║   ║   ┌─┐      ┌───┐  │       └───┘├───┤»
# «          q_5: ──■──┤ H ├───────────╫───╫───┤M├──|0>─┤ H ├──■─────────■──┤ H ├»
# «                 │  ├───┤┌───┐      ║   ║   └╥┘      └───┘            │  ├───┤»
# «          q_6: ──■──┤ H ├┤ H ├──────╫───╫────╫───────────────────■────■──┤ H ├»
# «                    └───┘├───┤      ║   ║    ║   ┌─┐      ┌───┐  │       └───┘»
# «          q_7: ───────■──┤ H ├──────╫───╫────╫───┤M├──|0>─┤ H ├──■─────────■──»
# «                      │  ├───┤┌───┐ ║   ║    ║   └╥┘      └───┘            │  »
# «          q_8: ──■────■──┤ H ├┤ H ├─╫───╫────╫────╫───────────────────■────■──»
# «                 │       ├───┤└───┘ ║   ║    ║    ║   ┌─┐      ┌───┐  │       »
# «          q_9: ──■────■──┤ H ├──────╫───╫────╫────╫───┤M├──|0>─┤ H ├──■────■──»
# «                      │  ├───┤┌───┐ ║   ║    ║    ║   └╥┘      └───┘       │  »
# «         q_10: ───────■──┤ H ├┤ H ├─╫───╫────╫────╫────╫─────────■─────────■──»
# «                    ┌───┐└┬─┬┘└───┘ ║   ║    ║    ║    ║  ┌───┐  │       ┌───┐»
# «         q_11: ──■──┤ H ├─┤M├──|0>──╫───╫────╫────╫────╫──┤ H ├──■────■──┤ H ├»
# «                 │  ├───┤ └╥┘ ┌───┐ ║   ║    ║    ║    ║  └───┘       │  ├───┤»
# «         q_12: ──■──┤ H ├──╫──┤ H ├─╫───╫────╫────╫────╫──────────────■──┤ H ├»
# «                    └───┘  ║  └───┘ ║   ║    ║    ║    ║                 └───┘»
# «     m_mcm0: 6/════════════╬════════╬═══╬════╬════╬════╬══════════════════════»
# «                           ║        ║   ║    ║    ║    ║                      »
# «     m_mcm1: 6/════════════╬════════╬═══╬════╬════╬════╬══════════════════════»
# «                           ║        ║   ║    ║    ║    ║                      »
# «     m_mcm2: 6/════════════╩════════╩═══╩════╩════╩════╩══════════════════════»
# «                           5        0   1    2    3    4                      »
# «     m_mcm3: 6/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «     m_mcm4: 6/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «     m_mcm5: 6/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «m_meas_all: 13/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «                                           ┌───┐┌───┐                         »
# «          q_0: ─────────────────────────■──┤ H ├┤ H ├─────────────────────────»
# «                         ┌─┐     ┌───┐  │  └───┘└───┘┌───┐                    »
# «          q_1: ──────────┤M├─|0>─┤ H ├──■─────────■──┤ H ├────────────────────»
# «                         └╥┘     └───┘            │  ├───┤┌───┐               »
# «          q_2: ───────────╫──────────────────■────■──┤ H ├┤ H ├───────────────»
# «                          ║  ┌─┐      ┌───┐  │       └───┘├───┤               »
# «          q_3: ───────────╫──┤M├──|0>─┤ H ├──■─────────■──┤ H ├───────────────»
# «                          ║  └╥┘      └───┘            │  ├───┤┌───┐          »
# «          q_4: ───────────╫───╫───────────────────■────■──┤ H ├┤ H ├──────────»
# «                          ║   ║   ┌─┐      ┌───┐  │       └───┘├───┤          »
# «          q_5: ───────────╫───╫───┤M├──|0>─┤ H ├──■─────────■──┤ H ├──────────»
# «               ┌───┐      ║   ║   └╥┘      └───┘            │  ├───┤┌───┐     »
# «          q_6: ┤ H ├──────╫───╫────╫───────────────────■────■──┤ H ├┤ H ├─────»
# «               ├───┤      ║   ║    ║   ┌─┐      ┌───┐  │       └───┘├───┤     »
# «          q_7: ┤ H ├──────╫───╫────╫───┤M├──|0>─┤ H ├──■─────────■──┤ H ├─────»
# «               ├───┤┌───┐ ║   ║    ║   └╥┘      └───┘            │  ├───┤┌───┐»
# «          q_8: ┤ H ├┤ H ├─╫───╫────╫────╫───────────────────■────■──┤ H ├┤ H ├»
# «               ├───┤└───┘ ║   ║    ║    ║   ┌─┐      ┌───┐  │       ├───┤└───┘»
# «          q_9: ┤ H ├──────╫───╫────╫────╫───┤M├──|0>─┤ H ├──■────■──┤ H ├─────»
# «               ├───┤┌───┐ ║   ║    ║    ║   └╥┘      └───┘       │  ├───┤┌───┐»
# «         q_10: ┤ H ├┤ H ├─╫───╫────╫────╫────╫─────────■─────────■──┤ H ├┤ H ├»
# «               └┬─┬┘└───┘ ║   ║    ║    ║    ║  ┌───┐  │       ┌───┐└┬─┬┘└───┘»
# «         q_11: ─┤M├──|0>──╫───╫────╫────╫────╫──┤ H ├──■────■──┤ H ├─┤M├──|0>─»
# «                └╥┘ ┌───┐ ║   ║    ║    ║    ║  └───┘       │  ├───┤ └╥┘ ┌───┐»
# «         q_12: ──╫──┤ H ├─╫───╫────╫────╫────╫──────────────■──┤ H ├──╫──┤ H ├»
# «                 ║  └───┘ ║   ║    ║    ║    ║                 └───┘  ║  └───┘»
# «     m_mcm0: 6/══╬════════╬═══╬════╬════╬════╬════════════════════════╬═══════»
# «                 ║        ║   ║    ║    ║    ║                        ║       »
# «     m_mcm1: 6/══╬════════╬═══╬════╬════╬════╬════════════════════════╬═══════»
# «                 ║        ║   ║    ║    ║    ║                        ║       »
# «     m_mcm2: 6/══╬════════╬═══╬════╬════╬════╬════════════════════════╬═══════»
# «                 ║        ║   ║    ║    ║    ║                        ║       »
# «     m_mcm3: 6/══╩════════╩═══╩════╩════╩════╩════════════════════════╬═══════»
# «                 5        0   1    2    3    4                        ║       »
# «     m_mcm4: 6/═══════════════════════════════════════════════════════╩═══════»
# «                                                                      5       »
# «     m_mcm5: 6/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «m_meas_all: 13/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «                                 ┌───┐┌───┐                                 »
# «          q_0: ───────────────■──┤ H ├┤ H ├─────────────────────────────────»
# «               ┌─┐     ┌───┐  │  └───┘└───┘┌───┐                    ┌─┐     »
# «          q_1: ┤M├─|0>─┤ H ├──■─────────■──┤ H ├────────────────────┤M├─|0>─»
# «               └╥┘     └───┘            │  ├───┤┌───┐               └╥┘     »
# «          q_2: ─╫──────────────────■────■──┤ H ├┤ H ├────────────────╫──────»
# «                ║  ┌─┐      ┌───┐  │       └───┘├───┤                ║  ┌─┐ »
# «          q_3: ─╫──┤M├──|0>─┤ H ├──■─────────■──┤ H ├────────────────╫──┤M├─»
# «                ║  └╥┘      └───┘            │  ├───┤┌───┐           ║  └╥┘ »
# «          q_4: ─╫───╫───────────────────■────■──┤ H ├┤ H ├───────────╫───╫──»
# «                ║   ║   ┌─┐      ┌───┐  │       └───┘├───┤           ║   ║  »
# «          q_5: ─╫───╫───┤M├──|0>─┤ H ├──■─────────■──┤ H ├───────────╫───╫──»
# «                ║   ║   └╥┘      └───┘            │  ├───┤┌───┐      ║   ║  »
# «          q_6: ─╫───╫────╫───────────────────■────■──┤ H ├┤ H ├──────╫───╫──»
# «                ║   ║    ║   ┌─┐      ┌───┐  │       └───┘├───┤      ║   ║  »
# «          q_7: ─╫───╫────╫───┤M├──|0>─┤ H ├──■─────────■──┤ H ├──────╫───╫──»
# «                ║   ║    ║   └╥┘      └───┘            │  ├───┤┌───┐ ║   ║  »
# «          q_8: ─╫───╫────╫────╫───────────────────■────■──┤ H ├┤ H ├─╫───╫──»
# «                ║   ║    ║    ║   ┌─┐      ┌───┐  │       ├───┤└───┘ ║   ║  »
# «          q_9: ─╫───╫────╫────╫───┤M├──|0>─┤ H ├──■────■──┤ H ├──────╫───╫──»
# «                ║   ║    ║    ║   └╥┘      └───┘       │  ├───┤┌───┐ ║   ║  »
# «         q_10: ─╫───╫────╫────╫────╫─────────■─────────■──┤ H ├┤ H ├─╫───╫──»
# «                ║   ║    ║    ║    ║  ┌───┐  │       ┌───┐└┬─┬┘└───┘ ║   ║  »
# «         q_11: ─╫───╫────╫────╫────╫──┤ H ├──■────■──┤ H ├─┤M├──|0>──╫───╫──»
# «                ║   ║    ║    ║    ║  └───┘       │  ├───┤ └╥┘ ┌───┐ ║   ║  »
# «         q_12: ─╫───╫────╫────╫────╫──────────────■──┤ H ├──╫──┤ H ├─╫───╫──»
# «                ║   ║    ║    ║    ║                 └───┘  ║  └───┘ ║   ║  »
# «     m_mcm0: 6/═╬═══╬════╬════╬════╬════════════════════════╬════════╬═══╬══»
# «                ║   ║    ║    ║    ║                        ║        ║   ║  »
# «     m_mcm1: 6/═╬═══╬════╬════╬════╬════════════════════════╬════════╬═══╬══»
# «                ║   ║    ║    ║    ║                        ║        ║   ║  »
# «     m_mcm2: 6/═╬═══╬════╬════╬════╬════════════════════════╬════════╬═══╬══»
# «                ║   ║    ║    ║    ║                        ║        ║   ║  »
# «     m_mcm3: 6/═╬═══╬════╬════╬════╬════════════════════════╬════════╬═══╬══»
# «                ║   ║    ║    ║    ║                        ║        ║   ║  »
# «     m_mcm4: 6/═╩═══╩════╩════╩════╩════════════════════════╬════════╬═══╬══»
# «                0   1    2    3    4                        ║        ║   ║  »
# «     m_mcm5: 6/═════════════════════════════════════════════╩════════╩═══╩══»
# «                                                            5        0   1  »
# «m_meas_all: 13/═════════════════════════════════════════════════════════════»
# «                                                                            »
# «                              ┌─┐
# «          q_0: ───────────────┤M├──────────────────────────────────────
# «                              └╥┘                       ┌─┐
# «          q_1: ────────────────╫────────────────────────┤M├────────────
# «                               ║      ┌─┐               └╥┘
# «          q_2: ────────────────╫──────┤M├────────────────╫─────────────
# «                               ║      └╥┘                ║ ┌─┐
# «          q_3: ─|0>────────────╫───────╫─────────────────╫─┤M├─────────
# «                               ║       ║ ┌─┐             ║ └╥┘
# «          q_4: ────────────────╫───────╫─┤M├─────────────╫──╫──────────
# «                ┌─┐            ║       ║ └╥┘             ║  ║ ┌─┐
# «          q_5: ─┤M├──|0>───────╫───────╫──╫──────────────╫──╫─┤M├──────
# «                └╥┘            ║       ║  ║ ┌─┐          ║  ║ └╥┘
# «          q_6: ──╫─────────────╫───────╫──╫─┤M├──────────╫──╫──╫───────
# «                 ║   ┌─┐       ║       ║  ║ └╥┘          ║  ║  ║ ┌─┐
# «          q_7: ──╫───┤M├──|0>──╫───────╫──╫──╫───────────╫──╫──╫─┤M├───
# «                 ║   └╥┘       ║       ║  ║  ║ ┌─┐       ║  ║  ║ └╥┘
# «          q_8: ──╫────╫────────╫───────╫──╫──╫─┤M├───────╫──╫──╫──╫────
# «                 ║    ║   ┌─┐  ║       ║  ║  ║ └╥┘       ║  ║  ║  ║ ┌─┐
# «          q_9: ──╫────╫───┤M├──╫──|0>──╫──╫──╫──╫────────╫──╫──╫──╫─┤M├
# «                 ║    ║   └╥┘  ║       ║  ║  ║  ║ ┌─┐    ║  ║  ║  ║ └╥┘
# «         q_10: ──╫────╫────╫───╫───────╫──╫──╫──╫─┤M├────╫──╫──╫──╫──╫─
# «                 ║    ║    ║   ║       ║  ║  ║  ║ └╥┘┌─┐ ║  ║  ║  ║  ║
# «         q_11: ──╫────╫────╫───╫───────╫──╫──╫──╫──╫─┤M├─╫──╫──╫──╫──╫─
# «                 ║    ║    ║   ║  ┌─┐  ║  ║  ║  ║  ║ └╥┘ ║  ║  ║  ║  ║
# «         q_12: ──╫────╫────╫───╫──┤M├──╫──╫──╫──╫──╫──╫──╫──╫──╫──╫──╫─
# «                 ║    ║    ║   ║  └╥┘  ║  ║  ║  ║  ║  ║  ║  ║  ║  ║  ║
# «     m_mcm0: 6/══╬════╬════╬═══╬═══╬═══╬══╬══╬══╬══╬══╬══╬══╬══╬══╬══╬═
# «                 ║    ║    ║   ║   ║   ║  ║  ║  ║  ║  ║  ║  ║  ║  ║  ║
# «     m_mcm1: 6/══╬════╬════╬═══╬═══╬═══╬══╬══╬══╬══╬══╬══╬══╬══╬══╬══╬═
# «                 ║    ║    ║   ║   ║   ║  ║  ║  ║  ║  ║  ║  ║  ║  ║  ║
# «     m_mcm2: 6/══╬════╬════╬═══╬═══╬═══╬══╬══╬══╬══╬══╬══╬══╬══╬══╬══╬═
# «                 ║    ║    ║   ║   ║   ║  ║  ║  ║  ║  ║  ║  ║  ║  ║  ║
# «     m_mcm3: 6/══╬════╬════╬═══╬═══╬═══╬══╬══╬══╬══╬══╬══╬══╬══╬══╬══╬═
# «                 ║    ║    ║   ║   ║   ║  ║  ║  ║  ║  ║  ║  ║  ║  ║  ║
# «     m_mcm4: 6/══╬════╬════╬═══╬═══╬═══╬══╬══╬══╬══╬══╬══╬══╬══╬══╬══╬═
# «                 ║    ║    ║   ║   ║   ║  ║  ║  ║  ║  ║  ║  ║  ║  ║  ║
# «     m_mcm5: 6/══╩════╩════╩═══╬═══╬═══╬══╬══╬══╬══╬══╬══╬══╬══╬══╬══╬═
# «                 2    3    4   ║   ║   ║  ║  ║  ║  ║  ║  ║  ║  ║  ║  ║
# «m_meas_all: 13/════════════════╩═══╩═══╩══╩══╩══╩══╩══╩══╩══╩══╩══╩══╩═
# «                               0   12  2  4  6  8  10 11 1  3  5  7  9
# -------------------------- phase_code8 ---------------------------
#                ┌───┐┌───┐┌───┐   ┌───┐┌───┐                            ┌───┐»
#           q_0: ┤ X ├┤ H ├┤ H ├─■─┤ H ├┤ H ├─────────────────────────■──┤ H ├»
#                ├───┤└───┘└───┘ │ └───┘├───┤          ┌─┐     ┌───┐  │  └───┘»
#           q_1: ┤ H ├───────────■───■──┤ H ├──────────┤M├─|0>─┤ H ├──■───────»
#                ├───┤┌───┐          │  ├───┤┌───┐     └╥┘     └───┘          »
#           q_2: ┤ H ├┤ H ├──■───────■──┤ H ├┤ H ├──────╫──────────────────■──»
# ...
# «               ┌───┐           ║   ║   └╥┘      └───┘            │  ├───┤┌───┐»
# «          q_6: ┤ H ├───────────╫───╫────╫───────────────────■────■──┤ H ├┤ H ├»
# «               ├───┤           ║   ║    ║   ┌─┐      ┌───┐  │       └───┘├───┤»
# «          q_7: ┤ H ├───────────╫───╫────╫───┤M├──|0>─┤ H ├──■─────────■──┤ H ├»
# «               ├───┤┌───┐      ║   ║    ║   └╥┘      └───┘            │  ├───┤»
# «          q_8: ┤ H ├┤ H ├──────╫───╫────╫────╫───────────────────■────■──┤ H ├»
# «               └───┘├───┤      ║   ║    ║    ║   ┌─┐      ┌───┐  │       └───┘»
# «          q_9: ──■──┤ H ├──────╫───╫────╫────╫───┤M├──|0>─┤ H ├──■─────────■──»
# «                 │  ├───┤┌───┐ ║   ║    ║    ║   └╥┘      └───┘            │  »
# «         q_10: ──■──┤ H ├┤ H ├─╫───╫────╫────╫────╫───────────────────■────■──»
# «                    └───┘├───┤ ║   ║    ║    ║    ║   ┌─┐      ┌───┐  │       »
# «         q_11: ───────■──┤ H ├─╫───╫────╫────╫────╫───┤M├──|0>─┤ H ├──■───────»
# «                      │  ├───┤ ║   ║    ║    ║    ║   └╥┘ ┌───┐└───┘          »
# «         q_12: ──■────■──┤ H ├─╫───╫────╫────╫────╫────╫──┤ H ├────────────■──»
# «                 │       ├───┤ ║   ║    ║    ║    ║    ║  └┬─┬┘     ┌───┐  │  »
# «         q_13: ──■────■──┤ H ├─╫───╫────╫────╫────╫────╫───┤M├──|0>─┤ H ├──■──»
# «                      │  ├───┤ ║   ║    ║    ║    ║    ║   └╥┘ ┌───┐└───┘     »
# «         q_14: ───────■──┤ H ├─╫───╫────╫────╫────╫────╫────╫──┤ H ├──────────»
# «                         └───┘ ║   ║    ║    ║    ║    ║    ║  └───┘          »
# «     m_mcm0: 7/════════════════╬═══╬════╬════╬════╬════╬════╬═════════════════»
# «                               ║   ║    ║    ║    ║    ║    ║                 »
# «     m_mcm1: 7/════════════════╬═══╬════╬════╬════╬════╬════╬═════════════════»
# «                               ║   ║    ║    ║    ║    ║    ║                 »
# «     m_mcm2: 7/════════════════╬═══╬════╬════╬════╬════╬════╬═════════════════»
# «                               ║   ║    ║    ║    ║    ║    ║                 »
# «     m_mcm3: 7/════════════════╩═══╩════╩════╩════╩════╩════╩═════════════════»
# «                               0   1    2    3    4    5    6                 »
# «     m_mcm4: 7/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «     m_mcm5: 7/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «     m_mcm6: 7/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «m_meas_all: 15/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «                                           ┌───┐┌───┐                         »
# «          q_0: ─────────────────────────■──┤ H ├┤ H ├─────────────────────────»
# «                         ┌─┐     ┌───┐  │  └───┘└───┘┌───┐                    »
# «          q_1: ──────────┤M├─|0>─┤ H ├──■─────────■──┤ H ├────────────────────»
# «                         └╥┘     └───┘            │  ├───┤┌───┐               »
# «          q_2: ───────────╫──────────────────■────■──┤ H ├┤ H ├───────────────»
# «                          ║  ┌─┐      ┌───┐  │       └───┘├───┤               »
# «          q_3: ───────────╫──┤M├──|0>─┤ H ├──■─────────■──┤ H ├───────────────»
# «                          ║  └╥┘      └───┘            │  ├───┤┌───┐          »
# «          q_4: ───────────╫───╫───────────────────■────■──┤ H ├┤ H ├──────────»
# «                          ║   ║   ┌─┐      ┌───┐  │       └───┘├───┤          »
# «          q_5: ───────────╫───╫───┤M├──|0>─┤ H ├──■─────────■──┤ H ├──────────»
# «                          ║   ║   └╥┘      └───┘            │  ├───┤┌───┐     »
# «          q_6: ───────────╫───╫────╫───────────────────■────■──┤ H ├┤ H ├─────»
# «                          ║   ║    ║   ┌─┐      ┌───┐  │       └───┘├───┤     »
# «          q_7: ───────────╫───╫────╫───┤M├──|0>─┤ H ├──■─────────■──┤ H ├─────»
# «               ┌───┐      ║   ║    ║   └╥┘      └───┘            │  ├───┤┌───┐»
# «          q_8: ┤ H ├──────╫───╫────╫────╫───────────────────■────■──┤ H ├┤ H ├»
# «               ├───┤      ║   ║    ║    ║   ┌─┐      ┌───┐  │       └───┘├───┤»
# «          q_9: ┤ H ├──────╫───╫────╫────╫───┤M├──|0>─┤ H ├──■─────────■──┤ H ├»
# «               ├───┤┌───┐ ║   ║    ║    ║   └╥┘      └───┘            │  ├───┤»
# «         q_10: ┤ H ├┤ H ├─╫───╫────╫────╫────╫───────────────────■────■──┤ H ├»
# «               └───┘├───┤ ║   ║    ║    ║    ║   ┌─┐      ┌───┐  │       └───┘»
# «         q_11: ──■──┤ H ├─╫───╫────╫────╫────╫───┤M├──|0>─┤ H ├──■─────────■──»
# «                 │  ├───┤ ║   ║    ║    ║    ║   └╥┘ ┌───┐└───┘            │  »
# «         q_12: ──■──┤ H ├─╫───╫────╫────╫────╫────╫──┤ H ├────────────■────■──»
# «                    ├───┤ ║   ║    ║    ║    ║    ║  └┬─┬┘     ┌───┐  │       »
# «         q_13: ──■──┤ H ├─╫───╫────╫────╫────╫────╫───┤M├──|0>─┤ H ├──■────■──»
# «                 │  ├───┤ ║   ║    ║    ║    ║    ║   └╥┘ ┌───┐└───┘       │  »
# «         q_14: ──■──┤ H ├─╫───╫────╫────╫────╫────╫────╫──┤ H ├────────────■──»
# «                    └───┘ ║   ║    ║    ║    ║    ║    ║  └───┘               »
# «     m_mcm0: 7/═══════════╬═══╬════╬════╬════╬════╬════╬══════════════════════»
# «                          ║   ║    ║    ║    ║    ║    ║                      »
# «     m_mcm1: 7/═══════════╬═══╬════╬════╬════╬════╬════╬══════════════════════»
# «                          ║   ║    ║    ║    ║    ║    ║                      »
# «     m_mcm2: 7/═══════════╬═══╬════╬════╬════╬════╬════╬══════════════════════»
# «                          ║   ║    ║    ║    ║    ║    ║                      »
# «     m_mcm3: 7/═══════════╬═══╬════╬════╬════╬════╬════╬══════════════════════»
# «                          ║   ║    ║    ║    ║    ║    ║                      »
# «     m_mcm4: 7/═══════════╩═══╩════╩════╩════╩════╩════╩══════════════════════»
# «                          0   1    2    3    4    5    6                      »
# «     m_mcm5: 7/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «     m_mcm6: 7/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «m_meas_all: 15/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «                                      ┌───┐┌───┐                              »
# «          q_0: ────────────────────■──┤ H ├┤ H ├──────────────────────────────»
# «                    ┌─┐     ┌───┐  │  └───┘└───┘┌───┐                         »
# «          q_1: ─────┤M├─|0>─┤ H ├──■─────────■──┤ H ├─────────────────────────»
# «                    └╥┘     └───┘            │  ├───┤┌───┐                    »
# «          q_2: ──────╫──────────────────■────■──┤ H ├┤ H ├────────────────────»
# «                     ║  ┌─┐      ┌───┐  │       └───┘├───┤                    »
# «          q_3: ──────╫──┤M├──|0>─┤ H ├──■─────────■──┤ H ├────────────────────»
# «                     ║  └╥┘      └───┘            │  ├───┤┌───┐               »
# «          q_4: ──────╫───╫───────────────────■────■──┤ H ├┤ H ├───────────────»
# «                     ║   ║   ┌─┐      ┌───┐  │       └───┘├───┤               »
# «          q_5: ──────╫───╫───┤M├──|0>─┤ H ├──■─────────■──┤ H ├───────────────»
# «                     ║   ║   └╥┘      └───┘            │  ├───┤┌───┐          »
# «          q_6: ──────╫───╫────╫───────────────────■────■──┤ H ├┤ H ├──────────»
# «                     ║   ║    ║   ┌─┐      ┌───┐  │       └───┘├───┤          »
# «          q_7: ──────╫───╫────╫───┤M├──|0>─┤ H ├──■─────────■──┤ H ├──────────»
# «                     ║   ║    ║   └╥┘      └───┘            │  ├───┤┌───┐     »
# «          q_8: ──────╫───╫────╫────╫───────────────────■────■──┤ H ├┤ H ├─────»
# «                     ║   ║    ║    ║   ┌─┐      ┌───┐  │       └───┘├───┤     »
# «          q_9: ──────╫───╫────╫────╫───┤M├──|0>─┤ H ├──■─────────■──┤ H ├─────»
# «               ┌───┐ ║   ║    ║    ║   └╥┘      └───┘            │  ├───┤┌───┐»
# «         q_10: ┤ H ├─╫───╫────╫────╫────╫───────────────────■────■──┤ H ├┤ H ├»
# «               ├───┤ ║   ║    ║    ║    ║   ┌─┐      ┌───┐  │       └───┘├───┤»
# «         q_11: ┤ H ├─╫───╫────╫────╫────╫───┤M├──|0>─┤ H ├──■─────────■──┤ H ├»
# «               ├───┤ ║   ║    ║    ║    ║   └╥┘ ┌───┐└───┘            │  ├───┤»
# «         q_12: ┤ H ├─╫───╫────╫────╫────╫────╫──┤ H ├────────────■────■──┤ H ├»
# «               ├───┤ ║   ║    ║    ║    ║    ║  └┬─┬┘     ┌───┐  │       ├───┤»
# «         q_13: ┤ H ├─╫───╫────╫────╫────╫────╫───┤M├──|0>─┤ H ├──■────■──┤ H ├»
# «               ├───┤ ║   ║    ║    ║    ║    ║   └╥┘ ┌───┐└───┘       │  ├───┤»
# «         q_14: ┤ H ├─╫───╫────╫────╫────╫────╫────╫──┤ H ├────────────■──┤ H ├»
# «               └───┘ ║   ║    ║    ║    ║    ║    ║  └───┘               └───┘»
# «     m_mcm0: 7/══════╬═══╬════╬════╬════╬════╬════╬═══════════════════════════»
# «                     ║   ║    ║    ║    ║    ║    ║                           »
# «     m_mcm1: 7/══════╬═══╬════╬════╬════╬════╬════╬═══════════════════════════»
# «                     ║   ║    ║    ║    ║    ║    ║                           »
# «     m_mcm2: 7/══════╬═══╬════╬════╬════╬════╬════╬═══════════════════════════»
# «                     ║   ║    ║    ║    ║    ║    ║                           »
# «     m_mcm3: 7/══════╬═══╬════╬════╬════╬════╬════╬═══════════════════════════»
# «                     ║   ║    ║    ║    ║    ║    ║                           »
# «     m_mcm4: 7/══════╬═══╬════╬════╬════╬════╬════╬═══════════════════════════»
# «                     ║   ║    ║    ║    ║    ║    ║                           »
# «     m_mcm5: 7/══════╩═══╩════╩════╩════╩════╩════╩═══════════════════════════»
# «                     0   1    2    3    4    5    6                           »
# «     m_mcm6: 7/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «m_meas_all: 15/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «                                                     ┌─┐                     »
# «          q_0: ──────────────────────────────────────┤M├─────────────────────»
# «               ┌─┐                                   └╥┘                     »
# «          q_1: ┤M├─|0>────────────────────────────────╫──────────────────────»
# «               └╥┘                                    ║ ┌─┐                  »
# «          q_2: ─╫─────────────────────────────────────╫─┤M├──────────────────»
# «                ║  ┌─┐                                ║ └╥┘                  »
# «          q_3: ─╫──┤M├──|0>───────────────────────────╫──╫───────────────────»
# «                ║  └╥┘                                ║  ║ ┌─┐               »
# «          q_4: ─╫───╫─────────────────────────────────╫──╫─┤M├───────────────»
# «                ║   ║   ┌─┐                           ║  ║ └╥┘               »
# «          q_5: ─╫───╫───┤M├──|0>──────────────────────╫──╫──╫────────────────»
# «                ║   ║   └╥┘                           ║  ║  ║ ┌─┐            »
# «          q_6: ─╫───╫────╫────────────────────────────╫──╫──╫─┤M├────────────»
# «                ║   ║    ║   ┌─┐                      ║  ║  ║ └╥┘            »
# «          q_7: ─╫───╫────╫───┤M├──|0>─────────────────╫──╫──╫──╫─────────────»
# «                ║   ║    ║   └╥┘                      ║  ║  ║  ║ ┌─┐         »
# «          q_8: ─╫───╫────╫────╫───────────────────────╫──╫──╫──╫─┤M├─────────»
# «                ║   ║    ║    ║   ┌─┐                 ║  ║  ║  ║ └╥┘         »
# «          q_9: ─╫───╫────╫────╫───┤M├──|0>────────────╫──╫──╫──╫──╫──────────»
# «                ║   ║    ║    ║   └╥┘                 ║  ║  ║  ║  ║ ┌─┐      »
# «         q_10: ─╫───╫────╫────╫────╫──────────────────╫──╫──╫──╫──╫─┤M├──────»
# «                ║   ║    ║    ║    ║   ┌─┐            ║  ║  ║  ║  ║ └╥┘      »
# «         q_11: ─╫───╫────╫────╫────╫───┤M├──|0>───────╫──╫──╫──╫──╫──╫───────»
# «                ║   ║    ║    ║    ║   └╥┘ ┌───┐      ║  ║  ║  ║  ║  ║ ┌─┐   »
# «         q_12: ─╫───╫────╫────╫────╫────╫──┤ H ├──────╫──╫──╫──╫──╫──╫─┤M├───»
# «                ║   ║    ║    ║    ║    ║  └┬─┬┘      ║  ║  ║  ║  ║  ║ └╥┘   »
# «         q_13: ─╫───╫────╫────╫────╫────╫───┤M├──|0>──╫──╫──╫──╫──╫──╫──╫────»
# «                ║   ║    ║    ║    ║    ║   └╥┘ ┌───┐ ║  ║  ║  ║  ║  ║  ║ ┌─┐»
# «         q_14: ─╫───╫────╫────╫────╫────╫────╫──┤ H ├─╫──╫──╫──╫──╫──╫──╫─┤M├»
# «                ║   ║    ║    ║    ║    ║    ║  └───┘ ║  ║  ║  ║  ║  ║  ║ └╥┘»
# «     m_mcm0: 7/═╬═══╬════╬════╬════╬════╬════╬════════╬══╬══╬══╬══╬══╬══╬══╬═»
# «                ║   ║    ║    ║    ║    ║    ║        ║  ║  ║  ║  ║  ║  ║  ║ »
# «     m_mcm1: 7/═╬═══╬════╬════╬════╬════╬════╬════════╬══╬══╬══╬══╬══╬══╬══╬═»
# «                ║   ║    ║    ║    ║    ║    ║        ║  ║  ║  ║  ║  ║  ║  ║ »
# «     m_mcm2: 7/═╬═══╬════╬════╬════╬════╬════╬════════╬══╬══╬══╬══╬══╬══╬══╬═»
# «                ║   ║    ║    ║    ║    ║    ║        ║  ║  ║  ║  ║  ║  ║  ║ »
# «     m_mcm3: 7/═╬═══╬════╬════╬════╬════╬════╬════════╬══╬══╬══╬══╬══╬══╬══╬═»
# «                ║   ║    ║    ║    ║    ║    ║        ║  ║  ║  ║  ║  ║  ║  ║ »
# «     m_mcm4: 7/═╬═══╬════╬════╬════╬════╬════╬════════╬══╬══╬══╬══╬══╬══╬══╬═»
# «                ║   ║    ║    ║    ║    ║    ║        ║  ║  ║  ║  ║  ║  ║  ║ »
# «     m_mcm5: 7/═╬═══╬════╬════╬════╬════╬════╬════════╬══╬══╬══╬══╬══╬══╬══╬═»
# «                ║   ║    ║    ║    ║    ║    ║        ║  ║  ║  ║  ║  ║  ║  ║ »
# «     m_mcm6: 7/═╩═══╩════╩════╩════╩════╩════╩════════╬══╬══╬══╬══╬══╬══╬══╬═»
# «                0   1    2    3    4    5    6        ║  ║  ║  ║  ║  ║  ║  ║ »
# «m_meas_all: 15/═══════════════════════════════════════╩══╩══╩══╩══╩══╩══╩══╩═»
# «                                                      0  2  4  6  8  10 12 14»
# «
# «          q_0: ─────────────────────
# «               ┌─┐
# «          q_1: ┤M├──────────────────
# «               └╥┘
# «          q_2: ─╫───────────────────
# «                ║ ┌─┐
# «          q_3: ─╫─┤M├───────────────
# «                ║ └╥┘
# «          q_4: ─╫──╫────────────────
# «                ║  ║ ┌─┐
# «          q_5: ─╫──╫─┤M├────────────
# «                ║  ║ └╥┘
# «          q_6: ─╫──╫──╫─────────────
# «                ║  ║  ║ ┌─┐
# «          q_7: ─╫──╫──╫─┤M├─────────
# «                ║  ║  ║ └╥┘
# «          q_8: ─╫──╫──╫──╫──────────
# «                ║  ║  ║  ║ ┌─┐
# «          q_9: ─╫──╫──╫──╫─┤M├──────
# «                ║  ║  ║  ║ └╥┘
# «         q_10: ─╫──╫──╫──╫──╫───────
# «                ║  ║  ║  ║  ║ ┌─┐
# «         q_11: ─╫──╫──╫──╫──╫─┤M├───
# «                ║  ║  ║  ║  ║ └╥┘
# «         q_12: ─╫──╫──╫──╫──╫──╫────
# «                ║  ║  ║  ║  ║  ║ ┌─┐
# «         q_13: ─╫──╫──╫──╫──╫──╫─┤M├
# «                ║  ║  ║  ║  ║  ║ └╥┘
# «         q_14: ─╫──╫──╫──╫──╫──╫──╫─
# «                ║  ║  ║  ║  ║  ║  ║
# «     m_mcm0: 7/═╬══╬══╬══╬══╬══╬══╬═
# «                ║  ║  ║  ║  ║  ║  ║
# «     m_mcm1: 7/═╬══╬══╬══╬══╬══╬══╬═
# «                ║  ║  ║  ║  ║  ║  ║
# «     m_mcm2: 7/═╬══╬══╬══╬══╬══╬══╬═
# «                ║  ║  ║  ║  ║  ║  ║
# «     m_mcm3: 7/═╬══╬══╬══╬══╬══╬══╬═
# «                ║  ║  ║  ║  ║  ║  ║
# «     m_mcm4: 7/═╬══╬══╬══╬══╬══╬══╬═
# «                ║  ║  ║  ║  ║  ║  ║
# «     m_mcm5: 7/═╬══╬══╬══╬══╬══╬══╬═
# «                ║  ║  ║  ║  ║  ║  ║
# «     m_mcm6: 7/═╬══╬══╬══╬══╬══╬══╬═
# «                ║  ║  ║  ║  ║  ║  ║
# «m_meas_all: 15/═╩══╩══╩══╩══╩══╩══╩═
# «                1  3  5  7  9  11 13

# %%
benchmark_features = {}
for benchmark, label in benchmarks:
    benchmark_features[label] = [
        supermarq.converters.compute_communication_with_qiskit(benchmark.qiskit_circuit()),
        supermarq.converters.compute_depth_with_qiskit(benchmark.qiskit_circuit()),
        supermarq.converters.compute_entanglement_with_qiskit(benchmark.qiskit_circuit()),
        supermarq.converters.compute_liveness_with_qiskit(benchmark.qiskit_circuit()),
        supermarq.converters.compute_measurement_with_qiskit(benchmark.qiskit_circuit()),
        supermarq.converters.compute_parallelism_with_qiskit(benchmark.qiskit_circuit()),]
print(benchmark_features)
# Out:
# {'phase_code3': [0.4, 0.375, 0.22857142857142856, 0.8, 0.15384615384615385, 0.375], 'phase_code4': [0.2857142857142857, 0.3333333333333333, 0.2571428571428571, 0.7687074829931972, 0.3, 0.3888888888888889], 'phase_code5': [0.2222222222222222, 0.25, 0.2711864406779661, 0.7860082304526749, 0.15384615384615385, 0.4212962962962963], 'phase_code6': [0.18181818181818182, 0.2, 0.2824858757062147, 0.7933884297520661, 0.3125, 0.43636363636363634], 'phase_code7': [0.15384615384615385, 0.16666666666666666, 0.2938775510204082, 0.7928994082840237, 0.3157894736842105, 0.44017094017094016], 'phase_code8': [0.13333333333333333, 0.14285714285714285, 0.2996941896024465, 0.797037037037037, 0.20454545454545456, 0.44761904761904764]}

# %%
jobs =[]
print("=============SCORES OF ALL THE CIRCUITS=============")    
for backend in selected_fakes:
    print("------------------------BACKEND-NAME :: ", backend().name)
    for benchmark, label in benchmarks:
        circuit=benchmark.qiskit_circuit()
        score_list=[]
        for i in range(0,5):
            job = backend().run(circuit, shots=1000)
            result=job.result()
            #print(result)
            counts = job.result(0).get_counts()
            score = benchmark.score(counts)
            score_list.append(score)
        score = np.mean(score_list) 
        sd = np.std(score_list)
        print(label," --> score :: ",score,"           SD :: ",sd,"  time_taken= ",job.result(0).time_taken)
        #counts=job.result(0).count()
        jobs.append((label,benchmark,backend,job,score,sd))
#jobs
# Out:
# =============SCORES OF ALL THE CIRCUITS=============
# ------------------------BACKEND-NAME ::  fake_quito
# phase_code3  --> score ::  9.860761315262648e-33            SD ::  1.9721522630525296e-32   time_taken=  0.14874863624572754
# phase_code4  --> score ::  0.0            SD ::  0.0   time_taken=  0.4058997631072998
# phase_code5  --> score ::  0.0            SD ::  0.0   time_taken=  0.27913904190063477
# phase_code6  --> score ::  0.0            SD ::  0.0   time_taken=  0.725759744644165
# phase_code7  --> score ::  0.0            SD ::  0.0   time_taken=  3.227837562561035
# phase_code8  --> score ::  0.0            SD ::  0.0   time_taken=  9.98405122756958
# ------------------------BACKEND-NAME ::  fake_essex
# phase_code3  --> score ::  0.0            SD ::  0.0   time_taken=  0.09540772438049316
# phase_code4  --> score ::  0.0            SD ::  0.0   time_taken=  0.11644315719604492
# phase_code5  --> score ::  0.0            SD ::  0.0   time_taken=  0.19867300987243652
# phase_code6  --> score ::  0.0            SD ::  0.0   time_taken=  0.6133389472961426
# phase_code7  --> score ::  0.0            SD ::  0.0   time_taken=  2.9974992275238037
# phase_code8  --> score ::  0.0            SD ::  0.0   time_taken=  12.211455345153809
# ------------------------BACKEND-NAME ::  fake_armonk
# phase_code3  --> score ::  0.0            SD ::  0.0   time_taken=  0.03549790382385254
# phase_code4  --> score ::  0.0            SD ::  0.0   time_taken=  0.04431629180908203
# phase_code5  --> score ::  0.0            SD ::  0.0   time_taken=  0.1165320873260498
# phase_code6  --> score ::  0.0            SD ::  0.0   time_taken=  0.7623789310455322
# phase_code7  --> score ::  0.0            SD ::  0.0   time_taken=  2.7681124210357666
# phase_code8  --> score ::  0.0            SD ::  0.0   time_taken=  9.982971906661987
# ------------------------BACKEND-NAME ::  fake_prague
# phase_code3  --> score ::  0.0            SD ::  0.0   time_taken=  0.7002279758453369
# phase_code4  --> score ::  0.0            SD ::  0.0   time_taken=  0.8091347217559814
# phase_code5  --> score ::  0.0            SD ::  0.0   time_taken=  0.952850341796875
# phase_code6  --> score ::  0.0            SD ::  0.0   time_taken=  1.6339514255523682
# phase_code7  --> score ::  0.0            SD ::  0.0   time_taken=  3.9968760013580322
# phase_code8  --> score ::  0.0            SD ::  0.0   time_taken=  11.187304735183716
# ------------------------BACKEND-NAME ::  fake_santiago
# phase_code3  --> score ::  0.0            SD ::  0.0   time_taken=  0.14341950416564941
# phase_code4  --> score ::  0.0            SD ::  0.0   time_taken=  0.11911940574645996
# phase_code5  --> score ::  0.0            SD ::  0.0   time_taken=  0.1937241554260254
# phase_code6  --> score ::  0.0            SD ::  0.0   time_taken=  0.459949254989624
# phase_code7  --> score ::  0.0            SD ::  0.0   time_taken=  3.216116189956665
# phase_code8  --> score ::  0.0            SD ::  0.0   time_taken=  9.76056456565857

# %%
all_scores={}  
all_fake_names=[]
all_fake_scores=[]
for i in selected_fakes:
    fakes=i
    i={}
    for label,benchmark,backend,job,score,sd in jobs:
        #supermarq.plotting.plot_results([score], [label])
        if fakes == backend:
            i[label] = score
    device_scores = 'device_score_' +str(fakes().name)
    all_scores[device_scores]= i
    all_fake_scores.append(i)
    all_fake_names.append(device_scores)

# %%
for label,benchmark,backend,job,score,sd in jobs:
    print("USED BACKEND::",backend().name,"; CIRCUIT_NAME:",label, "; SCORE =",score)
    supermarq.plotting.plot_results([score], [label])
    print("-----------------------------------------------------------")
# Out:
# USED BACKEND:: fake_quito ; CIRCUIT_NAME: phase_code3 ; SCORE = 9.860761315262648e-33
# -----------------------------------------------------------
# USED BACKEND:: fake_quito ; CIRCUIT_NAME: phase_code4 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_quito ; CIRCUIT_NAME: phase_code5 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_quito ; CIRCUIT_NAME: phase_code6 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_quito ; CIRCUIT_NAME: phase_code7 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_quito ; CIRCUIT_NAME: phase_code8 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_essex ; CIRCUIT_NAME: phase_code3 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_essex ; CIRCUIT_NAME: phase_code4 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_essex ; CIRCUIT_NAME: phase_code5 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_essex ; CIRCUIT_NAME: phase_code6 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_essex ; CIRCUIT_NAME: phase_code7 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_essex ; CIRCUIT_NAME: phase_code8 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_armonk ; CIRCUIT_NAME: phase_code3 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_armonk ; CIRCUIT_NAME: phase_code4 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_armonk ; CIRCUIT_NAME: phase_code5 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_armonk ; CIRCUIT_NAME: phase_code6 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_armonk ; CIRCUIT_NAME: phase_code7 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_armonk ; CIRCUIT_NAME: phase_code8 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_prague ; CIRCUIT_NAME: phase_code3 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_prague ; CIRCUIT_NAME: phase_code4 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_prague ; CIRCUIT_NAME: phase_code5 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_prague ; CIRCUIT_NAME: phase_code6 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_prague ; CIRCUIT_NAME: phase_code7 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_prague ; CIRCUIT_NAME: phase_code8 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_santiago ; CIRCUIT_NAME: phase_code3 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_santiago ; CIRCUIT_NAME: phase_code4 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_santiago ; CIRCUIT_NAME: phase_code5 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_santiago ; CIRCUIT_NAME: phase_code6 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_santiago ; CIRCUIT_NAME: phase_code7 ; SCORE = 0.0
# -----------------------------------------------------------
# USED BACKEND:: fake_santiago ; CIRCUIT_NAME: phase_code8 ; SCORE = 0.0
# -----------------------------------------------------------

# %%
names=[]
scores=[]
X="A "+name_of_algo+' Benchamrk'
for i,j in benchmark_features.items():
    names.append(i)
    scores.append(j)
supermarq.plotting.plot_benchmark(
        [X,names,scores],
        spoke_labels=["PC", "CD", "Ent", "Liv", "Mea", "Par"],
        show=True)

# %%
supermarq.plotting.plot_correlations(benchmark_features,all_fake_scores,["PC", "CD", "Ent", "Liv", "Mea", "Par"],device_name=all_fake_names,show=True,)

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 
import numpy as np
all_fake_names=[]
all_score=[]
all_sd=[]
all_ckt=[]
for i in selected_fakes:
    all_fake_names.append(i().name)    
for benchmark, label in benchmarks:
    i=[]
    j=[]
    k=[]
    for ckt,benchmark,backend,job,score,sd in jobs:
        if ckt == label:
            i.append(score)
            j.append(sd)
    all_ckt.append(label)
    all_score.append(i)
    all_sd.append(j)
num_bars = len(all_score)
width = 0.1
x = np.arange(len(all_fake_names)) # x-axis positions for each bar
fig, ax = plt.subplots()
for i in range(num_bars):               # Create bars for each category with appropriate offsets
    ax.bar(x + i * width, all_score[i], width=width, label=f'Bar {i+1}', 
           yerr=all_sd[i],align='center',alpha=0.9,ecolor='black',capsize=2)
ax.set_xlabel('Name of Fake Backends',fontweight ='bold',fontsize = 12)
ax.set_ylabel('Scores',fontweight ='bold',fontsize = 12)
ax.set_title('Plot of GHZ over Multiple Qubits')
ax.set_xticks(x + (num_bars - 1) * width / 2)
ax.set_xticklabels(all_fake_names)
ax.legend(all_ckt,loc="lower left")
#ax.grid(True)
plt.show()
